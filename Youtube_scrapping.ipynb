# %%
from googleapiclient.discovery import build

# %%
import pandas as pd

# %%
import numpy as np

# %%
api_key='AIzaSyBVBJR_UMhZVjcviHjCvgLU2LmVo0zzbWU'
channel_ids=['UCnz-ZXXER4jOvuED5trXfEA',  # tech TFQ
            'UC7cs8q-gJRlGwj4A8OmCmXg', #alex the analist
            'UCCWi3hpnq_Pe03nGxuS7isg', # campus X
            'UC8uU_wruBMHeeRma49dtZKA', # chando
            'UCh9nVJoWXmFb7sLApWGcLPQ', # code basics
            'UCcIXc5mJsHVYTZR1maL5l9w', # deeplearning
            'UCkndrGoNpUDV-uia6a9jwVg', # excelfun
            'UCFp1vaKzpfvoGai0vE5VJ0w', # guy in a cube
            'UCq6XkhO5SZ66N04IcPbqNcw', #keith galli
            'UCiT9RITQ9PW6BhXK0y2jaeg', #ken lee
            'UCfJT_eYDTmDE-ovKaxVE1ig', # kevin startvert
            'UCNU_lfiiWBdtULKOw6X0Dig', # krish naik
            'UCJtUOos_MwJa_Ewii-R3cJA', # Leila Gharani
            'UCLLw7jmFsvfIVaUFsLs8mlQ', # luke barousse
            'UC3rY5HOgbBvGmq7RnDfwF7A', # rishab mishra
            'UCxladMszXan-jfgzyeIMyvw', # rob mulla
            'UCfzlCWGWYyIQ0aLC5w48gBQ', # sentdex
            'UCW6TXMZ5Pq6yL6_k5NZ2e0Q', # Socratica
            'UCtYLUTtgS3k1Fg4y5tAhLbw', #StatQuest with Josh Starmer
            'UC7HYxRWmaNlJux-X7rNLZyw', # Tableau Tim
            'UCJQJAI7IjbLcpsjWdSzYz0Q', # Thu Vu data analytics
            'UC2UXDak6o7rBm23k3Vv5dww', # Tina Huang
            'UC0T6MVd3wQDB5ICAe45OxaQ', # wscube
            'UCXUPKJO5MZQN11PqgIvyuvQ', #Andrej Karpathy
            'UCChmJrVa8kDg05JfCmxpLRw', #Darshil Parmar
            'UC_lePY0Lm0E2-_IkYUWpI5A', #Dataquest
            'UC8butISFwT-Wl7EV0hUK0BQ', #freeCodeCamp.org 
            'UCSNeZleDn9c74yQc-EKnVTA', #Kaggle
            'UCHXa4OpASJEwrHrLeIzw7Yg', #Nicholas Renotte 
            'UCKq-lHnyradGRmFClX_ACMw', #Ryan Nolan Data
            'UCtYLUTtgS3k1Fg4y5tAhLbw', #StatQuest with Josh Starmer
             
             
            ]

youtube=build('youtube','v3',developerKey=api_key)

# %%
def get_channel_stats(youtube,channel_ids):
    all_data=[]
    request=youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response=request.execute()
    for i in range (len(response['items'])):
        data=dict(Channel_Name=response['items'][i]['snippet']['title'],
                  publishedAt=response['items'][i]['snippet']['publishedAt'],
                  channel_country=response['items'][i]['snippet'].get('country', 'N/A'),
                  Subscribers=response['items'][i]['statistics']['subscriberCount'],
                  Views=response['items'][i]['statistics']['viewCount'],
                  Total_videos=response['items'][i]['statistics']['videoCount'],
                  Playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
                  

    return all_data

# %%
channel_info=get_channel_stats(youtube,channel_ids)
channel_info
# Out:
# [{'Channel_Name': 'Rishabh Mishra',
#   'publishedAt': '2022-02-12T14:28:29.641872Z',
#   'channel_country': 'IN',
#   'Subscribers': '265000',
#   'Views': '16618957',
#   'Total_videos': '88',
#   'Playlist_id': 'UU3rY5HOgbBvGmq7RnDfwF7A'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'publishedAt': '2011-05-24T01:52:48Z',
#   'channel_country': 'US',
#   'Subscribers': '1190000',
#   'Views': '65965965',
#   'Total_videos': '278',
#   'Playlist_id': 'UUtYLUTtgS3k1Fg4y5tAhLbw'},
#  {'Channel_Name': 'Nicholas Renotte',
#   'publishedAt': '2019-01-26T22:31:46Z',
#   'channel_country': 'AU',
#   'Subscribers': '266000',
#   'Views': '17782015',
#   'Total_videos': '307',
#   'Playlist_id': 'UUHXa4OpASJEwrHrLeIzw7Yg'},
#  {'Channel_Name': 'Leila Gharani',
#   'publishedAt': '2015-08-11T10:54:25Z',
#   'channel_country': 'AT',
#   'Subscribers': '2620000',
#   'Views': '253760489',
#   'Total_videos': '585',
#   'Playlist_id': 'UUJtUOos_MwJa_Ewii-R3cJA'},
#  {'Channel_Name': 'Ryan Nolan Data',
#   'publishedAt': '2023-05-17T11:37:25.800931Z',
#   'channel_country': 'N/A',
#   'Subscribers': '9260',
#   'Views': '331996',
#   'Total_videos': '156',
#   'Playlist_id': 'UUKq-lHnyradGRmFClX_ACMw'},
#  {'Channel_Name': 'WsCube Tech',
#   'publishedAt': '2015-08-22T13:22:51Z',
#   'channel_country': 'IN',
#   'Subscribers': '3400000',
#   'Views': '292224166',
#   'Total_videos': '5232',
#   'Playlist_id': 'UU0T6MVd3wQDB5ICAe45OxaQ'},
#  {'Channel_Name': 'codebasics',
#   'publishedAt': '2015-11-07T17:29:46Z',
#   'channel_country': 'US',
#   'Subscribers': '1040000',
#   'Views': '86137181',
#   'Total_videos': '881',
#   'Playlist_id': 'UUh9nVJoWXmFb7sLApWGcLPQ'},
#  {'Channel_Name': 'Ken Jee',
#   'publishedAt': '2014-02-28T14:58:24Z',
#   'channel_country': 'US',
#   'Subscribers': '260000',
#   'Views': '9019341',
#   'Total_videos': '287',
#   'Playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'},
#  {'Channel_Name': 'Kaggle',
#   'publishedAt': '2011-10-25T02:57:52Z',
#   'channel_country': 'N/A',
#   'Subscribers': '142000',
#   'Views': '4267029',
#   'Total_videos': '379',
#   'Playlist_id': 'UUSNeZleDn9c74yQc-EKnVTA'},
#  {'Channel_Name': 'Luke Barousse',
#   'publishedAt': '2020-08-03T09:02:41.213077Z',
#   'channel_country': 'US',
#   'Subscribers': '445000',
#   'Views': '22229968',
#   'Total_videos': '158',
#   'Playlist_id': 'UULLw7jmFsvfIVaUFsLs8mlQ'},
#  {'Channel_Name': 'DeepLearningAI',
#   'publishedAt': '2017-08-22T22:27:58Z',
#   'channel_country': 'N/A',
#   'Subscribers': '312000',
#   'Views': '18593110',
#   'Total_videos': '434',
#   'Playlist_id': 'UUcIXc5mJsHVYTZR1maL5l9w'},
#  {'Channel_Name': 'Dataquest',
#   'publishedAt': '2019-01-30T18:36:22Z',
#   'channel_country': 'US',
#   'Subscribers': '58000',
#   'Views': '2114736',
#   'Total_videos': '50',
#   'Playlist_id': 'UU_lePY0Lm0E2-_IkYUWpI5A'},
#  {'Channel_Name': 'Keith Galli',
#   'publishedAt': '2016-12-27T20:18:51Z',
#   'channel_country': 'US',
#   'Subscribers': '221000',
#   'Views': '15224886',
#   'Total_videos': '87',
#   'Playlist_id': 'UUq6XkhO5SZ66N04IcPbqNcw'},
#  {'Channel_Name': 'Darshil Parmar',
#   'publishedAt': '2021-04-13T14:01:35.850568Z',
#   'channel_country': 'IN',
#   'Subscribers': '136000',
#   'Views': '6359799',
#   'Total_videos': '152',
#   'Playlist_id': 'UUChmJrVa8kDg05JfCmxpLRw'},
#  {'Channel_Name': 'Rob Mulla',
#   'publishedAt': '2021-09-26T18:25:56.754723Z',
#   'channel_country': 'US',
#   'Subscribers': '171000',
#   'Views': '11691719',
#   'Total_videos': '157',
#   'Playlist_id': 'UUxladMszXan-jfgzyeIMyvw'},
#  {'Channel_Name': 'Andrej Karpathy',
#   'publishedAt': '2013-09-07T08:21:13Z',
#   'channel_country': 'US',
#   'Subscribers': '488000',
#   'Views': '10574792',
#   'Total_videos': '15',
#   'Playlist_id': 'UUXUPKJO5MZQN11PqgIvyuvQ'},
#  {'Channel_Name': 'Tina Huang',
#   'publishedAt': '2013-08-28T18:05:17Z',
#   'channel_country': 'US',
#   'Subscribers': '665000',
#   'Views': '31396034',
#   'Total_videos': '222',
#   'Playlist_id': 'UU2UXDak6o7rBm23k3Vv5dww'},
#  {'Channel_Name': 'sentdex',
#   'publishedAt': '2012-12-16T20:49:11Z',
#   'channel_country': 'US',
#   'Subscribers': '1340000',
#   'Views': '114924004',
#   'Total_videos': '1254',
#   'Playlist_id': 'UUfzlCWGWYyIQ0aLC5w48gBQ'},
#  {'Channel_Name': 'CampusX',
#   'publishedAt': '2019-04-17T19:32:35Z',
#   'channel_country': 'IN',
#   'Subscribers': '205000',
#   'Views': '22409916',
#   'Total_videos': '1185',
#   'Playlist_id': 'UUCWi3hpnq_Pe03nGxuS7isg'},
#  {'Channel_Name': 'Chandoo',
#   'publishedAt': '2009-05-02T06:44:42Z',
#   'channel_country': 'NZ',
#   'Subscribers': '615000',
#   'Views': '48366694',
#   'Total_videos': '479',
#   'Playlist_id': 'UU8uU_wruBMHeeRma49dtZKA'},
#  {'Channel_Name': 'freeCodeCamp.org',
#   'publishedAt': '2014-12-16T21:18:48Z',
#   'channel_country': 'US',
#   'Subscribers': '9590000',
#   'Views': '724979565',
#   'Total_videos': '1673',
#   'Playlist_id': 'UU8butISFwT-Wl7EV0hUK0BQ'},
#  {'Channel_Name': 'Socratica',
#   'publishedAt': '2011-12-24T18:39:38Z',
#   'channel_country': 'US',
#   'Subscribers': '883000',
#   'Views': '59548763',
#   'Total_videos': '661',
#   'Playlist_id': 'UUW6TXMZ5Pq6yL6_k5NZ2e0Q'},
#  {'Channel_Name': 'Kevin Stratvert',
#   'publishedAt': '2007-01-08T00:08:18Z',
#   'channel_country': 'US',
#   'Subscribers': '3030000',
#   'Views': '422255209',
#   'Total_videos': '857',
#   'Playlist_id': 'UUfJT_eYDTmDE-ovKaxVE1ig'},
#  {'Channel_Name': 'Tableau Tim',
#   'publishedAt': '2010-04-05T00:58:32Z',
#   'channel_country': 'GB',
#   'Subscribers': '169000',
#   'Views': '4024030',
#   'Total_videos': '516',
#   'Playlist_id': 'UU7HYxRWmaNlJux-X7rNLZyw'},
#  {'Channel_Name': 'Thu Vu data analytics',
#   'publishedAt': '2021-04-30T15:22:58.33437Z',
#   'channel_country': 'US',
#   'Subscribers': '234000',
#   'Views': '7913464',
#   'Total_videos': '87',
#   'Playlist_id': 'UUJQJAI7IjbLcpsjWdSzYz0Q'},
#  {'Channel_Name': 'Guy in a Cube',
#   'publishedAt': '2014-12-03T13:23:39Z',
#   'channel_country': 'US',
#   'Subscribers': '433000',
#   'Views': '35813956',
#   'Total_videos': '1044',
#   'Playlist_id': 'UUFp1vaKzpfvoGai0vE5VJ0w'},
#  {'Channel_Name': 'Krish Naik',
#   'publishedAt': '2012-02-11T04:05:06Z',
#   'channel_country': 'IN',
#   'Subscribers': '971000',
#   'Views': '99650820',
#   'Total_videos': '1917',
#   'Playlist_id': 'UUNU_lfiiWBdtULKOw6X0Dig'},
#  {'Channel_Name': 'techTFQ',
#   'publishedAt': '2020-06-13T05:20:37.182391Z',
#   'channel_country': 'MY',
#   'Subscribers': '305000',
#   'Views': '16795279',
#   'Total_videos': '136',
#   'Playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_Name': 'ExcelIsFun',
#   'publishedAt': '2008-02-16T03:31:10Z',
#   'channel_country': 'US',
#   'Subscribers': '1000000',
#   'Views': '154825458',
#   'Total_videos': '3698',
#   'Playlist_id': 'UUkndrGoNpUDV-uia6a9jwVg'},
#  {'Channel_Name': 'Alex The Analyst',
#   'publishedAt': '2020-01-08T05:04:24.970712Z',
#   'channel_country': 'US',
#   'Subscribers': '798000',
#   'Views': '35615518',
#   'Total_videos': '308',
#   'Playlist_id': 'UU7cs8q-gJRlGwj4A8OmCmXg'}]

# %%
channel_data=pd.DataFrame(channel_info)

# %%
channel_data
# Out:
#                    Channel_Name                  publishedAt channel_country  \
# 0                Rishabh Mishra  2022-02-12T14:28:29.641872Z              IN
# 1   StatQuest with Josh Starmer         2011-05-24T01:52:48Z              US
# 2              Nicholas Renotte         2019-01-26T22:31:46Z              AU
# 3                 Leila Gharani         2015-08-11T10:54:25Z              AT
# 4               Ryan Nolan Data  2023-05-17T11:37:25.800931Z             N/A
# 5                   WsCube Tech         2015-08-22T13:22:51Z              IN
# 6                    codebasics         2015-11-07T17:29:46Z              US
# 7                       Ken Jee         2014-02-28T14:58:24Z              US
# 8                        Kaggle         2011-10-25T02:57:52Z             N/A
# 9                 Luke Barousse  2020-08-03T09:02:41.213077Z              US
# 10               DeepLearningAI         2017-08-22T22:27:58Z             N/A
# 11                    Dataquest         2019-01-30T18:36:22Z              US
# 12                  Keith Galli         2016-12-27T20:18:51Z              US
# 13               Darshil Parmar  2021-04-13T14:01:35.850568Z              IN
# 14                    Rob Mulla  2021-09-26T18:25:56.754723Z              US
# 15              Andrej Karpathy         2013-09-07T08:21:13Z              US
# 16                   Tina Huang         2013-08-28T18:05:17Z              US
# 17                      sentdex         2012-12-16T20:49:11Z              US
# 18                      CampusX         2019-04-17T19:32:35Z              IN
# 19                      Chandoo         2009-05-02T06:44:42Z              NZ
# 20             freeCodeCamp.org         2014-12-16T21:18:48Z              US
# 21                    Socratica         2011-12-24T18:39:38Z              US
# 22              Kevin Stratvert         2007-01-08T00:08:18Z              US
# 23                  Tableau Tim         2010-04-05T00:58:32Z              GB
# 24        Thu Vu data analytics   2021-04-30T15:22:58.33437Z              US
# 25                Guy in a Cube         2014-12-03T13:23:39Z              US
# 26                   Krish Naik         2012-02-11T04:05:06Z              IN
# 27                      techTFQ  2020-06-13T05:20:37.182391Z              MY
# 28                   ExcelIsFun         2008-02-16T03:31:10Z              US
# 29             Alex The Analyst  2020-01-08T05:04:24.970712Z              US
#
#    Subscribers      Views Total_videos               Playlist_id
# 0       265000   16618957           88  UU3rY5HOgbBvGmq7RnDfwF7A
# 1      1190000   65965965          278  UUtYLUTtgS3k1Fg4y5tAhLbw
# 2       266000   17782015          307  UUHXa4OpASJEwrHrLeIzw7Yg
# 3      2620000  253760489          585  UUJtUOos_MwJa_Ewii-R3cJA
# 4         9260     331996          156  UUKq-lHnyradGRmFClX_ACMw
# 5      3400000  292224166         5232  UU0T6MVd3wQDB5ICAe45OxaQ
# 6      1040000   86137181          881  UUh9nVJoWXmFb7sLApWGcLPQ
# 7       260000    9019341          287  UUiT9RITQ9PW6BhXK0y2jaeg
# 8       142000    4267029          379  UUSNeZleDn9c74yQc-EKnVTA
# 9       445000   22229968          158  UULLw7jmFsvfIVaUFsLs8mlQ
# 10      312000   18593110          434  UUcIXc5mJsHVYTZR1maL5l9w
# 11       58000    2114736           50  UU_lePY0Lm0E2-_IkYUWpI5A
# 12      221000   15224886           87  UUq6XkhO5SZ66N04IcPbqNcw
# 13      136000    6359799          152  UUChmJrVa8kDg05JfCmxpLRw
# 14      171000   11691719          157  UUxladMszXan-jfgzyeIMyvw
# 15      488000   10574792           15  UUXUPKJO5MZQN11PqgIvyuvQ
# 16      665000   31396034          222  UU2UXDak6o7rBm23k3Vv5dww
# 17     1340000  114924004         1254  UUfzlCWGWYyIQ0aLC5w48gBQ
# 18      205000   22409916         1185  UUCWi3hpnq_Pe03nGxuS7isg
# 19      615000   48366694          479  UU8uU_wruBMHeeRma49dtZKA
# 20     9590000  724979565         1673  UU8butISFwT-Wl7EV0hUK0BQ
# 21      883000   59548763          661  UUW6TXMZ5Pq6yL6_k5NZ2e0Q
# 22     3030000  422255209          857  UUfJT_eYDTmDE-ovKaxVE1ig
# 23      169000    4024030          516  UU7HYxRWmaNlJux-X7rNLZyw
# 24      234000    7913464           87  UUJQJAI7IjbLcpsjWdSzYz0Q
# 25      433000   35813956         1044  UUFp1vaKzpfvoGai0vE5VJ0w
# 26      971000   99650820         1917  UUNU_lfiiWBdtULKOw6X0Dig
# 27      305000   16795279          136  UUnz-ZXXER4jOvuED5trXfEA
# 28     1000000  154825458         3698  UUkndrGoNpUDV-uia6a9jwVg
# 29      798000   35615518          308  UU7cs8q-gJRlGwj4A8OmCmXg

# %%
channel_name = channel_data['Channel_Name'].tolist()

# %%
channel_name
# Out:
# ['Rishabh Mishra',
#  'StatQuest with Josh Starmer',
#  'Nicholas Renotte',
#  'Leila Gharani',
#  'Ryan Nolan Data',
#  'WsCube Tech',
#  'codebasics',
#  'Ken Jee',
#  'Kaggle',
#  'Luke Barousse',
#  'DeepLearningAI',
#  'Dataquest',
#  'Keith Galli',
#  'Darshil Parmar',
#  'Rob Mulla',
#  'Andrej Karpathy',
#  'Tina Huang',
#  'sentdex',
#  'CampusX',
#  'Chandoo',
#  'freeCodeCamp.org',
#  'Socratica',
#  'Kevin Stratvert',
#  'Tableau Tim',
#  'Thu Vu data analytics',
#  'Guy in a Cube',
#  'Krish Naik',
#  'techTFQ',
#  'ExcelIsFun',
#  'Alex The Analyst']

# %%
channel_data.dtypes
# Out:
# Channel_Name       object
# publishedAt        object
# channel_country    object
# Subscribers        object
# Views              object
# Total_videos       object
# Playlist_id        object
# dtype: object

# %%
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']=pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']=pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
# Out:
# Channel_Name       object
# publishedAt        object
# channel_country    object
# Subscribers         int64
# Views               int64
# Total_videos        int64
# Playlist_id        object
# dtype: object

# %% [markdown]
# ## function to get videos ids

# %%
playlist_id2 = channel_data['Playlist_id'].tolist()

# %%
playlist_id2
# Out:
# ['UU3rY5HOgbBvGmq7RnDfwF7A',
#  'UUtYLUTtgS3k1Fg4y5tAhLbw',
#  'UUHXa4OpASJEwrHrLeIzw7Yg',
#  'UUJtUOos_MwJa_Ewii-R3cJA',
#  'UUKq-lHnyradGRmFClX_ACMw',
#  'UU0T6MVd3wQDB5ICAe45OxaQ',
#  'UUh9nVJoWXmFb7sLApWGcLPQ',
#  'UUiT9RITQ9PW6BhXK0y2jaeg',
#  'UUSNeZleDn9c74yQc-EKnVTA',
#  'UULLw7jmFsvfIVaUFsLs8mlQ',
#  'UUcIXc5mJsHVYTZR1maL5l9w',
#  'UU_lePY0Lm0E2-_IkYUWpI5A',
#  'UUq6XkhO5SZ66N04IcPbqNcw',
#  'UUChmJrVa8kDg05JfCmxpLRw',
#  'UUxladMszXan-jfgzyeIMyvw',
#  'UUXUPKJO5MZQN11PqgIvyuvQ',
#  'UU2UXDak6o7rBm23k3Vv5dww',
#  'UUfzlCWGWYyIQ0aLC5w48gBQ',
#  'UUCWi3hpnq_Pe03nGxuS7isg',
#  'UU8uU_wruBMHeeRma49dtZKA',
#  'UU8butISFwT-Wl7EV0hUK0BQ',
#  'UUW6TXMZ5Pq6yL6_k5NZ2e0Q',
#  'UUfJT_eYDTmDE-ovKaxVE1ig',
#  'UU7HYxRWmaNlJux-X7rNLZyw',
#  'UUJQJAI7IjbLcpsjWdSzYz0Q',
#  'UUFp1vaKzpfvoGai0vE5VJ0w',
#  'UUNU_lfiiWBdtULKOw6X0Dig',
#  'UUnz-ZXXER4jOvuED5trXfEA',
#  'UUkndrGoNpUDV-uia6a9jwVg',
#  'UU7cs8q-gJRlGwj4A8OmCmXg']

# %%
def get_video_ids(youtube, playlist_ids):
    all_video_ids = []
    
    for playlist_id in playlist_ids:
        video_ids = []
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50)
        response = request.execute()
        
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        more_pages = True

        while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)
                response = request.execute()
                for item in response['items']:
                    video_ids.append(item['contentDetails']['videoId'])
                next_page_token = response.get('nextPageToken')
        
        all_video_ids.extend(video_ids)
    
    return all_video_ids

# %%
video_ids=get_video_ids(youtube,playlist_id2)

# %%
video_ids
# Out:
# ['8XoDVwWdaqI',
#  'mJf_vJK6STY',
#  '_ibqqJY8EEM',
#  '3iLLBXGblqk',
#  'e6TwZg0QXYw',
#  'rWBvRFwq4as',
#  'T0geCaVBXXE',
#  'TM4O9x8kBvg',
#  'gn7qLNR-wkg',
#  'xipnW2w5EfE',
#  'aGGJLDgIrD8',
#  'viKPhMIw7Fc',
#  'Rp3EcF9nx6U',
#  'fZn83JRt4Nk',
#  'FP0rOvPwMdQ',
#  'uy_q3bg_52k',
#  'ussgXhJ-cp0',
#  'KgCgpCIOkIs',
#  '5JFrzN6r1KI',
#  'j4xlVLgsmNQ',
#  'AZzTHWF7tEc',
#  '6cV3OwFrOkk',
#  'p9vjhj7_A4o',
#  'gTK5rNhWJyA',
#  'ZAcdjEjrkNI',
#  'iuIpiVY-HN8',
#  'VFIuIjswMKM',
#  '8Dh3FbjWF1o',
#  'I4vHFR0AZZE',
#  'AyMBPxxQRtA',
#  'OX-iyb-21tk',
#  'fSJpU9xwdCM',
#  'ZBCAR5Rs7wk',
#  'kTYQqxYILOQ',
#  'hMaWsrSRhFE',
#  'On9eSN3F8w0',
#  'SbOXK7Rre-E',
#  'WHBH0yz35_8',
#  '2MgUGNMY-8E',
#  'bdfMRFxaIQU',
#  'n_0kijUi7IA',
#  'S1do1EeA7ng',
#  '9gHIiuyySws',
#  '5O2OuN1ougU',
#  'V3xjmBi1QQE',
#  'H6988OpZKTU',
#  'kwGh6XvLrEk',
#  'SvJLXj05cow',
#  '9NfthspfXEo',
#  '55_UN5gVARs',
#  'rfWYbMd3ApA',
#  'eiLqDeDp7Oc',
#  'jxzXwe_KMXE',
#  'c_InIhw-VVc',
#  '4YAAgrm8_ZI',
#  'MFe05GIH3x8',
#  'v-2cIUgx_jw',
#  'E-Qn2tbcmDE',
#  'HmH-76_2Ak8',
#  'yH1zCq-iaeU',
#  'b-OzqmNTS7U',
#  'ZFZc8-PugcA',
#  'HjSbGw-Rm4E',
#  'lVoQnV3rUmU',
#  'DX0V7D0GWwI',
#  'qvKspeuyBfQ',
#  'lCoPTPsTJ4s',
#  'mGu1CzsVUPc',
#  'B5lMVJoaQnA',
#  'VB376MMEq38',
#  '9XmD2o5Slb8',
#  'GZnAtwUBo8g',
#  'JJdD_oM1CmQ',
#  'TiWGpLmYJD4',
#  'Ih0YFsk7BSw',
#  'GQenH76iAxs',
#  'ezCbHuTii38',
#  'opy2P3Twb1E',
#  'WSFZYc6hnnk',
#  'qEGuQQnHofs',
#  'ysRmlBK8GgQ',
#  'r-Ob4fghRnA',
#  'KFBsLkFFpg4',
#  'cbWRbvnlezM',
#  'PmZKUifl2fw',
#  'T-IrTR2myxI',
#  '1VL3ZZrS1RY',
#  'EjOznXqN8Hg',
#  'm8fvdRZb5CE',
#  'QhWZq8oBpVw',
#  'JV0S5f89-Q4',
#  'UC5jflMmubs',
#  'Oekl7K1iwxY',
#  'iujLN48gumk',
#  's-8kQT-YVJg',
#  'KphmOJnLAdI',
#  'l2hro8DemsM',
#  'fx0GGAANIus',
#  'lA2baUE00uY',
#  'QdXF69-EGEI',
#  'ZTt9gsGcdDo',
#  'Qf06XDYXCXI',
#  'rC9vw2dSpQo',
#  'Ka04Dj7DxGk',
#  'bQ5BoolX9Ag',
#  'zxQyTK8quyY',
#  '8ZcccMzTz7Y',
#  'YaQEUgIr4Mk',
#  'PSs6nxngL6k',
#  '953NHzFtGHc',
#  '02zO75hHpZQ',
#  'L8HKweZIOmg',
#  'y8xRw76i1qY',
#  'LS6VX7noVWY',
#  'ZYDN25N5WhQ',
#  'ccjrsxXmfnw',
#  'bv9agba7blc',
#  'oZ9SrkF_-LE',
#  'A88rDEf-pfk',
#  'qioNUZGVH1A',
#  'P4aYC1kS4d0',
#  'viZrOnJclY0',
#  'yOJmPkyyZ18',
#  '3Bg2XRFOTzg',
#  'KXOTSkPL2X4',
#  'tc4LGTVRXV8',
#  '589nCGeWG1w',
#  '5GqtRXY-80k',
#  'eJIp_mgVLwE',
#  'e9U0QAFbfLI',
#  'RHGiXPuo_pI',
#  '1xBB8iAXxds',
#  'k3b9Mvtt6lU',
#  'KiGsuKqaq0Y',
#  'LoocDAbgwlM',
#  'R7xd624pR1A',
#  'mno47Jn4gaU',
#  'EkAQAi3a4js',
#  'wsi0jg_gH28',
#  '7ArmBVF2dCs',
#  'bMccdk8EdGo',
#  'YCzL96nL7j0',
#  'c3xEDTh7Uc8',
#  'zxagGtF9MeU',
#  'K8ykIS1x_qQ',
#  'EzjtTh-WUWY',
#  'Za9wm6HWkvo',
#  'BgxBEKhaqyQ',
#  'khMzi6xPbuM',
#  'CHOir6-ZpkE',
#  'AsNTP8Kwu80',
#  '80-Wpwf1_dg',
#  'FHdlXe1bSe4',
#  'W4sYsXGeCls',
#  'aH3mZjHkAbs',
#  'jth4kEvJ3P8',
#  'eN0wFzBA4Sc',
#  'L35fFDpwIM4',
#  'PWvfrTgaPBI',
#  'wtLQUjfomig',
#  '-14BImgVENA',
#  'RDZUdRSDOok',
#  '6fWk_lQ_K5A',
#  'YtebGVx-Fxw',
#  '9wCnvr7Xw4E',
#  '_IgyaD7vOOA',
#  'N4ZQQqyIf6k',
#  'Xz0x-8-cgaQ',
#  'aOOaGLa8s4c',
#  'OSPr6G6Ka-U',
#  'ilUbD7EoQnk',
#  'crLXJG-EAhk',
#  '_L39rN6gz7Y',
#  'Llqoz1u8Pfk',
#  'KLs_7b7SKi4',
#  'HGwBXDKFk9I',
#  'xBEh66V9gZo',
#  '6ArSys5qHAU',
#  'M59JElEPgIg',
#  'KpKog-L9veg',
#  '83LYR-1IcjA',
#  '0nK6iPpqNPU',
#  '68BZ5f7P94E',
#  'GKZoOHXGcLo',
#  'iyn2zdALii8',
#  'IN2XmBhILt4',
#  'SEwxvjfxxmE',
#  'CqOfi41LfDw',
#  'GrJP9FLV3FE',
#  'Y5tyrAxhmUc',
#  'wl1myxrtQHQ',
#  '0oc49DyA3hU',
#  '5koKb5B_YWo',
#  '8A7L0GsBiLQ',
#  'isEcgoCmlO0',
#  'q90UDEgYqeI',
#  'H3EjCKtlVog',
#  'O2L2Uv9pdDA',
#  'hGoTUyBnbxg',
#  'Xm2C_gTAl8c',
#  'ONCOkccpk3w',
#  'iiN_J9S0KLM',
#  'Rsc5znwR5FA',
#  'VX_M3tIyiYk',
#  'HDCOUXE3HMM',
#  'fU2PuYKsr6M',
#  'uHK1-Q8cKAw',
#  'i4iUvjsGCMc',
#  'JQc3yx0-Q9E',
#  'vemZtEM63GY',
#  'bTs-QA2oJSE',
#  '8ECts3BErqk',
#  'oRrKeUCEbq8',
#  'iTxzRVLoTQ0',
#  'ZVFeW798-2I',
#  'BKnM0MCGbVc',
#  'pSWRT9pObX0',
#  'sQ870aTKqiM',
#  '8b1JEDvenQU',
#  'jaXexgj2ONQ',
#  'OtD8wVaFm6E',
#  'vP06aMoz4v8',
#  'D0efHEJsfHo',
#  'Qc5IyLW_hns',
#  'Toet3EiSFcM',
#  'efR1C6CvhmE',
#  'g9c66TUylZ4',
#  'xZ_z8KWkhXE',
#  'qtaqvPAeEJY',
#  'SzZ6GpcfoQY',
#  'sHRBg6BhKjI',
#  '4jRBRDbJemM',
#  'vikkiwjQqfU',
#  'vMh0zPT0tLI',
#  'StWY5QWMXCw',
#  'jxuNLH5dXCs',
#  'HUzQIZLQxA0',
#  '2xudPOBz-vs',
#  '3CC4N4z3GJc',
#  'xOOrxD92Wt4',
#  'sDv4f4s2SB8',
#  'Dr2aj85tcUI',
#  'LsK-xG1cLYA',
#  'CqLGvwi-5Pc',
#  'F7Gqjbg3bWI',
#  'qcvAqAH60Yw',
#  'Rvm1aMwcraY',
#  'Gv9_4yMHFhI',
#  'hRdBqO4FFDs',
#  'Kdsp6soqA7o',
#  'ctmNq7FgbvI',
#  '1dKRdX9bfIo',
#  'NGf0voTMlcs',
#  'G9POY1cHn50',
#  'Q81RR3yKn30',
#  'EuBBz3bI-aA',
#  'Dn6b9fCIUpM',
#  'YAlJCEDH2uY',
#  'OxA6i3iJd7M',
#  '4KKV9yZCoM4',
#  'J8jNoF-K8E8',
#  'tjLaxniTPmE',
#  'p3T-_LMrvBc',
#  'C4N3_XJJ-jU',
#  'JC56jS2gVUE',
#  '9T0wlKdew6I',
#  'EH4-RtVpsy4',
#  '8nm0G-1uJzA',
#  'xxFYro8QuXA',
#  'BfKanl1aSG0',
#  'vN5cNN2-HWE',
#  'Glr8Qk3OZHc',
#  '4b5d3muPQmA',
#  'ARfXDSkQf1Y',
#  '069WKnPyFnw',
#  'fSytzGwwBVw',
#  'nkWGmaYRues',
#  '_ft2yqArm-I',
#  'oRvgq966yZg',
#  'FgakZw6K1QQ',
#  'kLQD8EJmnx8',
#  'pYxNSUDSFH4',
#  'yIYKR4sgzI8',
#  'nuumjAsHTxk',
#  '6EXPYzbfLCE',
#  'J4Wdy0Wc_xQ',
#  'lrR9odYNNzs',
#  'wpNl-JwwplA',
#  'Lsue2gEM9D0',
#  'kGIIJ8rIrfs',
#  'pGAUHhLYp5Q',
#  'GEn-_dAyYME',
#  'HMOI_lkzW08',
#  'adx4fsdwpfM',
#  '0Jp4gsfOLMs',
#  'ecjN6Xpv6SE',
#  'okjYjClSjOg',
#  'IFKQLDmRK0Y',
#  'Lg0okx38rOQ',
#  'hokALdIst8k',
#  'zITIFTsivN8',
#  '67zCIqdeXpo',
#  'Exk0OoRG0PQ',
#  'rzFX5NWojp0',
#  'Hrr2anyK_5s',
#  'Odt_r4cAD8A',
#  'qBigTkBLU6g',
#  'NEaUSP4YerM',
#  'arSkMA2uLFU',
#  'tlf6wYJrwKY',
#  '01205ys-GtI',
#  'NF5_btOaCig',
#  'UY8iYbxuzjc',
#  'XepXtl9YKwc',
#  'u1cc1r_Y7M0',
#  'nk2CQITm_eo',
#  'yQhTtdq_y9M',
#  'fHLhBnmwUM0',
#  'FKM7hZKYEqw',
#  'HVXime0nQeI',
#  '7xHsRkOdVwo',
#  'Vf7oJ6z2LCc',
#  'BXeZgqXAKAU',
#  'PaFPbb66DxQ',
#  'Gi0JdrxRq5s',
#  'XLCWeSVzHUU',
#  'TGvLteZCdAc',
#  'bsZGt-caXO4',
#  'oI3hZJqXJuc',
#  'Wdt6jdi-NQo',
#  'Mgm-T-dILAQ',
#  'UFB993xufUU',
#  'A82brFpdr9g',
#  'udyAvvaMjfM',
#  'nnBJeb_I-q8',
#  'aVvTVYi5vBk',
#  'RiEZ_hEf96A',
#  'VSi0Z04fWj0',
#  'KEofcJ1tfkI',
#  'zXEvFLj2880',
#  'K8LQSvtjcEo',
#  'MIgCbrNJyGo',
#  '68e5i5D8qYU',
#  'DyaQp6Cz8RA',
#  'UFhJefdVCjE',
#  'Rblav_ehMTE',
#  'G-9USywzN3E',
#  'R6ALolnItXg',
#  'azXCzI57Yfc',
#  'xXqa7sVypYI',
#  'cKdUdPAVyOU',
#  '-tibALm6VEI',
#  'WkjBXrX1Q2k',
#  'oMtDyOn2TCc',
#  'K2QWmW6LKmg',
#  'TCrC8Vdv1_4',
#  'gKnfP2_Xdpo',
#  '_UVHneBUBW0',
#  'TTUrtCY2k-w',
#  'TqOeMYtOc1w',
#  'O33LgXNk87g',
#  'zB7CCWQbkWs',
#  'XNgt7F6FqDU',
#  'fglJIFv08hs',
#  '2AQKmw14mHM',
#  'Sn-keVh_ERw',
#  'yMYcH8-OfJk',
#  'iy9Z4DyHxvE',
#  '2IGbkWm0cNo',
#  'voHTS9Nk5VY',
#  'c9OjEThuJjY',
#  'giO92FBk33c',
#  'SedGB8m2XLM',
#  'kcfA3J3PNmc',
#  'XviSeTiE1ls',
#  'HJl50-GHQr8',
#  'hMJgdVJWQRU',
#  '5JpPo-NOq9s',
#  'u8vQyTzNGVY',
#  'MlK6SIjcjE8',
#  'M-2Cj_2fzWI',
#  '55nZ8rU9lM0',
#  'ZGPl3YR0U9E',
#  'pekEMLmYx34',
#  'RF53NPPhBmE',
#  'ZkFKF-ohsKk',
#  'FMPYShYLg3o',
#  'VUoM7p_Fb1k',
#  '3nN8ntjJPpw',
#  'of4hjw_Vm5Y',
#  'pkJtIAsJIxU',
#  'Xy-kOqWvmKE',
#  'F4WEGvFAwv8',
#  'HBQOj_ebQX8',
#  'FmS3iPmkRXM',
#  'xMERaoPsz1E',
#  '6D4ezSYEYR8',
#  'uKyojQjbx4c',
#  '7uKKOV7NUvw',
#  'po5qTPKBrRc',
#  'TotbC33Djr0',
#  '0MtRHcI8mlk',
#  'vPoglMjsBeo',
#  '_AVBG6pgPhs',
#  'vdRp_w9f-qM',
#  'c_WbKfyt8pY',
#  'SgoVJq18YSI',
#  'zPWxavBy1X0',
#  '3l16wCsDglU',
#  'xTKoyfCQiiU',
#  'aMldpZF6GBU',
#  'hEyeVD_kKLQ',
#  'bgqfxCVDU4Q',
#  'XtJuPgqvHmU',
#  'msGOrJIMGy8',
#  'ppabEHhrh70',
#  'GeLz1LSImyk',
#  'HoMZxHNpM84',
#  '7xc0Fs3fpCg',
#  'Ebb4gUI2IpQ',
#  'SHJlKPw3xBE',
#  'BQur2S8kKVg',
#  'xcgb9ChrRCo',
#  'zaBy3X37Oa8',
#  'IMzZ0UqENTg',
#  'PGsAsuwBdw0',
#  'yrHVsfWlF1E',
#  'EmR0gg4Ish8',
#  'i3bisLX-dCc',
#  'QQJ3kvNEAnk',
#  'mozBidd58VQ',
#  '8Ji-SAGMXXI',
#  '-_CaP2aNAnQ',
#  '8RT8RfRwPvs',
#  'xs9gUA0aDgI',
#  'Souzjv6WfrY',
#  '2O3dzzrhpRw',
#  '6-lwJlo2jYE',
#  'LHWFu___jgw',
#  'YyYPHyo-OQY',
#  'CY-ZvLBRaQE',
#  'C82lT9cWQiA',
#  'fq8jUu4t7ps',
#  'dRP4ZhFH3_I',
#  'BIXR7GioPQk',
#  'Z3kKk6K8zxU',
#  'N_O0fUwUHKQ',
#  'MsBP-OV0JmM',
#  'Eafs_H_u7_o',
#  'rzTtHKbW81Y',
#  '7IuFN6sbbmM',
#  'aGMsvXz8CYY',
#  'P-rzgaIfZCo',
#  'FXiLOfout3Y',
#  '2_7vRKawvEU',
#  'srxNPCw_UO4',
#  'mqG5K9YjjhA',
#  'G6i7Xy2MeFA',
#  'pkFqpOwBbPs',
#  'P0_gjv3j9YQ',
#  'ioKLYek3UZE',
#  'FewiMdJlR5s',
#  'M-xZE8ac7vY',
#  '59v0iAX_PPw',
#  '1TYxba_YT4o',
#  'ufXg-uH--dA',
#  'aZ37SBeFaG4',
#  'SPf81FEoihM',
#  'b-jR2dUFnCg',
#  'ymF9xq7xIug',
#  '6rFXsG0tUMI',
#  'qVD1NBLoOJw',
#  'vETCCrUQ_Q4',
#  'R_Reegsk7Ps',
#  'dWmJ5CXSKdw',
#  '232dwr1-R6o',
#  '-MX5C_e5Ytk',
#  '0sgjH5NWbNw',
#  'IxHQHJjtqPw',
#  'Aso895pvii0',
#  'GH1RuKguO54',
#  'vahwuupy81A',
#  'ilrHB5tD15g',
#  'AALBGpLbj6Q',
#  'TW5WuaSyKjY',
#  'Zanrd7IzZLM',
#  'kKZFmklDSXs',
#  'qpFrg4gN4Mg',
#  'N_W4EYtsa10',
#  'ZUqB-luawZg',
#  'jztwpsIzEGc',
#  '19LQRx78QVU',
#  'ZLIPkmmDJAc',
#  'bNi8RMQ-g6A',
#  'IHLwjiBmf-g',
#  '0iZdzWG1-NY',
#  '67hqsP7fhvQ',
#  '0efnQCHbsyE',
#  'AOmuGsiomrs',
#  'rzbFhu6So5U',
#  'G1uGSkANZjQ',
#  '2VP9nOWiJ04',
#  'eBCU-tqLGfQ',
#  '2eeYqJ0uBKE',
#  '6cXV8dhNu50',
#  'E6B3uWF-V7w',
#  'H7cGq0xIHbc',
#  'FygLqV15TxQ',
#  'mEzBnhJPUjc',
#  'ZlUj2WQ7_GE',
#  'LKispFFQ5GU',
#  '43eAC1LMrsU',
#  '6yA5S9B2Z60',
#  'M6jukmppMqU',
#  'FfywuRCPmqY',
#  'FNHLVRJ1HU4',
#  'W1pw_ojO7XE',
#  '2UXWNsOPN30',
#  'Z3Bafw9DO7o',
#  'tHJyTBaGLDY',
#  'sQpPaW17TwU',
#  'PwR_OVrv0F0',
#  'QBxQxYvdNek',
#  'sw3o0rAazMg',
#  'UMjW4Db4E_g',
#  'bK_k7eebGgc',
#  'RcJLSRx3DRQ',
#  'KC7nJtBHBqg',
#  'k_WJn40u-4U',
#  'Yo5Hw8aV3vY',
#  'hYGyHpmPghM',
#  't5xwQguk9XU',
#  '3uhP6xDfx3o',
#  'yGN28LY5VuA',
#  'sOR4K9CS0TI',
#  'p1mSVgmSOAQ',
#  'MXZ3FRCLhBs',
#  'boEUcROx1N8',
#  'RjNthMx9Ohc',
#  'ec6AtCMtqcA',
#  'Cg-yCDAT4r0',
#  'gr8BNtbsxlM',
#  'jq5QfwDkBGs',
#  'JuG6ZcNe_3Q',
#  'feA-H6blwr4',
#  'tFNJGim3FXw',
#  'SSW9LzOJSus',
#  'sL-4rWuEiVw',
#  '4htP-hmIBvc',
#  'doDUihpj6ro',
#  'wJsUY7IxsvU',
#  '4aqx5P2Y38U',
#  'Mut_u40Sqz4',
#  'szczpgOEdXs',
#  'xSElsMUqFqI',
#  'i_-ud01wFhc',
#  'cCmGg_Pn9K8',
#  '0tB6jG55mig',
#  'Wh77ZGdIaZQ',
#  '0-4p_QgrdbE',
#  '6MI0f6YjJIk',
#  'EgjwKM3KzGU',
#  'vQZ4IvB07ec',
#  'We1uB79Ci-w',
#  '06TE_U21FK4',
#  'yqkISICHH-U',
#  'pG4sUNDOZFg',
#  'YCyuZM454_I',
#  'YbKnsJQKazA',
#  'V0Pk_dPU2lY',
#  'q-Uw9gC3D4o',
#  'D9sU1hLT0QY',
#  'nRHjymV2PX8',
#  'oLpBGtY-_sI',
#  '-HbCA0WGbBg',
#  'aJQAeMswAvg',
#  'cHymMt1SQn8',
#  'JctmnczWg0U',
#  '5bnBE950SHQ',
#  'wzWcaLkCy1w',
#  'UPS54i7Km30',
#  'IO1tjm9gcIs',
#  'pvPc7tQkVA8',
#  'TsfLm5iiYb4',
#  'Bpaa560qN9U',
#  'mgX0Iz4q0bE',
#  'bD6V3rcr_54',
#  'bFeltWvzZpQ',
#  'zO1IG8FHSFU',
#  'sNNFEKZhOlA',
#  'hCeJeq8U0lo',
#  '6_2hzRopPbQ',
#  'tUHl5TiP_oA',
#  'KvLG1uTC-KU',
#  'NApYP_5wlKY',
#  'WajtPtLAg-o',
#  'dZh_ps8gKgs',
#  '2dwSXXMFhPY',
#  'B5emClQf_I4',
#  'ZTSRZt04JkY',
#  'uTdUUpfA83s',
#  'ZVKaWPW9oQY',
#  'pDXdlXlaCco',
#  'IOI0o3Cxv9Q',
#  '02ChRbyYQWg',
#  'bVCrzoIVudU',
#  'ERWZhMZuJfs',
#  'WewKL2wSaxs',
#  '9MTiQMxTXPE',
#  'sylpzyltetE',
#  '_EgqxIoUE7U',
#  'KAaXbGr9o0s',
#  'f7uBsb-0sGQ',
#  'ZUsaIOTJvM4',
#  '7lXYGDVHUNw',
#  'zUvnUQeBLb8',
#  'LPhrWzlM_8w',
#  'FM6kHcXpw98',
#  'PyxsziqatFE',
#  'uRsE5WGiKWo',
#  'cO5g5qLrLSo',
#  'u7WXnFvX0d4',
#  '_jLRKUuBUtY',
#  'tRKeLrwfUgU',
#  '8k8S5ruFAUs',
#  'T9KfYaS9hwQ',
#  'A9_0OgW1LZU',
#  'Ee0kLCMhqeM',
#  'Oi1FyKbivdg',
#  '2b_xDzrBv6c',
#  '_2gHffpM9Q8',
#  'LglAar_m5ZY',
#  'FFM8YUKzT8o',
#  'rr-KwIjinpM',
#  'EzhzJyu77y8',
#  'x-VQ0Nr-Pg0',
#  'Qg8DwCzXg24',
#  'ufYtueq2DCw',
#  'KE33E_Ilta4',
#  'iPUWwpocc1c',
#  '6iHFdS_PQjc',
#  'pCuV_7H2vyQ',
#  'TsK289LVlrY',
#  '-rejmmjSnHM',
#  'D_doogJln14',
#  's6cw6R5hu5c',
#  'xof1OgxcRhY',
#  'CeId265HGnM',
#  'nxRRf0ebPxU',
#  'AHc5ylZaiLY',
#  '3jJcS7owO1U',
#  'KewKapgrmrQ',
#  'hEo_la9bT6Y',
#  'py8QwrIUynE',
#  '8StpGqv6_n0',
#  'dWWlG5LPL6Y',
#  'iwX7pOgUHzs',
#  '52m8ozsv068',
#  'wH3VPyb-LCE',
#  'TkLMgTLuEKk',
#  '3xukwXLDbbE',
#  'Do5tCydKv8E',
#  'ivhTe_b2aus',
#  '5ndLJp_pb2Q',
#  '9gjKx9Z9E9Y',
#  '0j3l5GciFIo',
#  'BpDXGB-U7VE',
#  'UmNplE591rc',
#  'GFSelpjYc4g',
#  'KDI-dr1vyi4',
#  'JjuCGJyZacE',
#  'PPq79Q51Ya4',
#  'oKDkwZkzX48',
#  'FgZsV09npbs',
#  'z16aNdvgAog',
#  'UCO80F8_uOs',
#  'YFnXV2be9eg',
#  'TDphx23AtqM',
#  '-Pi68IkutaQ',
#  'wP8NWRR0Fdg',
#  'vqMhTJzAz2Y',
#  'UaCGZIlvoRg',
#  '1xF3xTqJjdA',
#  'jaVuY06T3JI',
#  'x00RGkAnBPg',
#  'mCJzhCxEQlM',
#  'QWL15bYXwvs',
#  'klfm3dBmTgY',
#  'EOhSODFLqic',
#  'eQHXxbveZHc',
#  'lHk6MdGAfw8',
#  'GqDSPny1Z7s',
#  'DNl9DzNwjv8',
#  'rpJss_pIn24',
#  'hBJgHQuhvmA',
#  '9uIxy9auP_o',
#  'j-7XcKqhEM0',
#  'uFfAqxoSEUs',
#  'M3MAs4_nahI',
#  '_ZLXuP2CoVg',
#  'bO-us8IX3Wo',
#  'fQf2EqDZPsQ',
#  'YZeDjy5NBgo',
#  'wBAnCMA98ls',
#  '2hLLS9TSoHY',
#  '1XKPg9gNUBM',
#  'kIWRKdapx08',
#  'WabLAFrnWyQ',
#  'cwuK4xKEQpk',
#  'FbBXtqtRnWU',
#  'QKjV_GdkTTw',
#  'K-FyqwKsIME',
#  '-5fFhMSgTHI',
#  'UnU81ITTsHU',
#  'k-9Dks8FTjo',
#  'zjiVqlVTq_8',
#  'WNrB1Q9Rry0',
#  'eaO7Nyd_4JM',
#  '-BiZjkqgaHc',
#  '0au3hhcYSjM',
#  '8hjgmJk5RiA',
#  'tRkbN2gWZEk',
#  'yxHPScN_ct4',
#  'dfhEnQ02L58',
#  'VVShslDBg5c',
#  'i2GZiH6IgqI',
#  'z66-6WVZSFY',
#  '5TVwC24eHHI',
#  'ZZRl7fALdjw',
#  'vITAMgh1buo',
#  'Atv_RTv9RWk',
#  'oiydMj12tv4',
#  '5hD5xqokDeQ',
#  'Io1hT57lJZs',
#  'nLtfDT-RBgE',
#  'BCZEqmejEmo',
#  '1mHAVptUKAk',
#  'X6ypwd7bhTU',
#  'V0E_Hrn-iJU',
#  '-7oNBm7SL8I',
#  'Y7PoYlZUMgo',
#  'tGMw6pc1rBs',
#  's96amWpVizg',
#  'I83ETxjjOt8',
#  'rvtuQo_8wTA',
#  'YYTLza7FIiU',
#  'Ft5kDiKLN20',
#  'rtV84alhUJQ',
#  'Y9HF39yAjjw',
#  'O20bjXIXQKI',
#  'hgJyF6LMSDA',
#  'vAAE5_QHB3w',
#  'ZEwb3zobLUs',
#  'D1kryglyzNc',
#  'x6a7jdQtEvQ',
#  'AXNPR5q1y08',
#  'P61TvKFLFvo',
#  'Gk7GNXplymw',
#  'kQPUWryXwag',
#  '_jWHD0CK9hY',
#  'fqSdajbg-U4',
#  'EpUWWH1CpQ0',
#  'MXRq-mJxTL8',
#  'n4oIcHcZnhs',
#  'O2L_acVRlxc',
#  '21bXQDXSxYs',
#  's9H16DqXuJk',
#  'ehrXyFPljBo',
#  '2D4E5k0hAeA',
#  'dCTW7JBpkjw',
#  'NFQq_5y2wX4',
#  'Lf-hVpAbIx4',
#  'BlwT4JhvGc0',
#  'kQ-yUKE_KHE',
#  '2BFIHm7QEqA',
#  'ZlyxesiiC6U',
#  'P1kSKfaPTic',
#  '4VuO1lO6USo',
#  '5ZGTWB5fBLI',
#  'xU_PRHTydmg',
#  'BbplhqDCWOM',
#  '7ZMQZ0UUuTs',
#  '5N-AKOG67sA',
#  'GpP0EbSMRpg',
#  'GdrH8UyrhP8',
#  'vpUt0gx8izI',
#  'RwzuckV1eT8',
#  'p92Ta3J5vGU',
#  'Xl09asNegcA',
#  'qNmBaUptrGM',
#  '5kOXKpq9Kao',
#  'b4NfgeDydyM',
#  'Fmqi5d87UJQ',
#  'kf1i7cK37SQ',
#  '05h3ABKHDQc',
#  'qD-nCRjmXxg',
#  'tp9OXKcn7sA',
#  'YKQ8xWZPnCM',
#  '4IkUfh05TGE',
#  'SJghXfhY69Y',
#  'jLHqGRpGOPk',
#  'rEOGFqkcPEc',
#  'ssbBaYLq8Mg',
#  'jgXF_6sXRDc',
#  'djf3tBIYmCw',
#  'vR7078CJ4hs',
#  '68yBb7a1uGU',
#  'HRDbTCX1qHk',
#  '0QHlDmX4Mc4',
#  'BLuhWVN_Z2U',
#  'yridBTXFme8',
#  'dVxZOzzrVdg',
#  'murtekAkJDs',
#  'ZmTfByhH6T8',
#  'a83EmWtZMfg',
#  'eOl-z5PSN9o',
#  'L4vzdKldwws',
#  'NtFOhvWPlIE',
#  'JZewxiKFplk',
#  'ojKnMnQtJO4',
#  '9XiszzUJRos',
#  'oUPlFxZs4Uc',
#  'dGwsAZWLvi8',
#  '5dCNmktBoPw',
#  'cC7YcemMDsw',
#  'sVrtkxjfDkc',
#  'umjO2jlBTeQ',
#  'qNz35j5ZevQ',
#  'eTHtfDQmWvQ',
#  'q_NXctql0wM',
#  '2X07EC5B4Hc',
#  'fJZi3ueyF54',
#  'AfCgr6S6b00',
#  '_eAm7CvXIyU',
#  '_9QFKGfCZ5Q',
#  'w_KVNMmizVk',
#  'E4FhwawB1G4',
#  '8ibe27Zuf0A',
#  'eyXfxPu1vcU',
#  'wOq1ay2hcEY',
#  'Wk7YaaoypWQ',
#  'gAGIVfL-i8Q',
#  'BdT6kz07qp0',
#  'xcVLWyEJHwY',
#  'HtaDzQwEVEQ',
#  'cuByjxckpy0',
#  'ml6oDaFUiBI',
#  'VWcLM6_Q_00',
#  'brUZ40qiMxM',
#  'zFDp916fG-I',
#  '8CvBidkd_yw',
#  '_jh7snqA4e4',
#  'P-OxvDje0tM',
#  'R7RRT5aelM0',
#  'WY_y0apzeGs',
#  'sFn0gE_y1U4',
#  'FJJR9vBAyeM',
#  'DgBZiBIgh3w',
#  '_vzgYY1QU58',
#  'mYpOSfqgTvY',
#  'RmUPrNr4QKk',
#  '3Qh5nUmCVd8',
#  'edOGoq-1r0o',
#  'cnCvn6CmP2k',
#  'TPQpcTJrnTw',
#  'uxdp5Z2I0mg',
#  'SjoCzOQTgtc',
#  'Kx3H8BolgaI',
#  'xZPlhccYqG4',
#  '3Wkagedga1U',
#  'sPehgaw9OS0',
#  'WjtuWcZnUF8',
#  'mZlsJeB2w4Q',
#  'c7LrqSxjJQQ',
#  'XmlHn2R-kbQ',
#  '40xO1MD_CCs',
#  'xptrrHabuS8',
#  'mr8l6tCI6Lk',
#  'Mq1VAk9ikwg',
#  'xxtONTBrvNE',
#  '8TVuNSlULVk',
#  'Gf4HmkR7_FE',
#  'mWmlnC5369U',
#  'j22tLUQQDh4',
#  'Nedinxo3z1o',
#  'cxw_lP_aKIo',
#  'Rd9-sFfm-2k',
#  'U-5iQpz3C5I',
#  'P7x9ZRVB9ao',
#  'VoGcQdT5FqU',
#  'tXS9nVJ6tC8',
#  'pi10BjP9qlk',
#  'yq81QDuasUk',
#  '9HpAWDi2y_E',
#  'iXKg225HVKY',
#  '8sg2yGg6Q1g',
#  'SIJcGWXPrlw',
#  'YqaEJiwJj2I',
#  'qpBXZLAl9Uk',
#  '56ovZeblFMY',
#  '1CX8MQkf9-4',
#  'Q3YY1Ue9j-k',
#  'PsfsVqAPLQI',
#  'fMYni2J7oao',
#  'trG79GiqJ28',
#  '284_INtIFJE',
#  'yTr6HlaRQRw',
#  '3BnvDPQk9o0',
#  'ClYn9i-XueE',
#  'yOagJo1ICek',
#  'v-_joMcPpLI',
#  '5Xk2A9APETs',
#  'lsmIoRDCoSM',
#  'Wyoo9mQPxCY',
#  '4eB98eLui5E',
#  'KcCtSc0cpcs',
#  '8HakuTeijGI',
#  'zp8o4J3Bra8',
#  'Qux26Gs9gSw',
#  'ADArCWLz55Y',
#  'u6tFKwJf9o8',
#  'dYyxX4Zi9FM',
#  'Jj1iJSnXEG8',
#  'egL77by9On0',
#  'dfMW-BoBuB8',
#  'iNXqJ-n92U4',
#  'ATIVwXhTXHg',
#  'PDe88CBz32M',
#  'Yv7QBZXEDDc',
#  'UuPuBPFexvU',
#  'umF81NrOZfM',
#  'ZmQn5Jlj6jQ',
#  'Mo5-Bu1SHGQ',
#  '3ke435GQSIg',
#  'oSTgFUiRDGI',
#  'hisnhKK94nI',
#  'xtJjm8uzRdY',
#  '2x23vZIRYRs',
#  'cS86rQPdhSo',
#  '5Qmp1hFjw0k',
#  'xQWgif2y7Vc',
#  'fny4zUycp_w',
#  'fzX8upOEppw',
#  'DOvHqukAGTY',
#  'cdQFyYY6X0c',
#  'apBglZR9W60',
#  'NUAP_Who9so',
#  'HJ7bDi5ITi8',
#  '9xx59nsoIXw',
#  'ku0NM9jhp-A',
#  'v73TaVDWh4s',
#  'V3t8wxvbews',
#  '0XifMrBegS0',
#  'RAeYV84esqg',
#  '66ZqsLOHlVA',
#  'Rn_-XRTnX2s',
#  'nzH4KPz_cIs',
#  'ryELjDAiO3s',
#  'WRhOl3ELrf0',
#  'yHzT_BUggQk',
#  'SRqByQrTFCc',
#  '1WwhfB3Rs14',
#  'An-2Nxf_Dms',
#  '6qQ24RfRedc',
#  'AN-FMWKjVls',
#  'GDnyzIvqpEo',
#  'b-W64DHKO8o',
#  'RPRmTvQwmCQ',
#  'At6mrBp4Myg',
#  'YBi9PgbnfLQ',
#  'uUvp0XgE--s',
#  'XfUqravaLb8',
#  'ekuMzKOTmYE',
#  '6gC8css__ng',
#  'RwMP33N0Usw',
#  'z_-Zn5e7asQ',
#  'TjGbOoKvZ7M',
#  '9S5PY3Jugoo',
#  '1IMcdKokMBw',
#  'O0k9uE4xnD0',
#  'm_SH0TOLsIc',
#  'gvmR27x78FU',
#  '8kLsGIH2PNg',
#  'uTlg2-D6GG0',
#  'wKglApDFMog',
#  'SUsik0FGzI0',
#  'ZTHlJW97w9A',
#  'apLkSKszEPk',
#  'y1126PQ5zRU',
#  'LL-0shD9vq0',
#  'bYNW5wge5dE',
#  '5M2Kq_5V24A',
#  '0tdlR1rBwkM',
#  'L4j4oGbfRy4',
#  'OlZrogcjRGc',
#  'p9FtLTCyFi0',
#  'dQ9wMNvjfCA',
#  'nn0S9KPbN84',
#  'q6LOhQThvB8',
#  '0S5lPoXHX_c',
#  ...]

# %% [markdown]
# ## extrtact details of the videos

# %%
len(video_ids)
# Out:
# 23002

# %%
def get_videos_details(youtube,video_ids):
    all_video_stats=[]
    for i in range(0,len(video_ids),50):
        request=youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response=request.execute()

        for video in response['items']:
            video_stats=dict(Channel_Name=video['snippet']['channelTitle'],
                             Title=video['snippet']['title'],
                             Published_date=video['snippet']['publishedAt'],
                             Views=video['statistics'].get('viewCount', 'N/A'),
                             Like_count=video['statistics'].get('likeCount', 'N/A'),
                             Comment_Count=video['statistics'].get('commentCount', 'N/A')
                            )
            all_video_stats.append(video_stats)                                           
        

    return all_video_stats

# %%
video_details=get_videos_details(youtube,video_ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Rishabh Mishra',
#   'Title': 'POWER BI Full PROJECT for Data Analysis with Practical Guide | End to End Power BI Dashboard Project',
#   'Published_date': '2024-04-20T11:57:21Z',
#   'Views': '157284',
#   'Like_count': '5575',
#   'Comment_Count': '632'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'AI Revolution - Future of Data Analyst Jobs & Coding | AI Career Opportunities',
#   'Published_date': '2024-03-23T03:45:04Z',
#   'Views': '78155',
#   'Like_count': '2712',
#   'Comment_Count': '245'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Reality of Data Analyst Courses and Data Science Jobs - The Dark Side',
#   'Published_date': '2024-03-16T12:47:05Z',
#   'Views': '43627',
#   'Like_count': '1285',
#   'Comment_Count': '267'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Personal Portfolio Website for Beginners | How to create Personal Website',
#   'Published_date': '2024-01-21T04:00:02Z',
#   'Views': '129956',
#   'Like_count': '3462',
#   'Comment_Count': '358'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How To Create LinkedIn Profile in 2024 | LinkedIn Tutorial for Beginners',
#   'Published_date': '2024-01-17T13:41:48Z',
#   'Views': '143309',
#   'Like_count': '3389',
#   'Comment_Count': '192'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How To get Your FIRST Data Analyst Job With No Experience in 2024',
#   'Published_date': '2024-01-13T13:06:48Z',
#   'Views': '150444',
#   'Like_count': '5995',
#   'Comment_Count': '362'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Power BI DAX Tutorial | How to use DAX functions with Examples | Beginners | Power BI Tutorial',
#   'Published_date': '2023-11-04T04:15:02Z',
#   'Views': '136062',
#   'Like_count': '4443',
#   'Comment_Count': '312'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Top 5 Data Analytics Projects with Resources to Get a JOB | Projects for Beginners',
#   'Published_date': '2023-09-23T04:17:50Z',
#   'Views': '149378',
#   'Like_count': '6389',
#   'Comment_Count': '324'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Recursive CTE (Common Table Expression) | Advance SQL Tutorial in Hindi',
#   'Published_date': '2023-09-20T11:30:23Z',
#   'Views': '9071',
#   'Like_count': '271',
#   'Comment_Count': '53'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How to Learn SQL for Free - ZERO to HERO🚀 | Complete SQL Roadmap',
#   'Published_date': '2023-09-17T04:30:29Z',
#   'Views': '62081',
#   'Like_count': '3184',
#   'Comment_Count': '295'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Top 10 SQL interview Questions and Answers | SQL Interview Questions (Must Watch)',
#   'Published_date': '2023-07-09T07:05:22Z',
#   'Views': '151092',
#   'Like_count': '4707',
#   'Comment_Count': '521'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': '5 Effective Ways To Apply for Data Analyst Jobs 🚀',
#   'Published_date': '2023-07-04T13:38:36Z',
#   'Views': '61603',
#   'Like_count': '3914',
#   'Comment_Count': '58'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Recursive CTE | Recursive SQL Queries | SQL Tutorial in Hindi 17',
#   'Published_date': '2023-07-02T04:51:24Z',
#   'Views': '33038',
#   'Like_count': '694',
#   'Comment_Count': '98'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Power BI Dashboard | Power Bi Project - Sales Dashboard | Power Bi Tutorial for Beginners',
#   'Published_date': '2023-05-27T06:46:46Z',
#   'Views': '394120',
#   'Like_count': '11490',
#   'Comment_Count': '1042'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How to become a Business Analyst for FREE - ZERO Coding🔥| Complete Business Analyst Roadmap',
#   'Published_date': '2023-05-21T04:30:05Z',
#   'Views': '289719',
#   'Like_count': '14345',
#   'Comment_Count': '781'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Career insights Q&A - Data Analyst | Rishabh Mishra',
#   'Published_date': '2023-05-07T04:40:09Z',
#   'Views': '24129',
#   'Like_count': '1140',
#   'Comment_Count': '255'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How to upload project on github | Github Tutorial -  How to use Github',
#   'Published_date': '2023-05-06T05:12:34Z',
#   'Views': '396579',
#   'Like_count': '9005',
#   'Comment_Count': '499'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Python Project for Data Analysis- Exploratory Data Analysis | Data Analyst Project',
#   'Published_date': '2023-04-08T04:30:09Z',
#   'Views': '551313',
#   'Like_count': '16982',
#   'Comment_Count': '1022'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Solve SQL Interview Questions for Data Analyst - Product Based Company Job Interview',
#   'Published_date': '2023-04-01T04:30:01Z',
#   'Views': '88206',
#   'Like_count': '2278',
#   'Comment_Count': '143'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Power BI Project End to End | Dashboard | Beginners | Complete Project - 2023',
#   'Published_date': '2023-03-18T05:30:02Z',
#   'Views': '555020',
#   'Like_count': '13309',
#   'Comment_Count': '1341'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Top SQL interview Questions and Answers | Most Asked SQL Questions for Job interview',
#   'Published_date': '2023-03-05T09:11:01Z',
#   'Views': '312811',
#   'Like_count': '9671',
#   'Comment_Count': '334'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Power Bi tutorial for Beginners | Power BI Dashboard Project in Hindi | Power Bi Course 2023',
#   'Published_date': '2023-02-25T05:15:00Z',
#   'Views': '1741471',
#   'Like_count': '45414',
#   'Comment_Count': '3058'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Data Analyst Roadmap | How to Become a Data Analyst | Learn Data Analytics Skills for FREE',
#   'Published_date': '2023-02-12T05:06:30Z',
#   'Views': '929994',
#   'Like_count': '48464',
#   'Comment_Count': '2279'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Full Project in Excel with Interactive Dashboard | Excel Tutorial for Beginners',
#   'Published_date': '2023-02-04T05:00:18Z',
#   'Views': '727188',
#   'Like_count': '23027',
#   'Comment_Count': '1750'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Forecasting in Excel - Must Skill for Data Analyst | Excel Tutorial',
#   'Published_date': '2023-01-26T05:00:14Z',
#   'Views': '127892',
#   'Like_count': '5455',
#   'Comment_Count': '196'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Hardest and Easiest Part of Data Analyst Job 🔥 #shorts',
#   'Published_date': '2023-01-22T05:00:16Z',
#   'Views': '40156',
#   'Like_count': '2801',
#   'Comment_Count': '50'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Data Analyst Portfolio Project - Music Store Data Analysis Project using SQL',
#   'Published_date': '2023-01-21T06:04:01Z',
#   'Views': '499820',
#   'Like_count': '14346',
#   'Comment_Count': '1704'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': '3 Must Skills for Data Analyst in 2023 #shorts',
#   'Published_date': '2023-01-18T13:00:08Z',
#   'Views': '55389',
#   'Like_count': '4740',
#   'Comment_Count': '50'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Data Science interview With An Artificial intelligence (ChatGPT)',
#   'Published_date': '2023-01-01T08:45:00Z',
#   'Views': '5477',
#   'Like_count': '186',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How I Learned Python in 30 Days? Best Python Course',
#   'Published_date': '2022-12-31T05:30:01Z',
#   'Views': '171997',
#   'Like_count': '6736',
#   'Comment_Count': '736'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Excel Tutorial For Beginners in Hindi | Complete Microsoft Excel Tutorial (Basic To Advance)',
#   'Published_date': '2022-12-24T05:45:00Z',
#   'Views': '1849050',
#   'Like_count': '64710',
#   'Comment_Count': '1912'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'What is ChatGPT and How You Can Use it | Chat GPT Explained',
#   'Published_date': '2022-12-22T12:53:07Z',
#   'Views': '3159',
#   'Like_count': '135',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Best Power BI Course & Free Resources | Power BI Tutorial For Beginners',
#   'Published_date': '2022-12-17T07:01:08Z',
#   'Views': '111537',
#   'Like_count': '3604',
#   'Comment_Count': '170'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Reality of Tech Jobs- Hiring freeze in 2024 | What You Should Do?',
#   'Published_date': '2022-12-12T13:06:24Z',
#   'Views': '1777',
#   'Like_count': '78',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Learn Statistics for Data Science - Best Course & Free Resources',
#   'Published_date': '2022-12-11T13:08:50Z',
#   'Views': '47910',
#   'Like_count': '2897',
#   'Comment_Count': '80'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'SQL Tutorial for Beginners | Full SQL Course In Hindi',
#   'Published_date': '2022-12-10T11:51:46Z',
#   'Views': '2127611',
#   'Like_count': '60901',
#   'Comment_Count': '3288'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Get JOB in Data Science with IBM Data Science Professional Certification Course 🔥',
#   'Published_date': '2022-12-01T06:26:22Z',
#   'Views': '87904',
#   'Like_count': '3394',
#   'Comment_Count': '253'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'SQL WITH Clause with examples | SQL CTE (Common Table Expression) | SQL Tutorial in Hindi 16',
#   'Published_date': '2022-11-29T14:43:31Z',
#   'Views': '94455',
#   'Like_count': '2094',
#   'Comment_Count': '197'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'What is Data Science & Future Scope ?',
#   'Published_date': '2022-11-20T12:48:37Z',
#   'Views': '82072',
#   'Like_count': '5177',
#   'Comment_Count': '77'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': '5 Best SQL Websites to Practice n Learn Interview Questions for FREE',
#   'Published_date': '2022-11-19T07:01:42Z',
#   'Views': '106029',
#   'Like_count': '10507',
#   'Comment_Count': '54'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'SQL Case Statement/Expression with Examples | WHEN THEN ELSE in sql | SQL Tutorial in Hindi 15',
#   'Published_date': '2022-11-19T03:30:25Z',
#   'Views': '80411',
#   'Like_count': '1245',
#   'Comment_Count': '61'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'SQL Window Function with Example- RANK, DENSE RANK, ROW NUMBER, LEAD/LAG | SQL Tutorial in Hindi 14',
#   'Published_date': '2022-11-13T05:34:50Z',
#   'Views': '140225',
#   'Like_count': '2748',
#   'Comment_Count': '229'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Most Asked SQL Interview Question - Solved Using 3 Methods',
#   'Published_date': '2022-10-30T07:56:40Z',
#   'Views': '61640',
#   'Like_count': '1592',
#   'Comment_Count': '81'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Complete SQL Subquery Using Comparison and Logical Operators | SQL Tutorial in Hindi 13',
#   'Published_date': '2022-10-29T05:22:53Z',
#   'Views': '106038',
#   'Like_count': '1718',
#   'Comment_Count': '68'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'SQL SELF JOIN | UNION & UNION ALL in SQL | SQL Tutorial in Hindi 12',
#   'Published_date': '2022-10-22T04:30:09Z',
#   'Views': '112167',
#   'Like_count': '1776',
#   'Comment_Count': '77'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Complete SQL JOINS For Beginners | SQL JOIN Queries with Examples | SQL Tutorial in Hindi 11',
#   'Published_date': '2022-10-19T13:15:01Z',
#   'Views': '349775',
#   'Like_count': '8202',
#   'Comment_Count': '525'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'TimeStamp and Extract Function | Date Time Function |  SQL Tutorial in Hindi 10',
#   'Published_date': '2022-10-16T04:33:38Z',
#   'Views': '68998',
#   'Like_count': '928',
#   'Comment_Count': '46'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Group By and Having Clause in SQL | SQL Tutorial in Hindi 9',
#   'Published_date': '2022-10-12T03:30:06Z',
#   'Views': '143800',
#   'Like_count': '2615',
#   'Comment_Count': '328'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Aggregate Functions in SQL - COUNT, SUM, AVG, MAX, MIN | SQL Tutorial in Hindi 8',
#   'Published_date': '2022-10-11T06:30:04Z',
#   'Views': '66202',
#   'Like_count': '836',
#   'Comment_Count': '28'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'String Functions in SQL | Functions in SQL | SQL Tutorial in Hindi 7',
#   'Published_date': '2022-10-09T04:30:01Z',
#   'Views': '91402',
#   'Like_count': '1090',
#   'Comment_Count': '36'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How To Import Excel File (CSV) to SQL | Import Data From File | SQL Tutorial in Hindi 6',
#   'Published_date': '2022-10-08T04:30:28Z',
#   'Views': '123855',
#   'Like_count': '1103',
#   'Comment_Count': '202'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'SELECT Statement & WHERE Clause with Example | Operators in SQL | SQL Tutorial in Hindi 5',
#   'Published_date': '2022-10-07T05:38:55Z',
#   'Views': '102721',
#   'Like_count': '1415',
#   'Comment_Count': '91'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Google Data Analytics Professional Certificate #dataanalyst #datascience #google',
#   'Published_date': '2022-10-03T13:56:56Z',
#   'Views': '16318',
#   'Like_count': '1220',
#   'Comment_Count': '25'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Start Your Career In Data Science With Google Data Analytics Professional Certification Course',
#   'Published_date': '2022-10-02T04:56:35Z',
#   'Views': '71263',
#   'Like_count': '2502',
#   'Comment_Count': '237'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'INSERT UPDATE, DELETE & ALTER Table in SQL With Example | SQL Tutorial in Hindi 4',
#   'Published_date': '2022-09-30T04:51:13Z',
#   'Views': '195909',
#   'Like_count': '4054',
#   'Comment_Count': '404'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Best Laptop Under Budget | Laptops for Students,  Coding, Gaming, Editing | Best Laptop 2022',
#   'Published_date': '2022-09-29T04:30:09Z',
#   'Views': '1787',
#   'Like_count': '66',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Create Table In SQL & Create Database | SQL Tutorial In Hindi 3',
#   'Published_date': '2022-09-25T08:20:57Z',
#   'Views': '234905',
#   'Like_count': '4228',
#   'Comment_Count': '274'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'how to install postgresql and pgadmin4',
#   'Published_date': '2022-09-25T07:47:46Z',
#   'Views': '174651',
#   'Like_count': '1689',
#   'Comment_Count': '228'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Data Types, Primary-Foreign Keys & Constraints in SQL | SQL Tutorial In Hindi 2',
#   'Published_date': '2022-09-24T07:30:02Z',
#   'Views': '190596',
#   'Like_count': '2716',
#   'Comment_Count': '119'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'What Is SQL ? | Database in SQL | SQL Introduction | SQL Tutorial In Hindi 1',
#   'Published_date': '2022-09-21T05:56:07Z',
#   'Views': '335480',
#   'Like_count': '9526',
#   'Comment_Count': '255'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'First Job tips for Beginners | Tips To Make Your Office Life Easy | Free Jobs Advice',
#   'Published_date': '2022-09-10T08:15:01Z',
#   'Views': '2210',
#   'Like_count': '117',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'What Does a Data Analyst Actually Do? | Data Analyst Role & Responsibilities',
#   'Published_date': '2022-09-04T05:24:33Z',
#   'Views': '277438',
#   'Like_count': '9831',
#   'Comment_Count': '782'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'VLOOKUP Formula in 2 Minute | VLOOKUP in Excel',
#   'Published_date': '2022-08-19T05:30:05Z',
#   'Views': '21801',
#   'Like_count': '342',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Pivot Tables in 1 Minute | How to use Pivot Tables in Excel',
#   'Published_date': '2022-08-17T06:30:07Z',
#   'Views': '23826',
#   'Like_count': '342',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How to use VLOOKUP formula in Excel | VLOOKUP in Excel Tutorial',
#   'Published_date': '2022-08-13T04:30:02Z',
#   'Views': '83105',
#   'Like_count': '1363',
#   'Comment_Count': '50'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How I Learned Data Science Skills & Switched Career to Data Science',
#   'Published_date': '2022-07-29T07:26:46Z',
#   'Views': '36514',
#   'Like_count': '2580',
#   'Comment_Count': '202'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Create Pivot Tables In Excel | Use of Pivot Table - Pivot Table Tutorial',
#   'Published_date': '2022-07-23T05:30:08Z',
#   'Views': '134000',
#   'Like_count': '2961',
#   'Comment_Count': '101'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Microsoft Excel Tutorial for Beginners - FREE Online Excel Course | Excel Tutorial Part 2',
#   'Published_date': '2022-07-19T05:30:08Z',
#   'Views': '59499',
#   'Like_count': '1564',
#   'Comment_Count': '100'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Microsoft Excel Tutorial for Beginners - FREE Online Excel Course | Excel Tutorial Part 1',
#   'Published_date': '2022-07-12T05:30:00Z',
#   'Views': '150191',
#   'Like_count': '3498',
#   'Comment_Count': '174'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Resume Format for Freshers 🔥 | Step by Step | Ms Word | Best Template for Fresher',
#   'Published_date': '2022-07-03T11:11:58Z',
#   'Views': '46172',
#   'Like_count': '930',
#   'Comment_Count': '39'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Business Analyst Vs Data Analyst - Job, Salary, Qualification, Skills & Career Path',
#   'Published_date': '2022-06-17T13:30:01Z',
#   'Views': '29915',
#   'Like_count': '1153',
#   'Comment_Count': '122'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Data Analyst in Bangalore PG Tour | How To Find PG in Bangalore | Cost of Living in Bangalore',
#   'Published_date': '2022-06-06T10:33:11Z',
#   'Views': '25124',
#   'Like_count': '700',
#   'Comment_Count': '68'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': '5 Minimum Skills to Get a Data Analyst Job || Skills to Become Data Analyst',
#   'Published_date': '2022-05-28T15:40:05Z',
#   'Views': '90608',
#   'Like_count': '4507',
#   'Comment_Count': '216'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How to Become Data Analyst | Complete Data Analyst Roadmap',
#   'Published_date': '2022-05-16T12:38:21Z',
#   'Views': '134861',
#   'Like_count': '7770',
#   'Comment_Count': '601'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'IT Jobs Without Coding with High Salary | Non Coding IT Jobs | Jobs without coding skills',
#   'Published_date': '2022-05-07T16:15:52Z',
#   'Views': '77516',
#   'Like_count': '1743',
#   'Comment_Count': '132'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Why Employees Are Quitting JOBS 😱 in TCS, Infosys, Wipro, Cognizant, etc. |The Great Resignation',
#   'Published_date': '2022-05-02T06:21:04Z',
#   'Views': '3857',
#   'Like_count': '119',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Best Websites to Apply Job | Top 3 Job Search App to get your First Job | Jobs for Freshers 2022',
#   'Published_date': '2022-04-24T07:31:44Z',
#   'Views': '4624',
#   'Like_count': '249',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Resume Format for Freshers that gets Shortlisted | Resume Kaise Banaye -  Resume Template & Tips',
#   'Published_date': '2022-04-17T04:46:27Z',
#   'Views': '2962',
#   'Like_count': '127',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': '5 Top Skills to Learn in 2022 That Will Make You RICH',
#   'Published_date': '2022-04-10T08:30:04Z',
#   'Views': '3630',
#   'Like_count': '111',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'How I Cracked My FIRST JOB After College 🔥 || My Placement Story',
#   'Published_date': '2022-04-03T11:15:03Z',
#   'Views': '7575',
#   'Like_count': '303',
#   'Comment_Count': '48'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': "FREE Courses with Certificates from World's Top Universities/colleges Websites for students",
#   'Published_date': '2022-03-31T13:05:03Z',
#   'Views': '17014',
#   'Like_count': '2031',
#   'Comment_Count': '21'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Google Tracks You Everywhere - Things Google Know About You',
#   'Published_date': '2022-03-30T07:22:03Z',
#   'Views': '4719',
#   'Like_count': '326',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Highest Paying Jobs In Digital Marketing #digitalmarketing #fresherjobs #jobs',
#   'Published_date': '2022-03-28T15:19:51Z',
#   'Views': '3114',
#   'Like_count': '61',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Websites to Earn Money Online from Freelancing or Part time job',
#   'Published_date': '2022-03-16T11:46:51Z',
#   'Views': '2941',
#   'Like_count': '193',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Top 15 Websites to Apply Job - Job Search Websites | Work From Home and Part Time Jobs #shorts',
#   'Published_date': '2022-03-15T13:23:10Z',
#   'Views': '3390',
#   'Like_count': '411',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Best Websites to Apply for Jobs | Online job portals #shorts',
#   'Published_date': '2022-03-08T11:30:13Z',
#   'Views': '7759',
#   'Like_count': '765',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'High Salary Jobs In Digital Marketing | Digital Marketing Jobs #shorts',
#   'Published_date': '2022-03-06T13:46:42Z',
#   'Views': '1815',
#   'Like_count': '83',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Title': 'Free Google Certificate to Start Your Career In Digital Marketing #shorts',
#   'Published_date': '2022-02-27T18:18:39Z',
#   'Views': '2746',
#   'Like_count': '183',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Amy Finnegan',
#   'Published_date': '2024-06-17T04:00:34Z',
#   'Views': '2726',
#   'Like_count': '50',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Xavier Moyá',
#   'Published_date': '2024-06-03T04:00:15Z',
#   'Views': '3603',
#   'Like_count': '54',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Tommy Tang',
#   'Published_date': '2024-05-20T04:00:10Z',
#   'Views': '4081',
#   'Like_count': '81',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Luis Serrano + Josh Starmer Q&A Livestream!!!',
#   'Published_date': '2024-05-11T04:01:07Z',
#   'Views': '5566',
#   'Like_count': '158',
#   'Comment_Count': '64'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Simon Stochholm',
#   'Published_date': '2024-04-29T11:50:30Z',
#   'Views': '4013',
#   'Like_count': '80',
#   'Comment_Count': '23'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Log_e Song - Official Lyric Video',
#   'Published_date': '2024-04-26T04:00:31Z',
#   'Views': '5192',
#   'Like_count': '240',
#   'Comment_Count': '73'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Brian Risk@devra.ai',
#   'Published_date': '2024-04-15T04:00:34Z',
#   'Views': '4525',
#   'Like_count': '91',
#   'Comment_Count': '21'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The matrix math behind transformer neural networks, one step at a time!!!',
#   'Published_date': '2024-04-08T04:00:09Z',
#   'Views': '45996',
#   'Like_count': '969',
#   'Comment_Count': '98'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Fabio Urbina',
#   'Published_date': '2024-04-01T04:00:26Z',
#   'Views': '4253',
#   'Like_count': '77',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Khushi Jain',
#   'Published_date': '2024-03-18T04:00:18Z',
#   'Views': '7526',
#   'Like_count': '140',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Achal Dixit',
#   'Published_date': '2024-03-04T07:00:17Z',
#   'Views': '7786',
#   'Like_count': '190',
#   'Comment_Count': '47'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Human Stories in AI: Rick Marks',
#   'Published_date': '2024-02-19T12:41:38Z',
#   'Views': '8186',
#   'Like_count': '187',
#   'Comment_Count': '27'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Essential Matrix Algebra for Neural Networks, Clearly Explained!!!',
#   'Published_date': '2023-12-11T05:00:25Z',
#   'Views': '44703',
#   'Like_count': '1369',
#   'Comment_Count': '136'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Word Embedding in PyTorch + Lightning',
#   'Published_date': '2023-11-06T13:03:55Z',
#   'Views': '31168',
#   'Like_count': '660',
#   'Comment_Count': '75'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Golden Play Button, Clearly Explained!!!’',
#   'Published_date': '2023-10-07T00:30:48Z',
#   'Views': '23763',
#   'Like_count': '2320',
#   'Comment_Count': '540'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Another 3 lessons from my Pop!!!',
#   'Published_date': '2023-09-04T04:00:16Z',
#   'Views': '11390',
#   'Like_count': '393',
#   'Comment_Count': '54'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Decoder-Only Transformers, ChatGPTs specific Transformer, Clearly Explained!!!',
#   'Published_date': '2023-08-28T04:00:30Z',
#   'Views': '102082',
#   'Like_count': '2642',
#   'Comment_Count': '323'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': "Transformer Neural Networks, ChatGPT's foundation, Clearly Explained!!!",
#   'Published_date': '2023-07-24T04:00:34Z',
#   'Views': '597172',
#   'Like_count': '15328',
#   'Comment_Count': '1199'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'What is a Logit?',
#   'Published_date': '2023-06-19T04:00:04Z',
#   'Views': '19904',
#   'Like_count': '818',
#   'Comment_Count': '42'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Logistic vs Logit Functions',
#   'Published_date': '2023-06-12T04:00:16Z',
#   'Views': '11869',
#   'Like_count': '515',
#   'Comment_Count': '24'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Attention for Neural Networks, Clearly Explained!!!',
#   'Published_date': '2023-06-05T04:00:19Z',
#   'Views': '231733',
#   'Like_count': '4934',
#   'Comment_Count': '392'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Likelihood vs Probability',
#   'Published_date': '2023-05-15T04:00:08Z',
#   'Views': '34551',
#   'Like_count': '2503',
#   'Comment_Count': '72'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'p-values',
#   'Published_date': '2023-05-15T04:00:00Z',
#   'Views': '7566',
#   'Like_count': '335',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Sequence-to-Sequence (seq2seq) Encoder-Decoder Neural Networks, Clearly Explained!!!',
#   'Published_date': '2023-05-08T04:00:17Z',
#   'Views': '164798',
#   'Like_count': '3443',
#   'Comment_Count': '319'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Matrix Multiplication',
#   'Published_date': '2023-04-16T04:00:33Z',
#   'Views': '11111',
#   'Like_count': '400',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Matrix Notation',
#   'Published_date': '2023-04-16T04:00:09Z',
#   'Views': '5837',
#   'Like_count': '277',
#   'Comment_Count': '21'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Ukulele: Clearly Explained!!!',
#   'Published_date': '2023-04-01T04:00:28Z',
#   'Views': '15871',
#   'Like_count': '532',
#   'Comment_Count': '104'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'PCA Eigenvalues',
#   'Published_date': '2023-03-21T17:13:30Z',
#   'Views': '22244',
#   'Like_count': '1052',
#   'Comment_Count': '42'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'PCA Eigenvectors',
#   'Published_date': '2023-03-20T11:46:03Z',
#   'Views': '14622',
#   'Like_count': '781',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Normalized Data',
#   'Published_date': '2023-03-20T11:45:51Z',
#   'Views': '6244',
#   'Like_count': '299',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Standardized Data',
#   'Published_date': '2023-03-20T11:45:47Z',
#   'Views': '6636',
#   'Like_count': '376',
#   'Comment_Count': '14'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Type 2 Errors',
#   'Published_date': '2023-03-20T11:45:38Z',
#   'Views': '5413',
#   'Like_count': '316',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Type 1 Errors',
#   'Published_date': '2023-03-20T11:45:33Z',
#   'Views': '7376',
#   'Like_count': '316',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Word Embedding and Word2Vec, Clearly Explained!!!',
#   'Published_date': '2023-03-13T04:00:23Z',
#   'Views': '265709',
#   'Like_count': '6810',
#   'Comment_Count': '468'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The AI Buzz, Episode #5: A new wave of AI-based products and the resurgence of personal applications',
#   'Published_date': '2023-03-07T16:00:08Z',
#   'Views': '10575',
#   'Like_count': '161',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'CatBoost Part 2: Building and Using Trees',
#   'Published_date': '2023-03-06T05:00:01Z',
#   'Views': '16909',
#   'Like_count': '319',
#   'Comment_Count': '85'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'CatBoost Part 1: Ordered Target Encoding',
#   'Published_date': '2023-02-27T05:00:07Z',
#   'Views': '29419',
#   'Like_count': '545',
#   'Comment_Count': '84'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The AI Buzz, Episode #4: ChatGPT + Bing and How to start an AI company in 3 easy steps.',
#   'Published_date': '2023-02-21T16:00:07Z',
#   'Views': '7113',
#   'Like_count': '161',
#   'Comment_Count': '23'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'One-Hot, Label, Target and K-Fold Target Encoding, Clearly Explained!!!',
#   'Published_date': '2023-02-13T05:00:03Z',
#   'Views': '44198',
#   'Like_count': '1520',
#   'Comment_Count': '160'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The AI Buzz, Episode #3: Constitutional AI, Emergent Abilities and Foundation Models',
#   'Published_date': '2023-02-07T16:00:10Z',
#   'Views': '4985',
#   'Like_count': '104',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Mutual Information, Clearly Explained!!!',
#   'Published_date': '2023-02-06T05:00:15Z',
#   'Views': '80693',
#   'Like_count': '2178',
#   'Comment_Count': '150'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Cosine Similarity, Clearly Explained!!!',
#   'Published_date': '2023-01-30T05:00:13Z',
#   'Views': '78289',
#   'Like_count': '3107',
#   'Comment_Count': '230'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Long Short-Term Memory with PyTorch + Lightning',
#   'Published_date': '2023-01-24T21:21:53Z',
#   'Views': '57950',
#   'Like_count': '1222',
#   'Comment_Count': '181'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The AI Buzz, Episode #2: Big data, Reinforcement Learning and Aligning Models',
#   'Published_date': '2023-01-24T16:00:08Z',
#   'Views': '5675',
#   'Like_count': '139',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The AI Buzz, Episode #1: ChatGPT, Transformers and Attention',
#   'Published_date': '2023-01-11T00:26:52Z',
#   'Views': '22563',
#   'Like_count': '487',
#   'Comment_Count': '61'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Design Matrix Examples in R, Clearly Explained!!!',
#   'Published_date': '2022-11-18T19:27:04Z',
#   'Views': '11124',
#   'Like_count': '177',
#   'Comment_Count': '39'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Design Matrices For Linear Models, Clearly Explained!!!',
#   'Published_date': '2022-11-18T19:22:30Z',
#   'Views': '11884',
#   'Like_count': '198',
#   'Comment_Count': '32'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Using Linear Models for t tests and ANOVA, Clearly Explained!!!',
#   'Published_date': '2022-11-18T19:19:19Z',
#   'Views': '49302',
#   'Like_count': '798',
#   'Comment_Count': '47'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Multiple Regression in R, Step by Step!!!',
#   'Published_date': '2022-11-18T19:14:19Z',
#   'Views': '74179',
#   'Like_count': '1247',
#   'Comment_Count': '68'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Multiple Regression, Clearly Explained!!!',
#   'Published_date': '2022-11-18T19:11:48Z',
#   'Views': '167658',
#   'Like_count': '1875',
#   'Comment_Count': '53'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Linear Regression in R, Step by Step',
#   'Published_date': '2022-11-18T19:09:00Z',
#   'Views': '70836',
#   'Like_count': '1359',
#   'Comment_Count': '62'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Linear Regression, Clearly Explained!!!',
#   'Published_date': '2022-11-18T19:08:44Z',
#   'Views': '215423',
#   'Like_count': '3888',
#   'Comment_Count': '231'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'R-squared, Clearly Explained!!!',
#   'Published_date': '2022-11-18T18:55:45Z',
#   'Views': '166358',
#   'Like_count': '3281',
#   'Comment_Count': '217'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Long Short-Term Memory (LSTM), Clearly Explained',
#   'Published_date': '2022-11-07T05:00:15Z',
#   'Views': '492274',
#   'Like_count': '12838',
#   'Comment_Count': '1165'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Cosine Similarity for NLP and CatBoost',
#   'Published_date': '2022-11-01T15:47:08Z',
#   'Views': '12060',
#   'Like_count': '378',
#   'Comment_Count': '43'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Happy Halloween (Neural Networks Are Not Scary)',
#   'Published_date': '2022-10-31T04:00:30Z',
#   'Views': '192819',
#   'Like_count': '2428',
#   'Comment_Count': '101'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Handmade Pasta, Clearly Explained!!!',
#   'Published_date': '2022-10-25T04:00:06Z',
#   'Views': '9057',
#   'Like_count': '404',
#   'Comment_Count': '80'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live Stream - More details about Target Encoding/AMA/Silly Songs',
#   'Published_date': '2022-10-18T15:55:23Z',
#   'Views': '6385',
#   'Like_count': '182',
#   'Comment_Count': '36'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live Stream - Target Encoding/AMA/Silly Songs!!!',
#   'Published_date': '2022-10-05T04:00:22Z',
#   'Views': '8243',
#   'Like_count': '216',
#   'Comment_Count': '38'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'StatQuest with Josh Starmer Live Stream',
#   'Published_date': '2022-09-19T11:56:32Z',
#   'Views': '0',
#   'Like_count': '0',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Introduction to Coding Neural Networks with PyTorch and Lightning',
#   'Published_date': '2022-09-19T04:00:14Z',
#   'Views': '58516',
#   'Like_count': '1420',
#   'Comment_Count': '187'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Three more lessons from my Pop!!!',
#   'Published_date': '2022-09-04T04:00:03Z',
#   'Views': '10789',
#   'Like_count': '467',
#   'Comment_Count': '77'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Recurrent Neural Networks (RNNs), Clearly Explained!!!',
#   'Published_date': '2022-07-11T04:00:06Z',
#   'Views': '489987',
#   'Like_count': '12233',
#   'Comment_Count': '709'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The StatQuest Illustrated Guide To Machine Learning, Theme Song!!!',
#   'Published_date': '2022-05-09T04:00:03Z',
#   'Views': '30084',
#   'Like_count': '918',
#   'Comment_Count': '257'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The StatQuest Introduction to PyTorch',
#   'Published_date': '2022-04-25T04:00:12Z',
#   'Views': '145209',
#   'Like_count': '4106',
#   'Comment_Count': '346'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Troll 2, Clearly Explained!!!',
#   'Published_date': '2022-04-01T04:00:09Z',
#   'Views': '16205',
#   'Like_count': '506',
#   'Comment_Count': '85'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Binomial Distribution in 30 Seconds!!!',
#   'Published_date': '2022-03-22T18:39:32Z',
#   'Views': '29214',
#   'Like_count': '1335',
#   'Comment_Count': '93'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'UMAP: Mathematical Details (clearly explained!!!)',
#   'Published_date': '2022-03-14T16:00:13Z',
#   'Views': '34525',
#   'Like_count': '751',
#   'Comment_Count': '80'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'UMAP Dimension Reduction, Main Ideas!!!',
#   'Published_date': '2022-03-07T17:00:10Z',
#   'Views': '100569',
#   'Like_count': '2720',
#   'Comment_Count': '163'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Tensors for Neural Networks, Clearly Explained!!!',
#   'Published_date': '2022-02-28T17:00:11Z',
#   'Views': '169736',
#   'Like_count': '5491',
#   'Comment_Count': '273'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Sensitivity, Specificity, Precision, Recall Sing-a-Long!!!',
#   'Published_date': '2022-02-10T17:19:53Z',
#   'Views': '74689',
#   'Like_count': '2524',
#   'Comment_Count': '147'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Exponential Distribution',
#   'Published_date': '2022-01-14T19:44:47Z',
#   'Views': '72029',
#   'Like_count': '1707',
#   'Comment_Count': '137'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The mean, the median, and the mode.',
#   'Published_date': '2022-01-14T19:17:37Z',
#   'Views': '59476',
#   'Like_count': '1084',
#   'Comment_Count': '51'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Clustering with DBSCAN, Clearly Explained!!!',
#   'Published_date': '2022-01-10T12:51:02Z',
#   'Views': '280567',
#   'Like_count': '8934',
#   'Comment_Count': '433'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Frank Starmer Clearly Explained (How my pop influenced StatQuest!!!)',
#   'Published_date': '2021-09-04T04:00:01Z',
#   'Views': '30298',
#   'Like_count': '1565',
#   'Comment_Count': '227'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Entropy (for data science) Clearly Explained!!!',
#   'Published_date': '2021-08-25T04:00:08Z',
#   'Views': '578397',
#   'Like_count': '18326',
#   'Comment_Count': '1276'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': "Bayes' Theorem, Clearly Explained!!!!",
#   'Published_date': '2021-08-16T04:00:05Z',
#   'Views': '338450',
#   'Like_count': '7264',
#   'Comment_Count': '428'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Conditional Probabilities, Clearly Explained!!!',
#   'Published_date': '2021-07-21T04:00:12Z',
#   'Views': '191846',
#   'Like_count': '5712',
#   'Comment_Count': '370'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Using Bootstrapping to Calculate p-values!!!',
#   'Published_date': '2021-07-13T04:00:07Z',
#   'Views': '102822',
#   'Like_count': '2615',
#   'Comment_Count': '221'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Bootstrapping Main Ideas!!!',
#   'Published_date': '2021-07-06T04:00:15Z',
#   'Views': '433164',
#   'Like_count': '12433',
#   'Comment_Count': '644'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': "Ken Jee's #66DaysOfData Challenge Clearly Explained!!!",
#   'Published_date': '2021-06-23T20:44:27Z',
#   'Views': '16790',
#   'Like_count': '594',
#   'Comment_Count': '71'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Expected Values for Continuous Variables!!!',
#   'Published_date': '2021-06-22T04:00:06Z',
#   'Views': '80351',
#   'Like_count': '2152',
#   'Comment_Count': '173'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Three (3) things to do when starting out in Data Science',
#   'Published_date': '2021-05-27T04:00:10Z',
#   'Views': '56400',
#   'Like_count': '2058',
#   'Comment_Count': '165'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'How to make your own StatQuest!!!',
#   'Published_date': '2021-05-03T04:00:22Z',
#   'Views': '14745',
#   'Like_count': '926',
#   'Comment_Count': '168'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Decision and Classification Trees, Clearly Explained!!!',
#   'Published_date': '2021-04-26T04:00:08Z',
#   'Views': '685349',
#   'Like_count': '14623',
#   'Comment_Count': '734'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Silly Songs, Clearly Explained!!!',
#   'Published_date': '2021-04-01T04:00:10Z',
#   'Views': '12950',
#   'Like_count': '723',
#   'Comment_Count': '117'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Expected Values, Main Ideas!!!',
#   'Published_date': '2021-03-29T04:00:03Z',
#   'Views': '176923',
#   'Like_count': '5848',
#   'Comment_Count': '377'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Part 8: Image Classification with Convolutional Neural Networks (CNNs)',
#   'Published_date': '2021-03-08T05:00:12Z',
#   'Views': '222458',
#   'Like_count': '7048',
#   'Comment_Count': '738'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Part 7: Cross Entropy Derivatives and Backpropagation',
#   'Published_date': '2021-03-01T05:15:01Z',
#   'Views': '120016',
#   'Like_count': '2884',
#   'Comment_Count': '308'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Part 6: Cross Entropy',
#   'Published_date': '2021-03-01T05:00:01Z',
#   'Views': '224633',
#   'Like_count': '5778',
#   'Comment_Count': '261'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The SoftMax Derivative, Step-by-Step!!!',
#   'Published_date': '2021-02-08T03:34:35Z',
#   'Views': '72355',
#   'Like_count': '1669',
#   'Comment_Count': '91'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Part 5: ArgMax and SoftMax',
#   'Published_date': '2021-02-08T03:34:23Z',
#   'Views': '147656',
#   'Like_count': '4077',
#   'Comment_Count': '227'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Pt. 4: Multiple Inputs and Outputs',
#   'Published_date': '2021-02-01T05:00:03Z',
#   'Views': '157899',
#   'Like_count': '4004',
#   'Comment_Count': '256'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'US Census Data and Contest!!!',
#   'Published_date': '2020-12-08T01:00:16Z',
#   'Views': '14492',
#   'Like_count': '266',
#   'Comment_Count': '54'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Pt. 3: ReLU In Action!!!',
#   'Published_date': '2020-11-23T09:05:29Z',
#   'Views': '248617',
#   'Like_count': '5663',
#   'Comment_Count': '296'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Backpropagation Details Pt. 2: Going bonkers with The Chain Rule',
#   'Published_date': '2020-11-02T05:15:01Z',
#   'Views': '121954',
#   'Like_count': '3761',
#   'Comment_Count': '476'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Backpropagation Details Pt. 1: Optimizing 3 parameters simultaneously.',
#   'Published_date': '2020-11-02T05:00:06Z',
#   'Views': '189362',
#   'Like_count': '4386',
#   'Comment_Count': '265'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Neural Networks Pt. 2: Backpropagation Main Ideas',
#   'Published_date': '2020-10-19T04:00:02Z',
#   'Views': '487790',
#   'Like_count': '10089',
#   'Comment_Count': '519'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'What is AutoML? A conversation with Gnosis Data Analysis',
#   'Published_date': '2020-09-07T04:00:08Z',
#   'Views': '34033',
#   'Like_count': '947',
#   'Comment_Count': '92'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Essential Main Ideas of Neural Networks',
#   'Published_date': '2020-08-31T04:00:03Z',
#   'Views': '887464',
#   'Like_count': '24259',
#   'Comment_Count': '1962'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'XGBoost in Python from Start to Finish',
#   'Published_date': '2020-08-01T18:13:06Z',
#   'Views': '216448',
#   'Like_count': '6018',
#   'Comment_Count': '710'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Elements of StatQuest (Webinar)',
#   'Published_date': '2020-07-20T04:00:03Z',
#   'Views': '8679',
#   'Like_count': '361',
#   'Comment_Count': '101'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'The Chain Rule',
#   'Published_date': '2020-07-13T04:00:18Z',
#   'Views': '236593',
#   'Like_count': '6305',
#   'Comment_Count': '446'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Hypothesis Testing and The Null Hypothesis, Clearly Explained!!!',
#   'Published_date': '2020-07-06T04:00:01Z',
#   'Views': '516681',
#   'Like_count': '10831',
#   'Comment_Count': '487'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Alternative Hypotheses: Main Ideas!!!',
#   'Published_date': '2020-07-06T04:00:00Z',
#   'Views': '144525',
#   'Like_count': '3908',
#   'Comment_Count': '162'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Support Vector Machines in Python from Start to Finish.',
#   'Published_date': '2020-06-30T17:34:48Z',
#   'Views': '130622',
#   'Like_count': '3646',
#   'Comment_Count': '371'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live 2020-06-15!!! Bootstrapping, Main Ideas',
#   'Published_date': '2020-06-15T15:36:26Z',
#   'Views': '33442',
#   'Like_count': '1353',
#   'Comment_Count': '206'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Classification Trees in Python from Start to Finish',
#   'Published_date': '2020-06-07T01:50:06Z',
#   'Views': '182196',
#   'Like_count': '4074',
#   'Comment_Count': '580'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Gaussian Naive Bayes, Clearly Explained!!!',
#   'Published_date': '2020-06-03T12:36:37Z',
#   'Views': '326559',
#   'Like_count': '7624',
#   'Comment_Count': '466'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Naive Bayes, Clearly Explained!!!',
#   'Published_date': '2020-06-03T12:35:57Z',
#   'Views': '1016514',
#   'Like_count': '26740',
#   'Comment_Count': '1562'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live 2020-06-01!!! Hypothesis Testing',
#   'Published_date': '2020-06-01T15:35:49Z',
#   'Views': '17586',
#   'Like_count': '755',
#   'Comment_Count': '105'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Ridge vs Lasso Regression, Visualized!!!',
#   'Published_date': '2020-05-19T04:00:08Z',
#   'Views': '238510',
#   'Like_count': '5754',
#   'Comment_Count': '401'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': "Live 2020-05-18!!! Bayes' Theorem",
#   'Published_date': '2020-05-18T15:42:14Z',
#   'Views': '24903',
#   'Like_count': '887',
#   'Comment_Count': '109'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live 2020-05-04!!! Conditional Probability',
#   'Published_date': '2020-05-04T16:39:56Z',
#   'Views': '12853',
#   'Like_count': '404',
#   'Comment_Count': '94'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Statistical Power, Clearly Explained!!!',
#   'Published_date': '2020-05-04T04:00:11Z',
#   'Views': '282627',
#   'Like_count': '6564',
#   'Comment_Count': '304'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Power Analysis, Clearly Explained!!!',
#   'Published_date': '2020-05-04T04:00:11Z',
#   'Views': '297917',
#   'Like_count': '6099',
#   'Comment_Count': '412'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'p-hacking: What it is and how to avoid it!',
#   'Published_date': '2020-05-04T04:00:05Z',
#   'Views': '132862',
#   'Like_count': '3723',
#   'Comment_Count': '271'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live 2020-04-20!!! Expected Values',
#   'Published_date': '2020-04-20T16:46:34Z',
#   'Views': '20729',
#   'Like_count': '893',
#   'Comment_Count': '157'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Live 2020-04-06!!! Naive Bayes: Gaussian',
#   'Published_date': '2020-04-06T16:49:34Z',
#   'Views': '17536',
#   'Like_count': '612',
#   'Comment_Count': '117'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'Bam!!! Clearly Explained!!!',
#   'Published_date': '2020-04-01T04:00:14Z',
#   'Views': '57005',
#   'Like_count': '3426',
#   'Comment_Count': '521'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Title': 'How to calculate p-values',
#   'Published_date': '2020-03-23T04:15:00Z',
#   'Views': '395536',
#   'Like_count': '9870',
#   'Comment_Count': '764'},
# ...
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Create a Table of Contents in Microsoft Word #shorts',
#   'Published_date': '2021-06-27T11:00:19Z',
#   'Views': '229662',
#   'Like_count': '6503',
#   'Comment_Count': '64'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Create Random Numbers in Excel (including no repeats)',
#   'Published_date': '2021-06-24T09:00:11Z',
#   'Views': '195436',
#   'Like_count': '4192',
#   'Comment_Count': '220'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Click to Reveal in PowerPoint | Trigger an Animation When YOU Need',
#   'Published_date': '2021-06-22T11:00:13Z',
#   'Views': '417762',
#   'Like_count': '7622',
#   'Comment_Count': '338'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': "The BEST Windows Shortcut You're NOT Using #shorts",
#   'Published_date': '2021-06-20T11:00:03Z',
#   'Views': '134263',
#   'Like_count': '6216',
#   'Comment_Count': '202'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Create INTERACTIVE Excel Dashboards With Option Buttons | How to use Radio Buttons',
#   'Published_date': '2021-06-17T09:00:32Z',
#   'Views': '586967',
#   'Like_count': '17245',
#   'Comment_Count': '528'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Easily Make a Video 🎞️ in PowerPoint (Slideshow & Screen Recording)',
#   'Published_date': '2021-06-15T11:00:14Z',
#   'Views': '697890',
#   'Like_count': '14756',
#   'Comment_Count': '525'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Presentation Tip: Use Mouse Sonar to Direct Attention #shorts',
#   'Published_date': '2021-06-13T11:00:20Z',
#   'Views': '86786',
#   'Like_count': '3658',
#   'Comment_Count': '100'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'EASILY UNLOCK Protected Excel Sheets WITHOUT Password',
#   'Published_date': '2021-06-10T09:00:01Z',
#   'Views': '1979647',
#   'Like_count': '39912',
#   'Comment_Count': '2614'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Inflation Is Back! What YOU Can Do to PROTECT Your Savings.',
#   'Published_date': '2021-06-08T11:00:12Z',
#   'Views': '86483',
#   'Like_count': '4021',
#   'Comment_Count': '323'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Get a Free Library as you Learn Excel Power Query Tricks (Custom data types, Hyperlink data type!)',
#   'Published_date': '2021-06-03T09:00:04Z',
#   'Views': '121002',
#   'Like_count': '3136',
#   'Comment_Count': '215'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Filters With Your Desktop Webcam - for Teams, Zoom & Meet #shorts',
#   'Published_date': '2021-06-01T11:00:17Z',
#   'Views': '98145',
#   'Like_count': '1473',
#   'Comment_Count': '60'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Introduction to Office Scripts & How to Tweak Macros to Automate Tasks in Excel',
#   'Published_date': '2021-05-27T09:00:29Z',
#   'Views': '137553',
#   'Like_count': '3041',
#   'Comment_Count': '189'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'FREE Windows Apps You Should be Using (who thought these are ACTUALLY FREE?!)',
#   'Published_date': '2021-05-25T11:00:12Z',
#   'Views': '1518957',
#   'Like_count': '59064',
#   'Comment_Count': '1623'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Do You Need to SWITCH from Excel VBA Macros to Office Scripts?',
#   'Published_date': '2021-05-20T09:00:04Z',
#   'Views': '374619',
#   'Like_count': '6443',
#   'Comment_Count': '441'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': '👕 Introducing the New Merch! ☕',
#   'Published_date': '2021-05-18T11:00:14Z',
#   'Views': '32177',
#   'Like_count': '858',
#   'Comment_Count': '118'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Import Emails From OUTLOOK to EXCEL & why you want to do that!',
#   'Published_date': '2021-05-13T09:00:01Z',
#   'Views': '1027780',
#   'Like_count': '24141',
#   'Comment_Count': '1049'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Top Tips to Manage Your Outlook Calendar 📅 (which are you using?)',
#   'Published_date': '2021-05-11T11:00:07Z',
#   'Views': '1051823',
#   'Like_count': '23136',
#   'Comment_Count': '464'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Show Changes and History of Edits in Excel (Formula changes too!)',
#   'Published_date': '2021-05-06T09:00:10Z',
#   'Views': '118117',
#   'Like_count': '2397',
#   'Comment_Count': '147'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'New Features in Microsoft Teams (Did you see these?)',
#   'Published_date': '2021-05-04T11:00:08Z',
#   'Views': '194284',
#   'Like_count': '4491',
#   'Comment_Count': '165'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Power Automate to Send Emails from Excel with PERSONAL Attachments',
#   'Published_date': '2021-04-29T09:00:14Z',
#   'Views': '380619',
#   'Like_count': '5922',
#   'Comment_Count': '604'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Why I Prefer Edge to Chrome (and YOU WILL TOO!)',
#   'Published_date': '2021-04-27T11:00:31Z',
#   'Views': '935934',
#   'Like_count': '32029',
#   'Comment_Count': '3724'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'GREAT NEWS! You can now UNHIDE All Excel Sheets in ONE GO! #shorts',
#   'Published_date': '2021-04-24T11:00:10Z',
#   'Views': '94505',
#   'Like_count': '3137',
#   'Comment_Count': '138'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Mail Merge in Word, Excel & Outlook | Dynamic Linking between Excel & Word',
#   'Published_date': '2021-04-22T09:00:01Z',
#   'Views': '695365',
#   'Like_count': '12015',
#   'Comment_Count': '564'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Power Apps | Get Started with THIS Tutorial & Create your 1st app',
#   'Published_date': '2021-04-20T11:00:16Z',
#   'Views': '685211',
#   'Like_count': '15422',
#   'Comment_Count': '375'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Automatically Create Clickable PDF Bookmarks Using Microsoft Word',
#   'Published_date': '2021-04-17T11:00:02Z',
#   'Views': '125578',
#   'Like_count': '4206',
#   'Comment_Count': '229'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Create & Update Planner Tasks from Excel (or Teams)',
#   'Published_date': '2021-04-15T09:00:07Z',
#   'Views': '244123',
#   'Like_count': '2501',
#   'Comment_Count': '192'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': '3 Cool Effects You Did NOT Think are Possible in PowerPoint | Morph',
#   'Published_date': '2021-04-13T11:00:32Z',
#   'Views': '6517335',
#   'Like_count': '210924',
#   'Comment_Count': '3062'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': "Color Code emails you're copied on in Outlook #shorts",
#   'Published_date': '2021-04-11T11:00:12Z',
#   'Views': '225567',
#   'Like_count': '8302',
#   'Comment_Count': '153'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Use Outlook Archive to FREE SPACE & CLEAN UP Your Mailbox',
#   'Published_date': '2021-04-10T11:00:09Z',
#   'Views': '384058',
#   'Like_count': '6423',
#   'Comment_Count': '243'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Advanced Pivot Table Techniques (to achieve more in Excel)',
#   'Published_date': '2021-04-08T09:00:17Z',
#   'Views': '1934843',
#   'Like_count': '45546',
#   'Comment_Count': '1381'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Breakout Rooms in Microsoft Teams',
#   'Published_date': '2021-04-06T11:00:24Z',
#   'Views': '119824',
#   'Like_count': '1429',
#   'Comment_Count': '74'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'FIFO Inventory Accounting Method EXPLAINED | First In, First Out Inventory Cost Flow',
#   'Published_date': '2021-04-03T11:00:01Z',
#   'Views': '59716',
#   'Like_count': '1844',
#   'Comment_Count': '109'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Create & Use Excel Macros (Real world example)',
#   'Published_date': '2021-04-01T09:00:02Z',
#   'Views': '1681915',
#   'Like_count': '29704',
#   'Comment_Count': '603'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Embarrassing Microsoft Teams Meeting Mistakes: What NOT TO DO!',
#   'Published_date': '2021-03-30T11:00:02Z',
#   'Views': '554098',
#   'Like_count': '11215',
#   'Comment_Count': '363'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'YOUR OWN TAB In EXCEL because... Why not?! #shorts',
#   'Published_date': '2021-03-28T11:00:02Z',
#   'Views': '168001',
#   'Like_count': '5644',
#   'Comment_Count': '200'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Create the Fanciest PowerPoint Intro slide to Dazzle your Audience',
#   'Published_date': '2021-03-27T12:00:04Z',
#   'Views': '795327',
#   'Like_count': '25932',
#   'Comment_Count': '515'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Calculate Ratios in Excel (GCD Function explained)',
#   'Published_date': '2021-03-25T10:00:07Z',
#   'Views': '91921',
#   'Like_count': '2099',
#   'Comment_Count': '152'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Microsoft To Do With Outlook, Teams & Planner',
#   'Published_date': '2021-03-23T12:00:19Z',
#   'Views': '710842',
#   'Like_count': '13476',
#   'Comment_Count': '257'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'TOP 10 Outlook Tips EVERY Professional NEEDS To Know',
#   'Published_date': '2021-03-20T12:00:04Z',
#   'Views': '1425841',
#   'Like_count': '27126',
#   'Comment_Count': '711'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Streamline Excel: Power Automate Tricks You Need to Know!',
#   'Published_date': '2021-03-18T10:00:19Z',
#   'Views': '165135',
#   'Like_count': '3312',
#   'Comment_Count': '196'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Microsoft To Do & Get Organized!',
#   'Published_date': '2021-03-16T12:00:14Z',
#   'Views': '1134637',
#   'Like_count': '24185',
#   'Comment_Count': '668'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Show Excel Formulas in Cells with FORMULATEXT Function #shorts',
#   'Published_date': '2021-03-14T12:00:10Z',
#   'Views': '83489',
#   'Like_count': '3775',
#   'Comment_Count': '117'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Windows 10 Tips & Tricks You NEED to Use!',
#   'Published_date': '2021-03-13T12:00:24Z',
#   'Views': '191494',
#   'Like_count': '7031',
#   'Comment_Count': '197'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Excel Features You NEED to KNOW (If you work in Accounting)',
#   'Published_date': '2021-03-11T10:00:02Z',
#   'Views': '455751',
#   'Like_count': '12828',
#   'Comment_Count': '353'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Microsoft Teams ESSENTIAL Tips for Teachers',
#   'Published_date': '2021-03-09T12:00:06Z',
#   'Views': '65574',
#   'Like_count': '1010',
#   'Comment_Count': '79'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use SEARCH 🔎 in Outlook to Find Emails FAST!',
#   'Published_date': '2021-03-06T12:13:52Z',
#   'Views': '781596',
#   'Like_count': '19673',
#   'Comment_Count': '542'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How To Import & Clean Messy Accounting Data in Excel | Use Power Query to Import SAP Data',
#   'Published_date': '2021-03-04T10:00:07Z',
#   'Views': '535296',
#   'Like_count': '12714',
#   'Comment_Count': '416'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': "Top 10 Tips in Microsoft Teams You Didn't Know You Needed | Shortcuts, Power Automate, Polls & more",
#   'Published_date': '2021-03-02T12:00:01Z',
#   'Views': '188157',
#   'Like_count': '3667',
#   'Comment_Count': '134'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'EXCEL NOT RESPONDING! NOTHING WORKS! 😳 Excel Prank Part 5 #shorts',
#   'Published_date': '2021-02-28T12:00:00Z',
#   'Views': '105707',
#   'Like_count': '3270',
#   'Comment_Count': '143'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': "10 Google Sheets Tips You DON'T Want to Miss",
#   'Published_date': '2021-02-27T12:00:06Z',
#   'Views': '555670',
#   'Like_count': '11894',
#   'Comment_Count': '309'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Excel for Accounting - 10 Excel Functions You NEED to KNOW!',
#   'Published_date': '2021-02-25T10:00:13Z',
#   'Views': '2034952',
#   'Like_count': '45389',
#   'Comment_Count': '914'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Three Ways to Schedule Meetings in Microsoft Teams',
#   'Published_date': '2021-02-23T12:00:09Z',
#   'Views': '389902',
#   'Like_count': '5018',
#   'Comment_Count': '154'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'WHERE Did MY CHARTS GO?! Excel Prank Part 4 #shorts',
#   'Published_date': '2021-02-21T12:00:03Z',
#   'Views': '46790',
#   'Like_count': '1200',
#   'Comment_Count': '54'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Mirror Phone on PC to Boost Your Productivity 📲 Your Phone App for Windows 10',
#   'Published_date': '2021-02-20T12:00:16Z',
#   'Views': '725741',
#   'Like_count': '13353',
#   'Comment_Count': '820'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Merge Excel Files with Different Headers in Power Query | List.Accumulate',
#   'Published_date': '2021-02-18T10:00:30Z',
#   'Views': '204871',
#   'Like_count': '4263',
#   'Comment_Count': '297'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Learn to Use Power Automate with Examples | Create Bulk PDF Files | Planner to Outlook',
#   'Published_date': '2021-02-16T12:00:20Z',
#   'Views': '833099',
#   'Like_count': '11287',
#   'Comment_Count': '529'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Excel Automatically Replaces Names | Excel Prank Part 3 #shorts',
#   'Published_date': '2021-02-14T12:00:23Z',
#   'Views': '88333',
#   'Like_count': '2815',
#   'Comment_Count': '135'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How To EASILY Convert PDF to Word | True and Scanned PDF',
#   'Published_date': '2021-02-13T12:00:03Z',
#   'Views': '1248313',
#   'Like_count': '20410',
#   'Comment_Count': '622'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Excel Formulas and Functions You NEED to KNOW!',
#   'Published_date': '2021-02-11T10:00:32Z',
#   'Views': '727842',
#   'Like_count': '15932',
#   'Comment_Count': '319'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to use Microsoft Whiteboard | Essential Practices for Meetings',
#   'Published_date': '2021-02-09T12:00:15Z',
#   'Views': '289144',
#   'Like_count': '5161',
#   'Comment_Count': '217'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'WARNING! RANDOM FILE WILL BE DELETED! Excel Prank Part 2 #shorts',
#   'Published_date': '2021-02-07T12:00:11Z',
#   'Views': '120311',
#   'Like_count': '4376',
#   'Comment_Count': '148'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'TOO MANY EMAILS? Use THESE Proven Techniques | Outlook tips included',
#   'Published_date': '2021-02-06T12:00:03Z',
#   'Views': '3102600',
#   'Like_count': '73708',
#   'Comment_Count': '1742'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Excel Tutorial for Beginners | Excel Made Easy',
#   'Published_date': '2021-02-04T10:00:02Z',
#   'Views': '1933087',
#   'Like_count': '38039',
#   'Comment_Count': '716'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'What Your Boss Can TRACK About YOU with Microsoft Teams',
#   'Published_date': '2021-02-02T12:00:05Z',
#   'Views': '6749236',
#   'Like_count': '58157',
#   'Comment_Count': '2663'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'ALL VALUES ERASED! Excel Prank Part 1 #Shorts',
#   'Published_date': '2021-01-31T12:00:12Z',
#   'Views': '139235',
#   'Like_count': '4949',
#   'Comment_Count': '236'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use Microsoft Excel For FREE | Differences to Paid Office 365 Version',
#   'Published_date': '2021-01-30T12:00:13Z',
#   'Views': '91214',
#   'Like_count': '1962',
#   'Comment_Count': '123'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to Use the STOCKHISTORY Function in Excel 📈',
#   'Published_date': '2021-01-28T10:00:09Z',
#   'Views': '165618',
#   'Like_count': '3318',
#   'Comment_Count': '298'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'How to use Microsoft Planner | Complete Guide | Add to Teams',
#   'Published_date': '2021-01-26T12:00:27Z',
#   'Views': '1050663',
#   'Like_count': '13899',
#   'Comment_Count': '419'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'Make Excel SPEAK | Excel Trick #Shorts',
#   'Published_date': '2021-01-23T12:00:15Z',
#   'Views': '135624',
#   'Like_count': '4525',
#   'Comment_Count': '138'},
#  {'Channel_Name': 'Leila Gharani',
#   'Title': 'When Should You Use the Hash Sign in Excel Formulas?',
#   'Published_date': '2021-01-21T10:00:00Z',
#   'Views': '1078367',
#   'Like_count': '24762',
#   'Comment_Count': '544'},
#  ...]

# %%
Video_data=pd.DataFrame(video_details)

# %%
Video_data
# Out:
#            Channel_Name                                              Title  \
# 0        Rishabh Mishra  POWER BI Full PROJECT for Data Analysis with P...
# 1        Rishabh Mishra  AI Revolution - Future of Data Analyst Jobs & ...
# 2        Rishabh Mishra  Reality of Data Analyst Courses and Data Scien...
# 3        Rishabh Mishra  Personal Portfolio Website for Beginners | How...
# 4        Rishabh Mishra  How To Create LinkedIn Profile in 2024 | Linke...
# ...                 ...                                                ...
# 22997  Alex The Analyst  Data Analyst Resume | Reviewing My Resume! | F...
# 22998  Alex The Analyst  Working at a Big Company Vs Small Company | To...
# 22999  Alex The Analyst      Data Analyst Salary | 100k with No Experience
# 23000  Alex The Analyst  Truth About Big Companies | Told by a Fortune ...
# 23001  Alex The Analyst                  Top 3 Data Analyst Skills in 2020
#
#              Published_date   Views Like_count Comment_Count
# 0      2024-04-20T11:57:21Z  157284       5575           632
# 1      2024-03-23T03:45:04Z   78155       2712           245
# 2      2024-03-16T12:47:05Z   43627       1285           267
# 3      2024-01-21T04:00:02Z  129956       3462           358
# 4      2024-01-17T13:41:48Z  143309       3389           192
# ...                     ...     ...        ...           ...
# 22997  2020-01-30T14:07:55Z   72678       1679            64
# 22998  2020-01-25T16:38:39Z   15225        412            22
# 22999  2020-01-23T03:16:09Z   64571       2196           229
# 23000  2020-01-21T03:52:15Z    8943        328            19
# 23001  2020-01-17T14:31:39Z   29074       1406           140
#
# [23002 rows x 6 columns]

# %%
Video_data['Views'] = Video_data['Views'].replace("N/A", np.nan)
Video_data['Like_count'] = Video_data['Like_count'].replace("N/A", np.nan)
Video_data['Comment_Count'] = Video_data['Comment_Count'].replace("N/A", np.nan)

# %%
Video_data['Views'] = pd.to_numeric(Video_data['Views'], errors='coerce')
Video_data['Like_count'] = pd.to_numeric(Video_data['Like_count'], errors='coerce')
Video_data['Comment_Count'] = pd.to_numeric(Video_data['Comment_Count'], errors='coerce')

# %%
Video_data['Published_date'] = pd.to_datetime(Video_data['Published_date']).dt.date

# %%
Video_data.dtypes
# Out:
# Channel_Name       object
# Title              object
# Published_date     object
# Views             float64
# Like_count        float64
# Comment_Count     float64
# dtype: object

# %%
Video_data.to_csv(r'A:\data science material\data set\youtube\Youtube_dataset_all_dataScience_channels.csv', index=False)
