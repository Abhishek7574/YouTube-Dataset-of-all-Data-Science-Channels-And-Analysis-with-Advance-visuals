# %%
from googleapiclient.discovery import build

# %%
import pandas as pd

# %%
import numpy as np

# %%
api_key='AIzaSyBVBJR_UMhZVjcviHjCvgLU2LmVo0zzbWU'
channel_ids=['UCnz-ZXXER4jOvuED5trXfEA',  # tech TFQ
            'UC7cs8q-gJRlGwj4A8OmCmXg', #alex the analist
            'UCCWi3hpnq_Pe03nGxuS7isg', # campus X
            'UC8uU_wruBMHeeRma49dtZKA', # chando
            'UCh9nVJoWXmFb7sLApWGcLPQ', # code basics
            'UCcIXc5mJsHVYTZR1maL5l9w', # deeplearning
            'UCkndrGoNpUDV-uia6a9jwVg', # excelfun
            'UCFp1vaKzpfvoGai0vE5VJ0w', # guy in a cube
            'UCq6XkhO5SZ66N04IcPbqNcw', #keith galli
            'UCiT9RITQ9PW6BhXK0y2jaeg', #ken lee
            'UCfJT_eYDTmDE-ovKaxVE1ig', # kevin startvert
            'UCNU_lfiiWBdtULKOw6X0Dig', # krish naik
            'UCJtUOos_MwJa_Ewii-R3cJA', # Leila Gharani
            'UCLLw7jmFsvfIVaUFsLs8mlQ', # luke barousse
            'UC3rY5HOgbBvGmq7RnDfwF7A', # rishab mishra
            'UCxladMszXan-jfgzyeIMyvw', # rob mulla
            'UCfzlCWGWYyIQ0aLC5w48gBQ', # sentdex
            'UCW6TXMZ5Pq6yL6_k5NZ2e0Q', # Socratica
            'UCtYLUTtgS3k1Fg4y5tAhLbw', #StatQuest with Josh Starmer
            'UC7HYxRWmaNlJux-X7rNLZyw', # Tableau Tim
            'UCJQJAI7IjbLcpsjWdSzYz0Q', # Thu Vu data analytics
            'UC2UXDak6o7rBm23k3Vv5dww', # Tina Huang
            'UC0T6MVd3wQDB5ICAe45OxaQ', # wscube
            'UCXUPKJO5MZQN11PqgIvyuvQ', #Andrej Karpathy
            'UCChmJrVa8kDg05JfCmxpLRw', #Darshil Parmar
            'UC_lePY0Lm0E2-_IkYUWpI5A', #Dataquest
            'UC8butISFwT-Wl7EV0hUK0BQ', #freeCodeCamp.org 
            'UCSNeZleDn9c74yQc-EKnVTA', #Kaggle
            'UCHXa4OpASJEwrHrLeIzw7Yg', #Nicholas Renotte 
            'UCKq-lHnyradGRmFClX_ACMw', #Ryan Nolan Data
            'UCtYLUTtgS3k1Fg4y5tAhLbw', #StatQuest with Josh Starmer
             
             
            ]

youtube=build('youtube','v3',developerKey=api_key)

# %%
def get_channel_stats(youtube,channel_ids):
    all_data=[]
    request=youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response=request.execute()
    for i in range (len(response['items'])):
        data=dict(Channel_Name=response['items'][i]['snippet']['title'],
                  publishedAt=response['items'][i]['snippet']['publishedAt'],
                  channel_country=response['items'][i]['snippet'].get('country', 'N/A'),
                  Subscribers=response['items'][i]['statistics']['subscriberCount'],
                  Views=response['items'][i]['statistics']['viewCount'],
                  Total_videos=response['items'][i]['statistics']['videoCount'],
                  Playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
                  

    return all_data

# %%
channel_info=get_channel_stats(youtube,channel_ids)
channel_info
# Out:
# [{'Channel_Name': 'DeepLearningAI',
#   'publishedAt': '2017-08-22T22:27:58Z',
#   'channel_country': 'N/A',
#   'Subscribers': '310000',
#   'Views': '18481426',
#   'Total_videos': '431',
#   'Playlist_id': 'UUcIXc5mJsHVYTZR1maL5l9w'},
#  {'Channel_Name': 'Andrej Karpathy',
#   'publishedAt': '2013-09-07T08:21:13Z',
#   'channel_country': 'US',
#   'Subscribers': '479000',
#   'Views': '10314208',
#   'Total_videos': '15',
#   'Playlist_id': 'UUXUPKJO5MZQN11PqgIvyuvQ'},
#  {'Channel_Name': 'CampusX',
#   'publishedAt': '2019-04-17T19:32:35Z',
#   'channel_country': 'IN',
#   'Subscribers': '202000',
#   'Views': '21975147',
#   'Total_videos': '1184',
#   'Playlist_id': 'UUCWi3hpnq_Pe03nGxuS7isg'},
#  {'Channel_Name': 'Keith Galli',
#   'publishedAt': '2016-12-27T20:18:51Z',
#   'channel_country': 'US',
#   'Subscribers': '220000',
#   'Views': '15176356',
#   'Total_videos': '87',
#   'Playlist_id': 'UUq6XkhO5SZ66N04IcPbqNcw'},
#  {'Channel_Name': 'Krish Naik',
#   'publishedAt': '2012-02-11T04:05:06Z',
#   'channel_country': 'IN',
#   'Subscribers': '965000',
#   'Views': '99036206',
#   'Total_videos': '1915',
#   'Playlist_id': 'UUNU_lfiiWBdtULKOw6X0Dig'},
#  {'Channel_Name': 'Tina Huang',
#   'publishedAt': '2013-08-28T18:05:17Z',
#   'channel_country': 'US',
#   'Subscribers': '663000',
#   'Views': '31237414',
#   'Total_videos': '220',
#   'Playlist_id': 'UU2UXDak6o7rBm23k3Vv5dww'},
#  {'Channel_Name': 'Kevin Stratvert',
#   'publishedAt': '2007-01-08T00:08:18Z',
#   'channel_country': 'US',
#   'Subscribers': '3010000',
#   'Views': '419364337',
#   'Total_videos': '853',
#   'Playlist_id': 'UUfJT_eYDTmDE-ovKaxVE1ig'},
#  {'Channel_Name': 'Thu Vu data analytics',
#   'publishedAt': '2021-04-30T15:22:58.33437Z',
#   'channel_country': 'US',
#   'Subscribers': '233000',
#   'Views': '7848118',
#   'Total_videos': '86',
#   'Playlist_id': 'UUJQJAI7IjbLcpsjWdSzYz0Q'},
#  {'Channel_Name': 'techTFQ',
#   'publishedAt': '2020-06-13T05:20:37.182391Z',
#   'channel_country': 'MY',
#   'Subscribers': '302000',
#   'Views': '16627939',
#   'Total_videos': '136',
#   'Playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_Name': 'ExcelIsFun',
#   'publishedAt': '2008-02-16T03:31:10Z',
#   'channel_country': 'US',
#   'Subscribers': '1000000',
#   'Views': '154690361',
#   'Total_videos': '3698',
#   'Playlist_id': 'UUkndrGoNpUDV-uia6a9jwVg'},
#  {'Channel_Name': 'Nicholas Renotte',
#   'publishedAt': '2019-01-26T22:31:46Z',
#   'channel_country': 'AU',
#   'Subscribers': '264000',
#   'Views': '17642074',
#   'Total_videos': '307',
#   'Playlist_id': 'UUHXa4OpASJEwrHrLeIzw7Yg'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'publishedAt': '2022-02-12T14:28:29.641872Z',
#   'channel_country': 'IN',
#   'Subscribers': '260000',
#   'Views': '16211792',
#   'Total_videos': '88',
#   'Playlist_id': 'UU3rY5HOgbBvGmq7RnDfwF7A'},
#  {'Channel_Name': 'WsCube Tech',
#   'publishedAt': '2015-08-22T13:22:51Z',
#   'channel_country': 'IN',
#   'Subscribers': '3380000',
#   'Views': '289899346',
#   'Total_videos': '5223',
#   'Playlist_id': 'UU0T6MVd3wQDB5ICAe45OxaQ'},
#  {'Channel_Name': 'Chandoo',
#   'publishedAt': '2009-05-02T06:44:42Z',
#   'channel_country': 'NZ',
#   'Subscribers': '612000',
#   'Views': '48131812',
#   'Total_videos': '478',
#   'Playlist_id': 'UU8uU_wruBMHeeRma49dtZKA'},
#  {'Channel_Name': 'Luke Barousse',
#   'publishedAt': '2020-08-03T09:02:41.213077Z',
#   'channel_country': 'US',
#   'Subscribers': '442000',
#   'Views': '22104468',
#   'Total_videos': '158',
#   'Playlist_id': 'UULLw7jmFsvfIVaUFsLs8mlQ'},
#  {'Channel_Name': 'sentdex',
#   'publishedAt': '2012-12-16T20:49:11Z',
#   'channel_country': 'US',
#   'Subscribers': '1340000',
#   'Views': '114827523',
#   'Total_videos': '1254',
#   'Playlist_id': 'UUfzlCWGWYyIQ0aLC5w48gBQ'},
#  {'Channel_Name': 'Kaggle',
#   'publishedAt': '2011-10-25T02:57:52Z',
#   'channel_country': 'N/A',
#   'Subscribers': '142000',
#   'Views': '4258072',
#   'Total_videos': '379',
#   'Playlist_id': 'UUSNeZleDn9c74yQc-EKnVTA'},
#  {'Channel_Name': 'Darshil Parmar',
#   'publishedAt': '2021-04-13T14:01:35.850568Z',
#   'channel_country': 'IN',
#   'Subscribers': '135000',
#   'Views': '6279377',
#   'Total_videos': '152',
#   'Playlist_id': 'UUChmJrVa8kDg05JfCmxpLRw'},
#  {'Channel_Name': 'Ken Jee',
#   'publishedAt': '2014-02-28T14:58:24Z',
#   'channel_country': 'US',
#   'Subscribers': '260000',
#   'Views': '9007872',
#   'Total_videos': '287',
#   'Playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'},
#  {'Channel_Name': 'Ryan Nolan Data',
#   'publishedAt': '2023-05-17T11:37:25.800931Z',
#   'channel_country': 'N/A',
#   'Subscribers': '8870',
#   'Views': '311850',
#   'Total_videos': '153',
#   'Playlist_id': 'UUKq-lHnyradGRmFClX_ACMw'},
#  {'Channel_Name': 'Socratica',
#   'publishedAt': '2011-12-24T18:39:38Z',
#   'channel_country': 'US',
#   'Subscribers': '883000',
#   'Views': '59463483',
#   'Total_videos': '661',
#   'Playlist_id': 'UUW6TXMZ5Pq6yL6_k5NZ2e0Q'},
#  {'Channel_Name': 'Dataquest',
#   'publishedAt': '2019-01-30T18:36:22Z',
#   'channel_country': 'US',
#   'Subscribers': '57600',
#   'Views': '2094609',
#   'Total_videos': '50',
#   'Playlist_id': 'UU_lePY0Lm0E2-_IkYUWpI5A'},
#  {'Channel_Name': 'codebasics',
#   'publishedAt': '2015-11-07T17:29:46Z',
#   'channel_country': 'US',
#   'Subscribers': '1030000',
#   'Views': '85377780',
#   'Total_videos': '876',
#   'Playlist_id': 'UUh9nVJoWXmFb7sLApWGcLPQ'},
#  {'Channel_Name': 'Leila Gharani',
#   'publishedAt': '2015-08-11T10:54:25Z',
#   'channel_country': 'AT',
#   'Subscribers': '2620000',
#   'Views': '252951023',
#   'Total_videos': '584',
#   'Playlist_id': 'UUJtUOos_MwJa_Ewii-R3cJA'},
#  {'Channel_Name': 'Tableau Tim',
#   'publishedAt': '2010-04-05T00:58:32Z',
#   'channel_country': 'GB',
#   'Subscribers': '166000',
#   'Views': '3991061',
#   'Total_videos': '514',
#   'Playlist_id': 'UU7HYxRWmaNlJux-X7rNLZyw'},
#  {'Channel_Name': 'Alex The Analyst',
#   'publishedAt': '2020-01-08T05:04:24.970712Z',
#   'channel_country': 'US',
#   'Subscribers': '791000',
#   'Views': '35220047',
#   'Total_videos': '307',
#   'Playlist_id': 'UU7cs8q-gJRlGwj4A8OmCmXg'},
#  {'Channel_Name': 'freeCodeCamp.org',
#   'publishedAt': '2014-12-16T21:18:48Z',
#   'channel_country': 'US',
#   'Subscribers': '9560000',
#   'Views': '721145314',
#   'Total_videos': '1668',
#   'Playlist_id': 'UU8butISFwT-Wl7EV0hUK0BQ'},
#  {'Channel_Name': 'Guy in a Cube',
#   'publishedAt': '2014-12-03T13:23:39Z',
#   'channel_country': 'US',
#   'Subscribers': '431000',
#   'Views': '35622493',
#   'Total_videos': '1041',
#   'Playlist_id': 'UUFp1vaKzpfvoGai0vE5VJ0w'},
#  {'Channel_Name': 'Rob Mulla',
#   'publishedAt': '2021-09-26T18:25:56.754723Z',
#   'channel_country': 'US',
#   'Subscribers': '170000',
#   'Views': '11611309',
#   'Total_videos': '157',
#   'Playlist_id': 'UUxladMszXan-jfgzyeIMyvw'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'publishedAt': '2011-05-24T01:52:48Z',
#   'channel_country': 'US',
#   'Subscribers': '1180000',
#   'Views': '65604611',
#   'Total_videos': '277',
#   'Playlist_id': 'UUtYLUTtgS3k1Fg4y5tAhLbw'}]

# %%
channel_data=pd.DataFrame(channel_info)

# %%
channel_data
# Out:
#                    Channel_Name                  publishedAt channel_country  \
# 0                DeepLearningAI         2017-08-22T22:27:58Z             N/A
# 1               Andrej Karpathy         2013-09-07T08:21:13Z              US
# 2                       CampusX         2019-04-17T19:32:35Z              IN
# 3                   Keith Galli         2016-12-27T20:18:51Z              US
# 4                    Krish Naik         2012-02-11T04:05:06Z              IN
# 5                    Tina Huang         2013-08-28T18:05:17Z              US
# 6               Kevin Stratvert         2007-01-08T00:08:18Z              US
# 7         Thu Vu data analytics   2021-04-30T15:22:58.33437Z              US
# 8                       techTFQ  2020-06-13T05:20:37.182391Z              MY
# 9                    ExcelIsFun         2008-02-16T03:31:10Z              US
# 10             Nicholas Renotte         2019-01-26T22:31:46Z              AU
# 11               Rishabh Mishra  2022-02-12T14:28:29.641872Z              IN
# 12                  WsCube Tech         2015-08-22T13:22:51Z              IN
# 13                      Chandoo         2009-05-02T06:44:42Z              NZ
# 14                Luke Barousse  2020-08-03T09:02:41.213077Z              US
# 15                      sentdex         2012-12-16T20:49:11Z              US
# 16                       Kaggle         2011-10-25T02:57:52Z             N/A
# 17               Darshil Parmar  2021-04-13T14:01:35.850568Z              IN
# 18                      Ken Jee         2014-02-28T14:58:24Z              US
# 19              Ryan Nolan Data  2023-05-17T11:37:25.800931Z             N/A
# 20                    Socratica         2011-12-24T18:39:38Z              US
# 21                    Dataquest         2019-01-30T18:36:22Z              US
# 22                   codebasics         2015-11-07T17:29:46Z              US
# 23                Leila Gharani         2015-08-11T10:54:25Z              AT
# 24                  Tableau Tim         2010-04-05T00:58:32Z              GB
# 25             Alex The Analyst  2020-01-08T05:04:24.970712Z              US
# 26             freeCodeCamp.org         2014-12-16T21:18:48Z              US
# 27                Guy in a Cube         2014-12-03T13:23:39Z              US
# 28                    Rob Mulla  2021-09-26T18:25:56.754723Z              US
# 29  StatQuest with Josh Starmer         2011-05-24T01:52:48Z              US
#
#    Subscribers      Views Total_videos               Playlist_id
# 0       310000   18481426          431  UUcIXc5mJsHVYTZR1maL5l9w
# 1       479000   10314208           15  UUXUPKJO5MZQN11PqgIvyuvQ
# 2       202000   21975147         1184  UUCWi3hpnq_Pe03nGxuS7isg
# 3       220000   15176356           87  UUq6XkhO5SZ66N04IcPbqNcw
# 4       965000   99036206         1915  UUNU_lfiiWBdtULKOw6X0Dig
# 5       663000   31237414          220  UU2UXDak6o7rBm23k3Vv5dww
# 6      3010000  419364337          853  UUfJT_eYDTmDE-ovKaxVE1ig
# 7       233000    7848118           86  UUJQJAI7IjbLcpsjWdSzYz0Q
# 8       302000   16627939          136  UUnz-ZXXER4jOvuED5trXfEA
# 9      1000000  154690361         3698  UUkndrGoNpUDV-uia6a9jwVg
# 10      264000   17642074          307  UUHXa4OpASJEwrHrLeIzw7Yg
# 11      260000   16211792           88  UU3rY5HOgbBvGmq7RnDfwF7A
# 12     3380000  289899346         5223  UU0T6MVd3wQDB5ICAe45OxaQ
# 13      612000   48131812          478  UU8uU_wruBMHeeRma49dtZKA
# 14      442000   22104468          158  UULLw7jmFsvfIVaUFsLs8mlQ
# 15     1340000  114827523         1254  UUfzlCWGWYyIQ0aLC5w48gBQ
# 16      142000    4258072          379  UUSNeZleDn9c74yQc-EKnVTA
# 17      135000    6279377          152  UUChmJrVa8kDg05JfCmxpLRw
# 18      260000    9007872          287  UUiT9RITQ9PW6BhXK0y2jaeg
# 19        8870     311850          153  UUKq-lHnyradGRmFClX_ACMw
# 20      883000   59463483          661  UUW6TXMZ5Pq6yL6_k5NZ2e0Q
# 21       57600    2094609           50  UU_lePY0Lm0E2-_IkYUWpI5A
# 22     1030000   85377780          876  UUh9nVJoWXmFb7sLApWGcLPQ
# 23     2620000  252951023          584  UUJtUOos_MwJa_Ewii-R3cJA
# 24      166000    3991061          514  UU7HYxRWmaNlJux-X7rNLZyw
# 25      791000   35220047          307  UU7cs8q-gJRlGwj4A8OmCmXg
# 26     9560000  721145314         1668  UU8butISFwT-Wl7EV0hUK0BQ
# 27      431000   35622493         1041  UUFp1vaKzpfvoGai0vE5VJ0w
# 28      170000   11611309          157  UUxladMszXan-jfgzyeIMyvw
# 29     1180000   65604611          277  UUtYLUTtgS3k1Fg4y5tAhLbw

# %%
channel_name = channel_data['Channel_Name'].tolist()

# %%
channel_name
# Out:
# ['DeepLearningAI',
#  'Andrej Karpathy',
#  'CampusX',
#  'Keith Galli',
#  'Krish Naik',
#  'Tina Huang',
#  'Kevin Stratvert',
#  'Thu Vu data analytics',
#  'techTFQ',
#  'ExcelIsFun',
#  'Nicholas Renotte',
#  'Rishabh Mishra',
#  'WsCube Tech',
#  'Chandoo',
#  'Luke Barousse',
#  'sentdex',
#  'Kaggle',
#  'Darshil Parmar',
#  'Ken Jee',
#  'Ryan Nolan Data',
#  'Socratica',
#  'Dataquest',
#  'codebasics',
#  'Leila Gharani',
#  'Tableau Tim',
#  'Alex The Analyst',
#  'freeCodeCamp.org',
#  'Guy in a Cube',
#  'Rob Mulla',
#  'StatQuest with Josh Starmer']

# %%
channel_data.dtypes
# Out:
# Channel_Name       object
# publishedAt        object
# channel_country    object
# Subscribers        object
# Views              object
# Total_videos       object
# Playlist_id        object
# dtype: object

# %%
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']=pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']=pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
# Out:
# Channel_Name       object
# publishedAt        object
# channel_country    object
# Subscribers         int64
# Views               int64
# Total_videos        int64
# Playlist_id        object
# dtype: object

# %% [markdown]
# ## function to get videos ids

# %%
playlist_id2 = channel_data['Playlist_id'].tolist()

# %%
playlist_id2
# Out:
# ['UUcIXc5mJsHVYTZR1maL5l9w',
#  'UUXUPKJO5MZQN11PqgIvyuvQ',
#  'UUCWi3hpnq_Pe03nGxuS7isg',
#  'UUq6XkhO5SZ66N04IcPbqNcw',
#  'UUNU_lfiiWBdtULKOw6X0Dig',
#  'UU2UXDak6o7rBm23k3Vv5dww',
#  'UUfJT_eYDTmDE-ovKaxVE1ig',
#  'UUJQJAI7IjbLcpsjWdSzYz0Q',
#  'UUnz-ZXXER4jOvuED5trXfEA',
#  'UUkndrGoNpUDV-uia6a9jwVg',
#  'UUHXa4OpASJEwrHrLeIzw7Yg',
#  'UU3rY5HOgbBvGmq7RnDfwF7A',
#  'UU0T6MVd3wQDB5ICAe45OxaQ',
#  'UU8uU_wruBMHeeRma49dtZKA',
#  'UULLw7jmFsvfIVaUFsLs8mlQ',
#  'UUfzlCWGWYyIQ0aLC5w48gBQ',
#  'UUSNeZleDn9c74yQc-EKnVTA',
#  'UUChmJrVa8kDg05JfCmxpLRw',
#  'UUiT9RITQ9PW6BhXK0y2jaeg',
#  'UUKq-lHnyradGRmFClX_ACMw',
#  'UUW6TXMZ5Pq6yL6_k5NZ2e0Q',
#  'UU_lePY0Lm0E2-_IkYUWpI5A',
#  'UUh9nVJoWXmFb7sLApWGcLPQ',
#  'UUJtUOos_MwJa_Ewii-R3cJA',
#  'UU7HYxRWmaNlJux-X7rNLZyw',
#  'UU7cs8q-gJRlGwj4A8OmCmXg',
#  'UU8butISFwT-Wl7EV0hUK0BQ',
#  'UUFp1vaKzpfvoGai0vE5VJ0w',
#  'UUxladMszXan-jfgzyeIMyvw',
#  'UUtYLUTtgS3k1Fg4y5tAhLbw']

# %%
def get_video_ids(youtube, playlist_ids):
    all_video_ids = []
    
    for playlist_id in playlist_ids:
        video_ids = []
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50)
        response = request.execute()
        
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        more_pages = True

        while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)
                response = request.execute()
                for item in response['items']:
                    video_ids.append(item['contentDetails']['videoId'])
                next_page_token = response.get('nextPageToken')
        
        all_video_ids.extend(video_ids)
    
    return all_video_ids

# %%
video_ids=get_video_ids(youtube,playlist_id2)

# %%
video_ids
# Out:
# ['6gnvm-8NEmA',
#  'EqEXTGot2xs',
#  'TBNTH-fwGPE',
#  'gzEENWPRf6Q',
#  'Zt2HRp9F5YQ',
#  'n5yiUW0wSzA',
#  'd3WiKofD-34',
#  'QtEUU9ppVLU',
#  'xtWsNDG8RSw',
#  'KE7iHWzyc3A',
#  'oGbD5lguxQA',
#  '5XHar8yjp_U',
#  'tcBYaZqdc4A',
#  'R1rF7_tyeqU',
#  'tHyPr9Faoig',
#  'npAcymuDmeA',
#  'aNVxdfFLNhM',
#  'K6Wui3mn-uI',
#  'XBnt68VV_1E',
#  'jMKRUo4wVKA',
#  'fo0F-DAum7E',
#  'Y9zudBWSkEE',
#  'eOac-VZRnNw',
#  'njN_Wu8dLfE',
#  'AIILR27LoSg',
#  'QXVCqtAZAn4',
#  'e1ZX0YvtkIM',
#  'Ep7uaxwN-mQ',
#  'f32dc5M2Mn0',
#  'tabmG21y290',
#  'OZn_M3qQOw4',
#  'kH4ZoZSvddM',
#  'ewfTtQUvfJU',
#  'L8B_g2JOQAs',
#  'Z5HurHL2fWc',
#  '0pnEUAwoDP0',
#  '3vtN-q9F9-0',
#  'AMBeN5vDwcU',
#  'H_8ZVRRtiIA',
#  'hkOosfWxBK4',
#  'AmlhNK9_I4o',
#  '3WUobZryyok',
#  'AlQCf2iYWCg',
#  'dfeoJ55EcXs',
#  'u1pNrsR1txA',
#  'Foc4kUd0k7M',
#  '8-wzjpZA2sc',
#  'O80XSQrfyGA',
#  'Z8GILwqeSXE',
#  'zCXf3amN08I',
#  '4xYos-CvkIY',
#  'g68qlo9Izf0',
#  '9PxhCekQYNI',
#  'Sh4n0uk-NHk',
#  '7EcznH0-of8',
#  '-0pvrCLd2Ak',
#  'UHFTY0B718s',
#  '7Pn_eEwoGtw',
#  'XCmQv0_S3oo',
#  'e97qoWit_bw',
#  'Ee8EOWWGJ7U',
#  'j2iN4xrrvi8',
#  '_xuz5daI64Y',
#  'ulClsulw8fs',
#  'rOmuRwYFSHs',
#  'Yhp8MbOvU7o',
#  'VnPjmB0Newc',
#  'PQfKE8HucGU',
#  'Dmw_-1Yh22g',
#  '3eJZzSl6I4g',
#  'DesR0-kGZ-k',
#  '4Kq39nLkwRE',
#  '-YehDP8LmmM',
#  'RGJE32ZyLoI',
#  '1X9cLvqOPhg',
#  'oRAhTejbtLg',
#  'cipk6Zgmdlg',
#  'HLVCvVEhzf4',
#  'Fxq6vjJwX3o',
#  'IESLSRTrMtk',
#  'OFirYUUnU2o',
#  'CLwssCapvAI',
#  'lIHtE_AKyyw',
#  'yf-VbOEwNWg',
#  'OTu7yNMmSj0',
#  'T1i5m_9-YoE',
#  '9CAKuAzyO7Y',
#  'v4xA2JYO8MI',
#  '7M5o9FO1t7k',
#  'eZZwySXsj-g',
#  'OIavgUGg7mc',
#  'bZwkaVnhEo4',
#  '4fkqXdcTmGk',
#  'fo7bD-NgA4Y',
#  '3CHB3_Q6GkA',
#  'eTieetk2dSw',
#  'BunESRhYhec',
#  'jFo_gDOOusk',
#  'obdVesVsGQI',
#  'H4YK_7MAckk',
#  'BY9KV8uCtj4',
#  'axkCZqngOSc',
#  'g7dv-Lnuor4',
#  'ChGx_wK7VaE',
#  'rt0uNjjBya4',
#  '_BZGtifh_gw',
#  'Se9tuEG-dmc',
#  'NhZXRzH2y-E',
#  'jhrrw8Iuus0',
#  'NIiZZY7nlfU',
#  '1kgcON0Eauc',
#  '8upNQi-40Q8',
#  '6SZUnXEHCns',
#  'YkTcK_LXAxw',
#  'vq4Ie5xWhww',
#  '0az8RjxLLPQ',
#  'xuTiAW0OR40',
#  'p-ltr1C7u2o',
#  'IFkRKJ5iBDE',
#  'ecOdZlY9jsQ',
#  'P_9hNBVRldM',
#  '5g4H5_gsTpU',
#  'gmJqLGrUscg',
#  'YVtP5UGdgXg',
#  'YjpCQof9tI8',
#  'uvTL1N02f04',
#  'U6zuBcmLxSg',
#  'jXg0vU0y1ak',
#  'tHDDbqYfflM',
#  'RGL_XUjPkGo',
#  'k0h8emRAAHE',
#  'PKm61nrqpCA',
#  'w_2vCijLiiM',
#  'WtlvKq_zxPI',
#  'L5INhX5cbWU',
#  'bFNz2u0hl9E',
#  'peNRqkfukYY',
#  'CFN5zHzEuGY',
#  'KWULpBYzIYk',
#  'dLc-lfEEYss',
#  '6dTL76DWYQU',
#  '_0bhZBqtCCs',
#  'gG_wI_uGfIE',
#  'hh6gE0LxfO8',
#  'sca5rQ9x1cA',
#  'XtlwSmJfUs4',
#  'wiNXzydta4c',
#  'vStJoetOxJg',
#  'ctpl3PMU-B4',
#  'Mk-KFP0r3oM',
#  'f-xGecL2H2w',
#  '4pkzY95Otm4',
#  'x6e6V3ybasw',
#  'D1W0kS40otM',
#  '0ZSLRLMaDN4',
#  'GK03Wje5Wi8',
#  'fiDmWKh_WeQ',
#  'O5mqR4EFBQk',
#  '8Covj8F-NNc',
#  'quEHyoA94rw',
#  'BdZ6bjcixhk',
#  'BlxnbyvHTyI',
#  'o4je1lSpyaw',
#  'k3UYUmp3Bi4',
#  'uot5sbPz1NQ',
#  'O9ZrPXPLmWg',
#  'foCIxwn7VpI',
#  'DTd7TyY7a-0',
#  'A2bnWAIpLIo',
#  'qOEeK1SNF3k',
#  '0aDhjrs8FMw',
#  'mzv1mkJRA10',
#  's5qFpEPNXEY',
#  'f5sN3xAEAWQ',
#  'a-oCxdzFapE',
#  'eW546hpa744',
#  'Ny970B12IQk',
#  'qt9tXjtlQt4',
#  'gz-44N3MMOA',
#  'hbqxEJisBHo',
#  'mFD5hUZubTI',
#  'UEMMOdFbT94',
#  '43CZ0HjIC7U',
#  'opWrnW5v25w',
#  'CEBwVqRdKWc',
#  '9p7WWapTrpA',
#  'oBB47VrQucA',
#  'lHXd2hBnlJk',
#  '79UqdjnPEZ0',
#  'hq_XyP9y0xg',
#  'ErNp43wcudY',
#  'UyEtTyeahus',
#  '1zhmudvZAs4',
#  'YJsRD_hU4tc',
#  'e69ZWbbsGng',
#  'NgWujOrCZFo',
#  'NJaVkJDrBCc',
#  '3WaqixS_yO0',
#  'ExMG-9-ridg',
#  'FCB0Qt2bnFw',
#  'EOpTXhGMloo',
#  'pVNmIV4F8ug',
#  'zLIyvg4zCos',
#  'tyn1AFeKv2I',
#  'M3S-8qMr_D4',
#  'bAn_m51ysNE',
#  'xqdgrrXGHKo',
#  'MR1KzFSlRQY',
#  'eu88EsQZQI0',
#  'vKn7f7uryes',
#  'fkB6NySGvGY',
#  '4Gq9E7m98xs',
#  '7xkDGdnRLTQ',
#  'YMCPq8gfUxA',
#  'D9hY8pZe7hk',
#  'ClMb3dvfom8',
#  'vf_5V_MZk6c',
#  'Yqj7Kyjznh4',
#  'A0ADFiiZU0k',
#  'Ta14KpeZJok',
#  'g9xvE0vWIkU',
#  'WyHPyWrvAts',
#  'XVkLL9eq8sk',
#  'gXluw4FxfKg',
#  'xvhOZLMaquY',
#  '06-AZXmwHjo',
#  'V56izzKDorU',
#  'pfmvIsmcvv0',
#  'U2nXlwCwuO4',
#  'kk6rh45r0fo',
#  '4Ai7wmUGFNA',
#  'QSLh7CUEfXA',
#  '_wxSoMmqnkg',
#  '4xIu4afZ4gY',
#  '_pDASRZSuH4',
#  'az7Og6k_-3o',
#  '3aL3J5tlw7s',
#  '1-8W6z4wBJU',
#  'uxEGdlO3YRY',
#  'vMnBE9FF9vg',
#  '7BNFJ2Fc-P8',
#  'u1VJdicsPEE',
#  '-LjJO5trqdA',
#  'V9fjtkPWD4E',
#  'H343JRrncfc',
#  'PiF2Aln-L3w',
#  'KGI7K_ehHsU',
#  'DffGdrfY9gI',
#  '9d4jmPmTWmc',
#  'SzAmGg2TVBg',
#  'Rp7qqjlBeRY',
#  'dvnsbOtAmYI',
#  'oJ2FL5BsFuQ',
#  '6dQgPFaZMGQ',
#  'zGFKSQlef_0',
#  'JtDQkaTXC0A',
#  '_YcAEBnbtPQ',
#  '6joSL0CUNtA',
#  'R2vIYVdMzPc',
#  'y2v1-u6t5eQ',
#  'V4gmRuYPtLA',
#  'y7RfAwltHTw',
#  'qvT3NyaycoA',
#  'cI6WLiujJDY',
#  'oCE3QLmize4',
#  '7VHsWChH27g',
#  'nbfJ23FxvuI',
#  'wlQvPJHxfOE',
#  'j2nGxw8sKYU',
#  '69dr4090Y-Q',
#  'U1bIc6pFdw4',
#  'eMh5YqKopjE',
#  'JS12eb1cTLE',
#  'quoGRI-1l0A',
#  'vm2SI8AJY0s',
#  'DejHQYAGb7Q',
#  'Er2ucMxjdHE',
#  'RLWuzLLSIgw',
#  'SysgYptB198',
#  'ZGUZwk7xIwk',
#  'Zqx_hbTmN6A',
#  '_i3aqgKVNQI',
#  'gb__z7LlN_4',
#  'y_-Gh3iARJM',
#  '-FfMVnwXrZ0',
#  '0NSLgoEtdnw',
#  '6jfw8MuKwpI',
#  '96b_weTZb2w',
#  'ChoV5h7tw5A',
#  'Cn8AtS-9Nwc',
#  'QgkLfjfGul8',
#  'R39tWYYKNcI',
#  'b1I5X3UfEYI',
#  'd2XB5-tuCWU',
#  'xY-DMAJpIP4',
#  '5e5pjeojznk',
#  '6ykvU9WuIws',
#  '9s_FpMpdYW8',
#  'ANIzQ5G-XPE',
#  'GSwYGkTfOKk',
#  'RTlwl2bv0Tg',
#  'VAo84c1hQX8',
#  'XdsmlBGOK-k',
#  'rRB9iymNy1w',
#  '-bvTzZCEOdM',
#  'C86ZXvgpejM',
#  'FQM13HkEfBk',
#  'JI8saFjK84o',
#  'KfV8CJh7hE0',
#  'RYth6EbBUqM',
#  'ZILIbUvp5lk',
#  'c1RBQzKsDCk',
#  'c3zw6KI6dLc',
#  'cFFu__mcoIw',
#  'dZVkygnKh1M',
#  '3PyJA9AfwSk',
#  '8oOgPUO-TBY',
#  'ArPaAX_PhIs',
#  'KTB_OFoAQcc',
#  'XuD4C8vJzEQ',
#  'am36dePheDc',
#  'ay3zYUeuyhU',
#  'bXJx7y51cl0',
#  'jPOAS7uCODQ',
#  'smHa2442Ah4',
#  'tQYZaDn_kSg',
#  'HfM8UIohGE0',
#  'sfk5h0yC67o',
#  'JoAxZsdw_3w',
#  'jyjJ-RpQ5zQ',
#  'dM0exrbVZ08',
#  'zg26t-BH7ao',
#  'CZf3oo0fuh0',
#  'NUmbgp1h64E',
#  'J3HHOwcrkK8',
#  'DFUqMbWs5d8',
#  '_Fe5kKmFieg',
#  'BH9mlmdXzzI',
#  'M3qpIzy4MQk',
#  'UEtvV1D6B3s',
#  'sofffBNhVSo',
#  'dFX8k1kXhOw',
#  '2BkqApHKwn0',
#  'GzphoJOVEcE',
#  'nJyUyKN-XBQ',
#  'okpqeEUdEkY',
#  'SHEPb1JHw5o',
#  'hCP1vGoCdYU',
#  'hjrYrynGWGA',
#  'k_S5fnKjO-4',
#  'uJryes5Vk1o',
#  '0S9c7nHoDws',
#  '5H7M5Vd3-pk',
#  'eqEc66RFY0I',
#  'pYWASRauTzs',
#  'KKfZLXcF-aE',
#  'V2QlTmh6P2Y',
#  'qsIrQi0fzbY',
#  'tKcLaGdvabM',
#  'xflCLdJh0n0',
#  'ysnIDax71yY',
#  'BYGpKPY9pO0',
#  'z_xiwjEdAC4',
#  'n1l-9lIMW7E',
#  'CS4cs9xVecg',
#  '7AZjh2VXD6E',
#  'l_-CUyEx_x4',
#  'ImUoubi_t7s',
#  'UdXfsAr4Gjw',
#  'sn_QSB7T1xo',
#  'yofjFQddwHE',
#  '2BH49JG_sTs',
#  '6g0t3Phly2M',
#  'NyG-7nRpsW8',
#  'C1N_PDHuJ6Q',
#  'SjQyLhQIXSM',
#  'a8i2eJin0lY',
#  's2coXdufOzE',
#  'y1xoI7mBtOc',
#  '2zgon7XfN4I',
#  'D8PJAL-MZv8',
#  'qhXZsFVxGKo',
#  '1waHlpKiNyY',
#  '2gw5tE2ziqA',
#  '6by6Xas_Kho',
#  'BOCLq2gpcGU',
#  'FDCfw-YqWTE',
#  'P7_jFxTtJEo',
#  'VTE2KlfoO3Q',
#  'xy5MOQpx3aQ',
#  'ARq74QuavAo',
#  'B7-iPbddhsw',
#  'NkOv_k7r6no',
#  'rMOdrD61IoU',
#  'yXcQ4B-YSjQ',
#  '5dWp1mw_XNk',
#  '7bLEWDZng_M',
#  'CcRkHl75Z-Y',
#  'S9ElPZupUsE',
#  'Xvg00QnyaIY',
#  'kkWRbIb42Ms',
#  'yslMo3hSbqE',
#  'AK6r-llqogg',
#  'fXOsFF95ifk',
#  'ueO_Ph0Pyqk',
#  'LLux1SW--oM',
#  '5qefnAek8OA',
#  'nUUqwaxLnWs',
#  'JXQT_vxqwIs',
#  '_e-LFe_igno',
#  'em6dfRxYkYU',
#  'k8fTYJPd3_I',
#  'tNIpEZLv_eg',
#  'wKkcBPp3F1Y',
#  'AXDByU3D1hA',
#  'NxTFlzBjS-4',
#  'lWzo8CajF5s',
#  '-_4Zi8fCZO4',
#  '4qJaSmvhxi8',
#  'fODpu1-lNTw',
#  'lAq96T8FkTw',
#  '4Ct3Yujl1dk',
#  'QzulmoOg2JE',
#  'QrzApibhohY',
#  'cSoK_6Rkbfg',
#  'xxu4IqwKw0w',
#  'LpAiPYNnxW0',
#  'dqwx-F7Eits',
#  'OT91E6_Qm1A',
#  'oJFShOfCZiA',
#  'dwFcodBz_2I',
#  'qzPQ8cEsVK8',
#  'l8pRSuU81PU',
#  'zduSFxRajkE',
#  'zjkBMFhNj_g',
#  'kCc8FmEb1nY',
#  't3YJ5hKiMQ0',
#  'q8SA3rM6ckI',
#  'P6sfmUTpUmc',
#  'TCH_1BHY58I',
#  'PaCmpygFfXo',
#  'kVpDARqZdrQ',
#  '2oKjtvYslMY',
#  'sM9bozW295Q',
#  'VMj-3S1tku0',
#  'vEnetcj_728',
#  'Jv1ayv-04H4',
#  'd4qykFC5Rso',
#  'qti0QPdaelg',
#  '8AESphhLlwo',
#  'GeoQBNNqIbM',
#  'oozXqbNDzBw',
#  '8Us9DXb88Uc',
#  'yh2AKoJCV3k',
#  'bTLaTvbi9vM',
#  'bX2QwpjsmuA',
#  'OR24M5ns-YY',
#  'nu0Ny79JRN4',
#  'nV2ovzlBcL4',
#  'zghjRYt8bcM',
#  'o4ZVA0TuDRg',
#  '5ZgGuujZSbs',
#  'r7mAt0iVqwo',
#  'lbR3jQsenWk',
#  'YyFuIubbqpo',
#  '-tCKPl_8Xb8',
#  'XnGGmvpDLA0',
#  'UDuyRAbIvY8',
#  'BjRVS2wTtcA',
#  'o4g4OTyCyDM',
#  '0hZT4_fHfNQ',
#  '6SRifO6dmuE',
#  'H4fZ3HFv684',
#  'CAlfPNOkweQ',
#  'rj5V6q6-XUM',
#  '1_bLnsNmhCI',
#  'KiL74WsgxoA',
#  '_J7HzClh4mo',
#  'FkZQGhCzROk',
#  '0Eo-_5bfers',
#  '8fX3rOjTloc',
#  'mELtxVUNNrw',
#  'a0pa3cLFyic',
#  'ToU414wge1k',
#  'rPteUQ_3gxI',
#  'k2NSm3MNdYg',
#  'gmp2tS2joaA',
#  'mlDkTrlLaio',
#  'C6aDw4y8qJ0',
#  'QQfZAoNGQmE',
#  'gQzHDZCle24',
#  'fiqo6uPCJVI',
#  'Akv3poqqwI4',
#  'z7IPBg6MyrU',
#  '4p5EQtyxSyI',
#  'Cs88FbH9sSU',
#  'RpeE2r5QEps',
#  '1jZm-9HNxGk',
#  'QBFVcBXRzu4',
#  'venF37V3AaU',
#  'rIsCKVyh4dI',
#  '2GV_ouHBw30',
#  'ndHDsvqmbuI',
#  'DUT4WEUngt0',
#  'gdW6hj9IXaA',
#  'HkDe1sqS8yw',
#  'abnL_GUGub4',
#  '5xWjleyItSY',
#  '6-1WiITAW10',
#  'hRTe7tSkR2k',
#  'XGJLWJ0a6aU',
#  'CyFW7wn41qk',
#  '5Y4pWR1P8G0',
#  'e_9vJXokd-Y',
#  'aEPoLeS6UMM',
#  '1ctqJCHMAmc',
#  'mQewAJb8oJ8',
#  'xHTMjxx14sU',
#  'S94mx6OL7kM',
#  'O0omBfGHYfs',
#  'X52HK2qkiIE',
#  '-WmJDYBor7c',
#  'U6QCc_3zgUk',
#  'ADqYqSdtyW8',
#  'C_QAURbgBqY',
#  '1ndVC500-EU',
#  'Uv3Blie7F3g',
#  'hysPNdlpXpI',
#  'e0HQVOdfqlQ',
#  'YgizUxmBFK8',
#  '3LJ-yWBQBGs',
#  'YYq47MN3TZI',
#  's6xAVqYdmJ4',
#  'nsKcmOly0UY',
#  'kzMZDlvHFak',
#  'ny1mh6VUpnQ',
#  'CTLwYjh92xw',
#  'PPEHpg2RixQ',
#  '0m1dXTy8IpE',
#  '5v8oTYGbh8M',
#  '-HnN8GBINnc',
#  'dA6ZksRR6aw',
#  'kLWeKeqc9Ms',
#  'f9Aje_cN_CY',
#  'DWVLRhnuGqI',
#  '7YDc5xU9CQQ',
#  'BfzoFMSzb3o',
#  'XaKn_cKFlSY',
#  'mxp2r2msfC4',
#  'UE6DmRQJ2w8',
#  'QzoRUwz8DoM',
#  'kjX6eIuTV5Y',
#  'Ssy1EfK5S-o',
#  'LPBjF4_gZnI',
#  'AWHSZzp96kM',
#  'zTa4MIrGTIE',
#  'OG31yhRQxPI',
#  '80QpbZA38HA',
#  'zCDVUyq8lkw',
#  'jFBpnd0G09o',
#  '40xGMygHMDU',
#  '0W_Xcz_wevM',
#  'XF6DCrNTzug',
#  'K_2AdybCEMY',
#  'OvCz1acvt-k',
#  '5pLs7Mtcw6Y',
#  'aMARZGTbULc',
#  'rvKR6tciJ2Q',
#  'o-TAYRMQzIQ',
#  'O-NrQvtorp0',
#  'TkeG4Jnd86U',
#  'bEWwM4hXZg8',
#  'P4xizq3CiJg',
#  'Trvqq5w7-0Q',
#  'jENsMMbN7Wc',
#  'TkOBxzhIySg',
#  'OOInK25PoFo',
#  'jcQjp11mn1A',
#  'WmbU3WBaoR0',
#  'vg7BRC7wd0c',
#  '7ltjqU5iytY',
#  '6HAu0Y9BjA4',
#  'JgnbwKnHMZQ',
#  'JCkIrdrZEE8',
#  '1z5-O7-5AXk',
#  'FrWzyQQCcJE',
#  'BjWqCcbusMM',
#  'scRY0O_cIPU',
#  '4KpRP-YUw6c',
#  'QAvlMMboGSA',
#  'OvQQP1QVru8',
#  'WWcgHjuKVqA',
#  'WJysB1RK2vM',
#  '0MVXteg7TB4',
#  'ESTydJQ-SuU',
#  'g4Npa_AE2TE',
#  'sM2C-SsREgM',
#  '0K4J_PTgysc',
#  'OoSDzOodY3Y',
#  'H5Mb0zWWSMk',
#  'RvCCFttGFMY',
#  'niE5DRKvD_E',
#  'd5luiaJxHcw',
#  'ewsvsJQOuTI',
#  'DwmGefkowCU',
#  'h_F7EsExE4M',
#  '3rf_yPux9b8',
#  'btWE6SsdDZA',
#  'DRXYOfbksGE',
#  'cgJx3GvQ5y8',
#  'OZXeAme3694',
#  'aslTGS9ef98',
#  'hDVFXf74P-U',
#  'oYnyNLj8RMA',
#  'qWjx-XdZLjk',
#  'N5AynalXD9g',
#  'p0wSmKslWi0',
#  'nqL9xYmhEpg',
#  'dtWag57PRDk',
#  'IdJL9rcQrFU',
#  'rKG9E6rce1c',
#  'HDST_IenJU4',
#  'FkTN6yw1S54',
#  'vVS4csXRlcQ',
#  'jAqVuYJ8TP8',
#  'F-HRiwlqPDU',
#  '3x81gGRQjwM',
#  'tbpBW5Yr44k',
#  'DLcBjo5gIxs',
#  'iCTTnQJn50E',
#  'zdIQkjtFX_I',
#  '2AscwXePInA',
#  'sVJW5UXe84s',
#  '4l1-i7_gGVQ',
#  'TXVtbgaEyms',
#  'BuuijIa7MZ8',
#  'bEfjDSSZ4wQ',
#  'E5wVPKJkwCg',
#  'Bwsp-ffCmcw',
#  'etk-4thyX7E',
#  '2RnuvkOMnsA',
#  'EjmbcroSC0Q',
#  'l01Y1DXRtmg',
#  'QoQoRsn17Qo',
#  'ek9qrl0-MuU',
#  'm9UaxSQJQGQ',
#  'WwgHS0vphNo',
#  'SB5CnzmeH_w',
#  '1pIrDi6puGs',
#  '9sEiMp8bCnY',
#  '_XDDVqnoEVA',
#  'nwVOSgcrbQI',
#  '2MSY0HwH5Ss',
#  'EmSNAtcHLm8',
#  'yA_Vtygj5FA',
#  '4Csy6VjbHiM',
#  '2OwWs7Hzr9g',
#  'ZcYVdmL8pzI',
#  'szkZ1DwABUs',
#  'rV-1w66cPqA',
#  '7LcUkgzx3AY',
#  'ZNgBfrqhb9w',
#  '1YoD0fg3_EM',
#  'b-YBvPmCTew',
#  'u2aOTtOwOkc',
#  '4xRonrhtkzc',
#  'owbU6WzIhhg',
#  'IicPavA37ew',
#  'vjh0Cqudqa0',
#  'D0xVD8eUk4o',
#  'tgIx04ML7-Y',
#  'T7KTKLHpTho',
#  'STdpODDHTns',
#  'gyTlcHVeBjM',
#  'yBKkSm2v3gg',
#  'hcDF7rVVzgY',
#  'mzRO0cVppQ0',
#  'Ygvskt5HadI',
#  'Ue_6n1yT_R8',
#  '04A6MJ_sqa0',
#  'uCrevbBh0zM',
#  '7z6yXpYk7sw',
#  'zRy6hrbvQG0',
#  'rW0eeTXas4k',
#  'br2Jl4TkCvA',
#  '6xO-x8y0YSY',
#  'ma6hWrU-LaI',
#  '-KMrkqIDMNo',
#  '6M1wWQmcUjQ',
#  'dBvjBwga8pU',
#  'gb5nm_3jBIo',
#  'ZfJoU67tG1A',
#  'pH7YVRhnpUI',
#  'RCmiPBiA4qg',
#  '3xPT2Pk0Jds',
#  '9wmImImmgcI',
#  '7MuiScUkboE',
#  'H0_3SJh4Rqs',
#  'qw7wFGgNCSU',
#  'Jp44b27VnOg',
#  '2_gCL5RAkHc',
#  'Lu2bruOHN6g',
#  'X7iIKPoZ0Sw',
#  'fne_UE7hDn0',
#  'fHF22Wxuyw4',
#  '2dH_qjc9mFg',
#  '1fvQU5yPjFs',
#  'NiI8IED2QmY',
#  'DAC3CuQ_IDU',
#  'SCVlg0VYxNE',
#  '9_mLV1Aj3Vw',
#  'e4Ni9QpCS2s',
#  'Mf2RdpEiXjU',
#  '269IGagoJfs',
#  'ww2uPkwSjjY',
#  '5J2J9Ywg1Pc',
#  'cNvZK0Wyoik',
#  'XTVP2gS6ftk',
#  'Qbd7U9F0QQ8',
#  'GaJ_LmHd0E8',
#  'DDfLc5AHoJI',
#  '39FONNQb-vc',
#  'XPDzwN1aXAQ',
#  '-ePqwviZx4I',
#  'l0rgITwCXKg',
#  'mdq43KRyy6M',
#  'eWlaWLZlkTQ',
#  'vo6gQz5lYRI',
#  '6C0sLtw5ctc',
#  'TEdzy19TDYc',
#  '29qyNyNkLHs',
#  'oWJe2T29kAo',
#  'zlUpTlaxAKI',
#  'PKv_okm1H-k',
#  'G1iqsaLOTc0',
#  'Ka5i9TVUT-E',
#  'Mh_RKdbrCjE',
#  'PWxFklmiCpQ',
#  'i9T4E5bSLrE',
#  'K6GSdn_iv8s',
#  'nopIGY1zJE0',
#  'FGBme8dWR_M',
#  'qKvgh-1XIpE',
#  'oH1ZF0OOf-c',
#  'tZd1okZiijo',
#  'coWzhv8XTXU',
#  'Ok_zkfWC0gI',
#  'jUt7bEeNl9U',
#  'Q1EeHessyaE',
#  'ygGknomFEWY',
#  'bZbI-vKFzGE',
#  'KpqgBYMERB4',
#  'O-aDHBGMqXA',
#  'sAzX_mF8wGo',
#  'SQHfry4xmdM',
#  'kH--k1VKFt4',
#  'sJgjRNhokPk',
#  'nMNiTZm-qY0',
#  'ax3WyB-_LJY',
#  'X67rclJcIL0',
#  'ZjbWF9f3VD4',
#  'fbKz7N92mhQ',
#  '0Zgt8PgX92I',
#  'xanJe6e8Xuw',
#  'AJKzWGOK54U',
#  '_rwNTY5Mn40',
#  'UPvv9SprgVo',
#  'MFraC1JObUo',
#  '5shTLzwAdEc',
#  'sRCuvcdvuzk',
#  '9e4nUuq2Hmg',
#  '7M5oWXCpDEw',
#  'JmXnztjULnQ',
#  'a20TaKNsriE',
#  'BgpM2IiCH6k',
#  'MoyU9kYT-go',
#  'RT0t9a3Xnfw',
#  'sFKnP0iP0K0',
#  'kRvIcdLhDtU',
#  'MFIMJJlI9mc',
#  'Nb21OhaW8GY',
#  'zKmxFfOCyD0',
#  'EtH2AOfRM3k',
#  'R47JAob1xBY',
#  'b7kEAoYHyuA',
#  'tdDhyFoSG94',
#  '5nQXhusiu7s',
#  'q7o4QoewLX8',
#  '4Im0CT43QxY',
#  'WOFVY_wQ9wU',
#  'l93jRojZMqU',
#  'jHgG4gjuFAk',
#  'F9uESCHGjhA',
#  'Q0QwvZKG_6Q',
#  'jBCzJlAjUM4',
#  'bHK1fE_BUms',
#  'iMToFoTl2Z8',
#  'Hc-Dwy35DRQ',
#  'DZmJxCEfkCs',
#  'ue1dZQKKLM8',
#  'cNy9Pc35fRw',
#  'YncZ0WwxyzU',
#  'scFDGSTuVQY',
#  '1xtrIEwY_zY',
#  'sM5-_9bJgdw',
#  'rTMUvrqKveA',
#  'RANHxyAvtM4',
#  'hCMnJT14XTw',
#  'mDEV0Iucwz0',
#  'IZnno-dKgVQ',
#  'ay_OcblJasE',
#  'WnBYW_DX3sM',
#  'lgs_o6mDzdU',
#  'ApOPyLoCFQk',
#  'Z8noL_0M4tw',
#  'QU3zhcSBWKU',
#  'mMCelsWjfac',
#  'Ai4fEP-QKSI',
#  'iK-kdhJ-7yI',
#  'fGckTEH5DPI',
#  'c09drtuCS3c',
#  'EHxqc8Vy3H8',
#  'PbpuN5yI68o',
#  'ABrrSwMYWSg',
#  'cPmiugHYvSI',
#  'u6UpEKy_ocM',
#  'awjXaFR1jOM',
#  '6bXOo0sxY5c',
#  'YjLFP8pW764',
#  'ehO0-6i9qD4',
#  '15sdH57DtsU',
#  'tLezwPKvPK4',
#  'QmSL27U7RDc',
#  'XNXzVfItWGY',
#  '_pNx8uEmHI0',
#  'JAigPIhUIM8',
#  '2g2DBkFhTTY',
#  'NQ0JI5IKggI',
#  'FN4aZPIAfI4',
#  'u1RKh1kQqaE',
#  'HLF4bFbBgwk',
#  '8osKeShYVRQ',
#  'Fci_wwMp8G8',
#  'oDlZBQjk_3A',
#  'aEow1QoTLo0',
#  'BNWLf3cKdbQ',
#  '_scscQ4HVTY',
#  'V7KBAa_gh4c',
#  'Jyo53pAyVAM',
#  'ORyfPJypKuU',
#  'VmZWXzxmNrE',
#  'NU37mF5q8VE',
#  'ashGekqstl8',
#  'Ti7c-Hz7GSM',
#  'dXHIDLPKdmA',
#  'UZPfbG0jNec',
#  'tofVCUDrg4M',
#  'tXXnxjj2wM4',
#  'iRbsBi5W0-c',
#  'ToGuhynu-No',
#  'ma-h30PoFms',
#  'bcXA4CqRXvM',
#  'Ccv1-W5ilak',
#  'OnPE-Z8jtqM',
#  'Lln1PKgGr_M',
#  'a38ehxv3kyk',
#  '-fK-xEev2I8',
#  'Ratcir3p03w',
#  'l_Wip8bEDFQ',
#  'mCL2xLBDw8M',
#  'aUnNWZorGmk',
#  'J73mvgG9fFs',
#  '9xiX-I5_LQY',
#  'kKWsJGKcMvo',
#  'lV_Z4HbNAx0',
#  'cTjj3LE8E90',
#  'xOccYkgRV4Q',
#  '5TVj6iEBR4I',
#  'U5oCv3JKWKA',
#  'w2GglmYHfmM',
#  'eBrGyuA2MIg',
#  '1Yw9sC0PNwY',
#  'sluoVhT0ehg',
#  'E69Lg2ZgOxg',
#  '6D3VtEfCw7w',
#  '4HyTlbHUKSw',
#  'mJlRTUuVr04',
#  '8NOdgjC1988',
#  'roTZJaxjnJc',
#  'fFwRC-fapIU',
#  'a_XrmKlaGTs',
#  'A9SezQlvakw',
#  'dr7z7a_8lQw',
#  '82P5N2m41jE',
#  'vVhD2EyS41Y',
#  '93rKZs0MkgU',
#  'iDbhQGz_rEo',
#  'lV36WzY_s1k',
#  'UZio8TcTMrI',
#  'sg7MwuLsnjQ',
#  '_C36hYMa8QU',
#  'Vy3SnnSQogA',
#  'Vw4LA54xG5A',
#  'shfXj_Og7ak',
#  'WGUNAJki2S4',
#  'hFZMyjLruKQ',
#  'SlMZqfvl5uw',
#  'ntAOq1ioTKo',
#  '3oOipgCbLIk',
#  'r7tzfm30SZc',
#  'HYVzrETXbkE',
#  'nPrhFxEuTYU',
#  '81ymPYEtFOw',
#  '-1T54G_E-ys',
#  '1v3_AQ26jZ0',
#  'b_vVNCVDrbw',
#  'fanEPKLRbPk',
#  'Y_78ARbpSwo',
#  'DPkpI2ezVO4',
#  'wlH9w1eA6PQ',
#  'AFrZ3JOQ0Qg',
#  'wRtAoZF50Jc',
#  'oUJs03eZ0S8',
#  'ZftI2fEz0Fw',
#  'LUiBOAy7x6Y',
#  'ut4vh59rGkw',
#  'pGQnNYdPTvY',
#  '_W1i-c_6rOk',
#  'Fe1MzID2BNg',
#  'QNeHcXZJ8Zg',
#  'Vdz0usYmSsU',
#  'DVxkI1VmpCk',
#  'S5NkE-xgx98',
#  'iRCaMnR_bpA',
#  '6RMNiTcxnp8',
#  '70nZfwjYkpk',
#  'K73cigZmSsE',
#  '3O5mJQhx_og',
#  'uHB2HL7_YGQ',
#  'tHbuA4d78b4',
#  'b-vrryTzKco',
#  'h9n6yNP2Zpw',
#  'RkEgOeTz_z0',
#  'QpSjsFNOl48',
#  'FyNEpTzAF1Q',
#  'ZUdCqt8F5pQ',
#  'yN2r1i_wFVc',
#  '95S3BW3nqlI',
#  'tZ6Ez7c6YNI',
#  'a2UUDYtsWks',
#  '4FO0REjG0x8',
#  'xt7lWNTWYC8',
#  't5lhXbwpNMo',
#  'vz-xweK5aLM',
#  't8LH2BOPW3M',
#  'lbkuGqJ0VMw',
#  'ooU3i6u826k',
#  'xpljKsusK7Y',
#  'aR08eUEaVxQ',
#  'x--vrns8mQo',
#  'mTE50i5prxc',
#  'zmXT-Odo_hg',
#  'HCXY4ZAta2I',
#  '95fWfyMAvQU',
#  '6hNM-HfBmPE',
#  'rRJUVA4MSHY',
#  'kr-NcI1JCLQ',
#  '8_0Ty1z3-os',
#  'W-bszHepsn8',
#  'qsXEqZfJVh8',
#  'viHXPOgSvBo',
#  'kxhaOoQNvOk',
#  'nQtLK2pKisI',
#  '15HAruMbjSI',
#  'shgVShLFZRg',
#  'uehLk9ECJJE',
#  'aDYQBdP5IJ8',
#  '9EH5b663d58',
#  'qL82QTDV8Go',
#  'OFb9cgeFiBU',
#  'kvxoZv5Rwwk',
#  'YG1diMPyE7o',
#  '0J8pg8KSirI',
#  'y6a4fDacqos',
#  '8Zaw5Om45uc',
#  'Nn1uCHqAbkA',
#  'ckpPchl4ISA',
#  'kbMMKOLxVY8',
#  'IEimXgz-Zvw',
#  'ayd0p3JWglc',
#  'U00q6soaYP8',
#  'LY6IJzrlejo',
#  'sUnN6Y24ztU',
#  'gHgke7nDkTg',
#  'eqc65Yh2tCE',
#  'HAdfI8SkZmQ',
#  'r6A229J4lzA',
#  '4J0uuIEPBZE',
#  'ZgIA0j9w848',
#  'Kg_7GllfN5A',
#  ...]

# %% [markdown]
# ## extrtact details of the videos

# %%
len(video_ids)
# Out:
# 22958

# %%
def get_videos_details(youtube,video_ids):
    all_video_stats=[]
    for i in range(0,len(video_ids),50):
        request=youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response=request.execute()

        for video in response['items']:
            video_stats=dict(Channel_Name=video['snippet']['channelTitle'],
                             Title=video['snippet']['title'],
                             Published_date=video['snippet']['publishedAt'],
                             Views=video['statistics'].get('viewCount', 'N/A'),
                             Like_count=video['statistics'].get('viewCount', 'N/A'),
                             Comment_Count=video['statistics'].get('commentCount', 'N/A')
                            )
            all_video_stats.append(video_stats)                                            
        

    return all_video_stats

# %%
video_details=get_videos_details(youtube,video_ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'DeepLearningAI',
#   'Title': 'Learn to build multi-agent systems with diverse roles and capabilities with AutoGen',
#   'Published_date': '2024-06-06T18:15:23Z',
#   'Views': '1650',
#   'Like_count': '1650',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New Course: AI Agents in LangGraph',
#   'Published_date': '2024-06-05T13:08:30Z',
#   'Views': '2472',
#   'Like_count': '2472',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course on agents! Enroll in AI Agentic Design Patterns with AutoGen',
#   'Published_date': '2024-05-29T13:03:06Z',
#   'Views': '3140',
#   'Like_count': '3140',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Learn to deploy AI models on edge devices like smartphones',
#   'Published_date': '2024-05-28T22:15:51Z',
#   'Views': '2234',
#   'Like_count': '2234',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Qualcomm: Introduction to On-Device AI',
#   'Published_date': '2024-05-21T12:46:13Z',
#   'Views': '2987',
#   'Like_count': '2987',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Learn How to Build Multimodal Search and RAG',
#   'Published_date': '2024-05-20T14:30:23Z',
#   'Views': '2866',
#   'Like_count': '2866',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Learn Multi AI Agent Systems with crewAI: Lesson 1',
#   'Published_date': '2024-05-16T17:01:17Z',
#   'Views': '3812',
#   'Like_count': '3812',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New short course: Multi AI Agent Systems with crewAI',
#   'Published_date': '2024-05-15T14:17:29Z',
#   'Views': '3429',
#   'Like_count': '3429',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Weaviate: Building Multimodal Search and RAG',
#   'Published_date': '2024-05-13T13:44:06Z',
#   'Views': '1822',
#   'Like_count': '1822',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course: Building Agentic RAG with LlamaIndex',
#   'Published_date': '2024-05-08T13:51:54Z',
#   'Views': '2998',
#   'Like_count': '2998',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Hugging Face: Quantization in Depth 🤗',
#   'Published_date': '2024-05-06T13:30:35Z',
#   'Views': '2286',
#   'Like_count': '2286',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Comet: Prompt Engineering for Vision Models',
#   'Published_date': '2024-04-29T13:33:44Z',
#   'Views': '2233',
#   'Like_count': '2233',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course! Getting Started with Mistral is live',
#   'Published_date': '2024-04-22T13:41:17Z',
#   'Views': '4144',
#   'Like_count': '4144',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Hugging Face: Quantization Fundamentals',
#   'Published_date': '2024-04-15T13:44:22Z',
#   'Views': '2952',
#   'Like_count': '2952',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Unstructured: Preprocessing Unstructured Data for LLM Applications',
#   'Published_date': '2024-04-10T12:12:35Z',
#   'Views': '3611',
#   'Like_count': '3611',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Giskard: Red Teaming LLM Applications',
#   'Published_date': '2024-04-03T13:24:57Z',
#   'Views': '2255',
#   'Like_count': '2255',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with LlamaIndex: JavaScript RAG Web Apps with LlamaIndex',
#   'Published_date': '2024-03-27T13:42:31Z',
#   'Views': '2735',
#   'Like_count': '2735',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'How To Read AI Research Papers Effectively',
#   'Published_date': '2024-03-21T18:31:57Z',
#   'Views': '36905',
#   'Like_count': '36905',
#   'Comment_Count': '30'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Predibase: Efficiently Serving LLMs',
#   'Published_date': '2024-03-18T14:53:02Z',
#   'Views': '1777',
#   'Like_count': '1777',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Neo4J: Knowledge Graphs for RAG',
#   'Published_date': '2024-03-13T13:37:02Z',
#   'Views': '6784',
#   'Like_count': '6784',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Building Production-Grade LLM Apps',
#   'Published_date': '2024-03-07T19:08:20Z',
#   'Views': '21640',
#   'Like_count': '21640',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Hugging Face: Open Source Models with Hugging Face',
#   'Published_date': '2024-03-04T14:11:56Z',
#   'Views': '4786',
#   'Like_count': '4786',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Meta: Prompt Engineering with Llama 2',
#   'Published_date': '2024-02-28T13:27:52Z',
#   'Views': '4585',
#   'Like_count': '4585',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Turbocharge Your RAG Applications with Powerful RAG Analytics',
#   'Published_date': '2024-02-22T19:09:33Z',
#   'Views': '13683',
#   'Like_count': '13683',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with AWS: Serverless LLM apps with Amazon Bedrock',
#   'Published_date': '2024-02-14T13:20:57Z',
#   'Views': '3868',
#   'Like_count': '3868',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Aligning LLMs with Direct Preference Optimization',
#   'Published_date': '2024-02-08T20:06:22Z',
#   'Views': '21362',
#   'Like_count': '21362',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Pinecone: Building Applications with Vector Databases',
#   'Published_date': '2024-01-31T12:10:10Z',
#   'Views': '3530',
#   'Like_count': '3530',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with CircleCI: Automated Testing for LLMOps',
#   'Published_date': '2024-01-24T13:35:58Z',
#   'Views': '2625',
#   'Like_count': '2625',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Prompt-Engineering for Open-Source LLMs',
#   'Published_date': '2024-01-23T19:24:27Z',
#   'Views': '31586',
#   'Like_count': '31586',
#   'Comment_Count': '46'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Google Cloud: LLMOps',
#   'Published_date': '2024-01-17T13:15:21Z',
#   'Views': '3767',
#   'Like_count': '3767',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with LangChain: Build LLM Apps with LangChain.js',
#   'Published_date': '2024-01-10T13:50:30Z',
#   'Views': '3209',
#   'Like_count': '3209',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Navigating LLM Threats: Detecting Prompt Injections and Jailbreaks',
#   'Published_date': '2024-01-09T19:04:28Z',
#   'Views': '8437',
#   'Like_count': '8437',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New short course: Advanced Retrieval for AI with Chroma',
#   'Published_date': '2024-01-03T10:47:00Z',
#   'Views': '4811',
#   'Like_count': '4811',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'LLM Agent Fine-Tuning: Enhancing Task Automation with Weights & Biases',
#   'Published_date': '2023-12-19T19:16:24Z',
#   'Views': '11214',
#   'Like_count': '11214',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Google Cloud: Reinforcement Learning from Human Feedback (RLHF)',
#   'Published_date': '2023-12-13T14:11:37Z',
#   'Views': '6905',
#   'Like_count': '6905',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'How to Build, Evaluate, and Iterate on LLM Agents',
#   'Published_date': '2023-12-05T19:16:08Z',
#   'Views': '30985',
#   'Like_count': '30985',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with TruEra and LlamaIndex: Building and Evaluating Advanced RAG',
#   'Published_date': '2023-11-29T16:49:27Z',
#   'Views': '4245',
#   'Like_count': '4245',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'AI for Good by DeepLearning.AI Now Available',
#   'Published_date': '2023-11-17T22:06:30Z',
#   'Views': '1480',
#   'Like_count': '1480',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#1 AI for Good Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2023-11-17T21:49:15Z',
#   'Views': '5648',
#   'Like_count': '5648',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#3 AI for Good Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2023-11-17T20:13:19Z',
#   'Views': '1100',
#   'Like_count': '1100',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with WhyLabs: Quality and Safety for LLM Applications',
#   'Published_date': '2023-11-15T16:32:27Z',
#   'Views': '2461',
#   'Like_count': '2461',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Building Multi-Modal Search with Vector Databases',
#   'Published_date': '2023-11-14T19:17:50Z',
#   'Views': '15767',
#   'Like_count': '15767',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course: Vector Databases: from Embeddings to Applications with Weaviate',
#   'Published_date': '2023-11-08T16:51:55Z',
#   'Views': '3772',
#   'Like_count': '3772',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Generative AI for Everyone, a course from Andrew Ng, is live!',
#   'Published_date': '2023-11-01T15:05:28Z',
#   'Views': '19685',
#   'Like_count': '19685',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Mitigating LLM Hallucinations with a Metrics-First Evaluation Framework',
#   'Published_date': '2023-10-26T18:06:06Z',
#   'Views': '20898',
#   'Like_count': '20898',
#   'Comment_Count': '20'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course: Functions, Tools and Agents with LangChain',
#   'Published_date': '2023-10-25T15:46:13Z',
#   'Views': '4637',
#   'Like_count': '4637',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'AI for Good: A discussion on addressing real-world problems with AI',
#   'Published_date': '2023-09-28T17:35:52Z',
#   'Views': '18644',
#   'Like_count': '18644',
#   'Comment_Count': '27'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Google: Pair Programming with a Large Language Model',
#   'Published_date': '2023-09-27T15:30:36Z',
#   'Views': '6785',
#   'Like_count': '6785',
#   'Comment_Count': '14'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': "AI for Good Specialization: Learn AI's role in addressing real-world challenges",
#   'Published_date': '2023-09-07T15:52:16Z',
#   'Views': '8511',
#   'Like_count': '8511',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Google Cloud: Understanding and Applying Text Embeddings with Vertex AI',
#   'Published_date': '2023-09-06T15:38:23Z',
#   'Views': '7086',
#   'Like_count': '7086',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Microsoft: How Business Thinkers Can Start Building AI Plugins With Semantic Kernel',
#   'Published_date': '2023-08-30T01:18:21Z',
#   'Views': '7842',
#   'Like_count': '7842',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Efficient Fine-Tuning for Llama-v2-7b on a Single GPU',
#   'Published_date': '2023-08-29T18:06:25Z',
#   'Views': '82741',
#   'Like_count': '82741',
#   'Comment_Count': '61'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New Course: Finetuning Large Language Models',
#   'Published_date': '2023-08-23T15:00:48Z',
#   'Views': '11356',
#   'Like_count': '11356',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'New course with Cohere: Large Language Models with Semantic Search',
#   'Published_date': '2023-08-16T04:33:40Z',
#   'Views': '10085',
#   'Like_count': '10085',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Deep Dive into LLM Evaluation with Weights & Biases',
#   'Published_date': '2023-08-15T18:06:36Z',
#   'Views': '17306',
#   'Like_count': '17306',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Mastering RLHF with AWS: A Hands-on Workshop on Reinforcement Learning from Human Feedback',
#   'Published_date': '2023-08-03T18:09:58Z',
#   'Views': '22753',
#   'Like_count': '22753',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Evaluating and Debugging Generative AI, Now Available!',
#   'Published_date': '2023-08-02T07:34:27Z',
#   'Views': '6170',
#   'Like_count': '6170',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#37 AI for Good Specialization [Course 1, Week 3, Lesson 2]',
#   'Published_date': '2023-07-27T17:13:02Z',
#   'Views': '1597',
#   'Like_count': '1597',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#36 AI for Good Specialization [Course 1, Week 3, Lesson 2]',
#   'Published_date': '2023-07-27T17:12:39Z',
#   'Views': '583',
#   'Like_count': '583',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#35 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:12:23Z',
#   'Views': '411',
#   'Like_count': '411',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#34 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:12:05Z',
#   'Views': '591',
#   'Like_count': '591',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#33 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:11:50Z',
#   'Views': '368',
#   'Like_count': '368',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#32 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:11:06Z',
#   'Views': '395',
#   'Like_count': '395',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#31 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:10:50Z',
#   'Views': '373',
#   'Like_count': '373',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#30 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:10:34Z',
#   'Views': '453',
#   'Like_count': '453',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#29 AI for Good Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2023-07-27T17:08:49Z',
#   'Views': '236',
#   'Like_count': '236',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#28 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:08:33Z',
#   'Views': '246',
#   'Like_count': '246',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#27 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:08:18Z',
#   'Views': '408',
#   'Like_count': '408',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#26 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:08:02Z',
#   'Views': '356',
#   'Like_count': '356',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#25 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:07:46Z',
#   'Views': '339',
#   'Like_count': '339',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#24 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:07:08Z',
#   'Views': '233',
#   'Like_count': '233',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#23 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:05:40Z',
#   'Views': '258',
#   'Like_count': '258',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#22 AI for Good Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2023-07-27T17:05:21Z',
#   'Views': '416',
#   'Like_count': '416',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#21 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:04:06Z',
#   'Views': '329',
#   'Like_count': '329',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#20 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:03:45Z',
#   'Views': '267',
#   'Like_count': '267',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#19 AI for Good Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2023-07-27T17:03:30Z',
#   'Views': '259',
#   'Like_count': '259',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#18 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T17:03:16Z',
#   'Views': '354',
#   'Like_count': '354',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#17 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:59:31Z',
#   'Views': '369',
#   'Like_count': '369',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#16 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:59:13Z',
#   'Views': '399',
#   'Like_count': '399',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#15 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:58:39Z',
#   'Views': '371',
#   'Like_count': '371',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#14 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:58:19Z',
#   'Views': '352',
#   'Like_count': '352',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#13 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:57:59Z',
#   'Views': '420',
#   'Like_count': '420',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#12 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:57:35Z',
#   'Views': '486',
#   'Like_count': '486',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#11 AI for Good Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2023-07-27T16:56:50Z',
#   'Views': '545',
#   'Like_count': '545',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#10 AI for Good Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2023-07-27T16:56:33Z',
#   'Views': '613',
#   'Like_count': '613',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#9 AI for Good Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2023-07-27T16:56:17Z',
#   'Views': '491',
#   'Like_count': '491',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#8 AI for Good Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2023-07-27T16:55:55Z',
#   'Views': '616',
#   'Like_count': '616',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#7 AI for Good Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2023-07-27T16:55:39Z',
#   'Views': '704',
#   'Like_count': '704',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#6 AI for Good Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2023-07-27T16:55:27Z',
#   'Views': '750',
#   'Like_count': '750',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#5 AI for Good Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2023-07-27T16:55:12Z',
#   'Views': '935',
#   'Like_count': '935',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#4 AI for Good Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2023-07-27T16:54:56Z',
#   'Views': '1010',
#   'Like_count': '1010',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#2 AI for Good Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2023-07-27T16:54:21Z',
#   'Views': '2136',
#   'Like_count': '2136',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Building Generative AI Applications with Gradio Now Available!',
#   'Published_date': '2023-07-26T14:24:39Z',
#   'Views': '7259',
#   'Like_count': '7259',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'LangChain: Chat with Your Data by DeepLearning.AI Now Available',
#   'Published_date': '2023-07-07T17:32:30Z',
#   'Views': '7459',
#   'Like_count': '7459',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Generative AI with Large Language Models by AWS and DeepLearning.AI',
#   'Published_date': '2023-06-28T15:48:50Z',
#   'Views': '10190',
#   'Like_count': '10190',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Building with Instruction-Tuned LLMs: A Step-by-Step Guide',
#   'Published_date': '2023-05-31T18:06:47Z',
#   'Views': '48555',
#   'Like_count': '48555',
#   'Comment_Count': '58'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Building Systems with the ChatGPT API: A short course from OpenAI and DeepLearning.AI',
#   'Published_date': '2023-05-31T16:14:19Z',
#   'Views': '21181',
#   'Like_count': '21181',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'LangChain for LLM Application Development: A short course by DeepLearning.AI',
#   'Published_date': '2023-05-31T16:14:15Z',
#   'Views': '26820',
#   'Like_count': '26820',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'How Diffusion Models Work: A short course by DeepLearning.AI',
#   'Published_date': '2023-05-31T16:14:12Z',
#   'Views': '18404',
#   'Like_count': '18404',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'ChatGPT Prompt Engineering for Developers: A short course from OpenAI and DeepLearning.AI',
#   'Published_date': '2023-04-27T14:49:09Z',
#   'Views': '161028',
#   'Like_count': '161028',
#   'Comment_Count': '131'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Yann LeCun and Andrew Ng: Why the 6-month AI Pause is a Bad Idea',
#   'Published_date': '2023-04-07T17:06:28Z',
#   'Views': '124595',
#   'Like_count': '124595',
#   'Comment_Count': '365'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Building Machine Learning Apps with Hugging Face: LLMs to Diffusion Modeling',
#   'Published_date': '2023-03-23T18:28:30Z',
#   'Views': '31605',
#   'Like_count': '31605',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Machine Learning Specialization by DeepLearning.AI',
#   'Published_date': '2023-03-08T16:39:30Z',
#   'Views': '47697',
#   'Like_count': '47697',
#   'Comment_Count': '66'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Practical Data Science on AWS: Generative AI',
#   'Published_date': '2023-02-23T19:10:47Z',
#   'Views': '21342',
#   'Like_count': '21342',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Ready for the Mathematics for Machine Learning and Data Science Specialization? 🚀',
#   'Published_date': '2023-01-31T16:13:22Z',
#   'Views': '16053',
#   'Like_count': '16053',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'FastAPI for Machine Learning: Live coding an ML web application.',
#   'Published_date': '2022-12-15T18:03:46Z',
#   'Views': '47014',
#   'Like_count': '47014',
#   'Comment_Count': '30'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Landing a Job in AI: Hiring Secrets from Technical Recruiters',
#   'Published_date': '2022-12-06T19:05:33Z',
#   'Views': '9856',
#   'Like_count': '9856',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#41 Machine Learning Specialization [Course 1, Week 3, Lesson 4]',
#   'Published_date': '2022-12-01T13:23:36Z',
#   'Views': '30660',
#   'Like_count': '30660',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#40 Machine Learning Specialization [Course 1, Week 3, Lesson 4]',
#   'Published_date': '2022-12-01T13:23:33Z',
#   'Views': '18744',
#   'Like_count': '18744',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#39 Machine Learning Specialization [Course 1, Week 3, Lesson 4]',
#   'Published_date': '2022-12-01T13:23:30Z',
#   'Views': '19998',
#   'Like_count': '19998',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#38 Machine Learning Specialization [Course 1, Week 3, Lesson 4]',
#   'Published_date': '2022-12-01T13:23:25Z',
#   'Views': '18209',
#   'Like_count': '18209',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#37 Machine Learning Specialization [Course 1, Week 3, Lesson 4]',
#   'Published_date': '2022-12-01T13:23:22Z',
#   'Views': '19682',
#   'Like_count': '19682',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#36 Machine Learning Specialization [Course 1, Week 3, Lesson 3]',
#   'Published_date': '2022-12-01T13:23:17Z',
#   'Views': '16594',
#   'Like_count': '16594',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#35 Machine Learning Specialization [Course 1, Week 3, Lesson 2]',
#   'Published_date': '2022-12-01T13:23:14Z',
#   'Views': '16156',
#   'Like_count': '16156',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#34 Machine Learning Specialization [Course 1, Week 3, Lesson 2]',
#   'Published_date': '2022-12-01T13:23:11Z',
#   'Views': '19424',
#   'Like_count': '19424',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#33 Machine Learning Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2022-12-01T13:23:09Z',
#   'Views': '19025',
#   'Like_count': '19025',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#32 Machine Learning Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2022-12-01T13:23:06Z',
#   'Views': '20437',
#   'Like_count': '20437',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#31 Machine Learning Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2022-12-01T13:23:03Z',
#   'Views': '22950',
#   'Like_count': '22950',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#30 Machine Learning Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-12-01T13:23:00Z',
#   'Views': '18679',
#   'Like_count': '18679',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#29 Machine Learning Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-12-01T13:22:57Z',
#   'Views': '16650',
#   'Like_count': '16650',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#28 Machine Learning Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-12-01T13:22:54Z',
#   'Views': '16679',
#   'Like_count': '16679',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#27 Machine Learning Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-12-01T13:22:51Z',
#   'Views': '17644',
#   'Like_count': '17644',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#26 Machine Learning Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-12-01T13:22:48Z',
#   'Views': '18962',
#   'Like_count': '18962',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#25 Machine Learning Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-12-01T13:22:45Z',
#   'Views': '21160',
#   'Like_count': '21160',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#24 Machine Learning Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2022-12-01T13:22:41Z',
#   'Views': '23636',
#   'Like_count': '23636',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#23 Machine Learning Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2022-12-01T13:22:38Z',
#   'Views': '21483',
#   'Like_count': '21483',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#22 Machine Learning Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2022-12-01T13:22:35Z',
#   'Views': '23566',
#   'Like_count': '23566',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#21 Machine Learning Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2022-12-01T13:22:32Z',
#   'Views': '27966',
#   'Like_count': '27966',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#20 Machine Learning Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-12-01T13:22:28Z',
#   'Views': '25092',
#   'Like_count': '25092',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#19 Machine Learning Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-12-01T13:22:25Z',
#   'Views': '25514',
#   'Like_count': '25514',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#18 Machine Learning Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-12-01T13:22:21Z',
#   'Views': '24732',
#   'Like_count': '24732',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#17 Machine Learning Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-12-01T13:22:17Z',
#   'Views': '26261',
#   'Like_count': '26261',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#16 Machine Learning Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-12-01T13:22:14Z',
#   'Views': '29493',
#   'Like_count': '29493',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#15 Machine Learning Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-12-01T13:22:10Z',
#   'Views': '33802',
#   'Like_count': '33802',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#14 Machine Learning Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-12-01T13:22:07Z',
#   'Views': '29731',
#   'Like_count': '29731',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#13 Machine Learning Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-12-01T13:22:03Z',
#   'Views': '34683',
#   'Like_count': '34683',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#12 Machine Learning Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-12-01T13:21:54Z',
#   'Views': '40852',
#   'Like_count': '40852',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#11 Machine Learning Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-12-01T13:21:50Z',
#   'Views': '43433',
#   'Like_count': '43433',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#10 Machine Learning Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-12-01T13:21:47Z',
#   'Views': '46412',
#   'Like_count': '46412',
#   'Comment_Count': '19'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#9 Machine Learning Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-12-01T13:21:45Z',
#   'Views': '56653',
#   'Like_count': '56653',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#8 Machine Learning Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-12-01T13:21:40Z',
#   'Views': '41428',
#   'Like_count': '41428',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#7 Machine Learning Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-12-01T13:21:37Z',
#   'Views': '40751',
#   'Like_count': '40751',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#6 Machine Learning Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-12-01T13:21:34Z',
#   'Views': '50422',
#   'Like_count': '50422',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#5 Machine Learning Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-12-01T13:21:30Z',
#   'Views': '58628',
#   'Like_count': '58628',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#4 Machine Learning Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-12-01T13:21:27Z',
#   'Views': '80397',
#   'Like_count': '80397',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#3 Machine Learning Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-12-01T13:21:24Z',
#   'Views': '73719',
#   'Like_count': '73719',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#2 Machine Learning Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2022-12-01T13:21:20Z',
#   'Views': '91131',
#   'Like_count': '91131',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#1 Machine Learning Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2022-12-01T13:20:48Z',
#   'Views': '249421',
#   'Like_count': '249421',
#   'Comment_Count': '31'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'How to Build a Real-World AI Project Portfolio',
#   'Published_date': '2022-11-29T18:14:20Z',
#   'Views': '13291',
#   'Like_count': '13291',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Branching out of the Notebook: ML Application Development with GitHub',
#   'Published_date': '2022-11-09T18:04:33Z',
#   'Views': '11710',
#   'Like_count': '11710',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': "Founding an AI Startup: Dos & Don'ts of Building a Company",
#   'Published_date': '2022-10-18T18:02:52Z',
#   'Views': '8661',
#   'Like_count': '8661',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Beyond Jupyter Notebooks: MLOps Environment Setup & First Deployment',
#   'Published_date': '2022-09-28T18:02:58Z',
#   'Views': '22047',
#   'Like_count': '22047',
#   'Comment_Count': '20'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'The Impact of AI for Social Good',
#   'Published_date': '2022-08-31T17:01:06Z',
#   'Views': '5188',
#   'Like_count': '5188',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Accelerating Your AI Career',
#   'Published_date': '2022-08-03T19:25:15Z',
#   'Views': '33213',
#   'Like_count': '33213',
#   'Comment_Count': '30'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Pathways in Machine Learning/Data Science',
#   'Published_date': '2022-05-18T18:17:18Z',
#   'Views': '8196',
#   'Like_count': '8196',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Prioritizing AI/ML Projects in Your Organization',
#   'Published_date': '2022-04-28T18:17:49Z',
#   'Views': '3659',
#   'Like_count': '3659',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#11 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 3]',
#   'Published_date': '2022-04-21T00:03:26Z',
#   'Views': '15614',
#   'Like_count': '15614',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#12 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 4]',
#   'Published_date': '2022-04-21T00:03:23Z',
#   'Views': '11265',
#   'Like_count': '11265',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#13 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 5]',
#   'Published_date': '2022-04-21T00:03:20Z',
#   'Views': '9924',
#   'Like_count': '9924',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#14 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 6]',
#   'Published_date': '2022-04-21T00:03:18Z',
#   'Views': '9379',
#   'Like_count': '9379',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#15 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 7]',
#   'Published_date': '2022-04-21T00:03:13Z',
#   'Views': '8236',
#   'Like_count': '8236',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#16 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 8]',
#   'Published_date': '2022-04-21T00:03:09Z',
#   'Views': '8251',
#   'Like_count': '8251',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#17 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 9]',
#   'Published_date': '2022-04-21T00:03:05Z',
#   'Views': '7668',
#   'Like_count': '7668',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#18 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 10]',
#   'Published_date': '2022-04-21T00:03:02Z',
#   'Views': '6659',
#   'Like_count': '6659',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#19 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 11]',
#   'Published_date': '2022-04-21T00:03:00Z',
#   'Views': '6719',
#   'Like_count': '6719',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#21 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 13]',
#   'Published_date': '2022-04-21T00:02:56Z',
#   'Views': '6607',
#   'Like_count': '6607',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#20 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 12]',
#   'Published_date': '2022-04-21T00:02:53Z',
#   'Views': '6857',
#   'Like_count': '6857',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#22 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 14]',
#   'Published_date': '2022-04-21T00:02:51Z',
#   'Views': '6351',
#   'Like_count': '6351',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#23 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 15]',
#   'Published_date': '2022-04-21T00:02:47Z',
#   'Views': '5663',
#   'Like_count': '5663',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#24 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 16]',
#   'Published_date': '2022-04-21T00:02:44Z',
#   'Views': '5441',
#   'Like_count': '5441',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#25 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 1]',
#   'Published_date': '2022-04-21T00:02:40Z',
#   'Views': '5831',
#   'Like_count': '5831',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#26 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3 Lesson 2]',
#   'Published_date': '2022-04-21T00:02:34Z',
#   'Views': '5584',
#   'Like_count': '5584',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#27 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 3]',
#   'Published_date': '2022-04-21T00:02:30Z',
#   'Views': '5537',
#   'Like_count': '5537',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#28 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 4]',
#   'Published_date': '2022-04-21T00:02:27Z',
#   'Views': '5303',
#   'Like_count': '5303',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#29 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 5]',
#   'Published_date': '2022-04-21T00:02:22Z',
#   'Views': '4800',
#   'Like_count': '4800',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#30 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 6]',
#   'Published_date': '2022-04-21T00:02:19Z',
#   'Views': '4873',
#   'Like_count': '4873',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#31 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 7]',
#   'Published_date': '2022-04-21T00:02:17Z',
#   'Views': '4771',
#   'Like_count': '4771',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#32 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 8]',
#   'Published_date': '2022-04-21T00:02:14Z',
#   'Views': '4846',
#   'Like_count': '4846',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#33 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 9]',
#   'Published_date': '2022-04-21T00:02:09Z',
#   'Views': '4536',
#   'Like_count': '4536',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#34 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 10]',
#   'Published_date': '2022-04-21T00:02:06Z',
#   'Views': '4631',
#   'Like_count': '4631',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#35 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 11]',
#   'Published_date': '2022-04-21T00:02:03Z',
#   'Views': '4510',
#   'Like_count': '4510',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#36 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 12]',
#   'Published_date': '2022-04-21T00:01:58Z',
#   'Views': '4824',
#   'Like_count': '4824',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#37 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 13]',
#   'Published_date': '2022-04-21T00:01:55Z',
#   'Views': '5767',
#   'Like_count': '5767',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#38 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 14]',
#   'Published_date': '2022-04-21T00:00:57Z',
#   'Views': '7138',
#   'Like_count': '7138',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#39 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 15]',
#   'Published_date': '2022-04-21T00:00:53Z',
#   'Views': '6621',
#   'Like_count': '6621',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#40 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 3, Lesson 16]',
#   'Published_date': '2022-04-21T00:00:50Z',
#   'Views': '9252',
#   'Like_count': '9252',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#10 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 2]',
#   'Published_date': '2022-04-21T00:00:29Z',
#   'Views': '11084',
#   'Like_count': '11084',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#9 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 2, Lesson 1]',
#   'Published_date': '2022-04-21T00:00:24Z',
#   'Views': '11741',
#   'Like_count': '11741',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#8 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 8]',
#   'Published_date': '2022-04-21T00:00:22Z',
#   'Views': '14944',
#   'Like_count': '14944',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#7 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 7]',
#   'Published_date': '2022-04-21T00:00:17Z',
#   'Views': '16176',
#   'Like_count': '16176',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#6 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 6]',
#   'Published_date': '2022-04-21T00:00:10Z',
#   'Views': '19311',
#   'Like_count': '19311',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#5 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 5]',
#   'Published_date': '2022-04-21T00:00:07Z',
#   'Views': '23546',
#   'Like_count': '23546',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#4 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 4]',
#   'Published_date': '2022-04-21T00:00:04Z',
#   'Views': '21239',
#   'Like_count': '21239',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#3 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 3]',
#   'Published_date': '2022-04-20T23:59:57Z',
#   'Views': '31446',
#   'Like_count': '31446',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#2 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 2]',
#   'Published_date': '2022-04-20T23:59:53Z',
#   'Views': '35620',
#   'Like_count': '35620',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#1 Machine Learning Engineering for Production (MLOps) Specialization [Course 1, Week 1, Lesson 1]',
#   'Published_date': '2022-04-20T23:59:50Z',
#   'Views': '125840',
#   'Like_count': '125840',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': 'Celebrating Deep Learner Month #BeADeepLearner',
#   'Published_date': '2022-04-08T22:57:53Z',
#   'Views': '7556',
#   'Like_count': '7556',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Kulsoom Abdullah with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:57:12Z',
#   'Views': '2932',
#   'Like_count': '2932',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Tim Steves with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:57:01Z',
#   'Views': '1149',
#   'Like_count': '1149',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Lei Xu with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:56:54Z',
#   'Views': '1099',
#   'Like_count': '1099',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Macit Giray Gokirmak with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:56:49Z',
#   'Views': '1136',
#   'Like_count': '1136',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Macit, Kulsoom, Lei and Tim',
#   'Published_date': '2022-04-08T22:56:43Z',
#   'Views': '483',
#   'Like_count': '483',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Apala, Luciano, Hermawan and Lorenzo',
#   'Published_date': '2022-04-08T22:56:39Z',
#   'Views': '414',
#   'Like_count': '414',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Aleksandr, Niranjan, I-Chiao, Matt and Yudhiesh',
#   'Published_date': '2022-04-08T22:56:35Z',
#   'Views': '534',
#   'Like_count': '534',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like I-Chiao Lin with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:56:29Z',
#   'Views': '957',
#   'Like_count': '957',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Yudhiesh Ravindran with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:56:23Z',
#   'Views': '607',
#   'Like_count': '607',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Title': '#BeADeepLearner like Niranjan Akella with DeepLearning.AI',
#   'Published_date': '2022-04-08T22:56:17Z',
#   'Views': '787',
#   'Like_count': '787',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'DeepLearningAI',
# ...
#   'Published_date': '2021-03-14T05:27:57Z',
#   'Views': '11409',
#   'Like_count': '11409',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Image Processing using OpenCV | Part 4 | Playing with RGB Color Channels',
#   'Published_date': '2021-03-14T05:24:30Z',
#   'Views': '13915',
#   'Like_count': '13915',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Image Processing using OpenCV | Part 3 | Converting RGB image to Grayscale',
#   'Published_date': '2021-03-14T04:59:38Z',
#   'Views': '20491',
#   'Like_count': '20491',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Image Processing using OpenCV | Part 2 | Reading an Image',
#   'Published_date': '2021-03-14T04:50:41Z',
#   'Views': '18606',
#   'Like_count': '18606',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Image Processing using OpenCV | Part 1 | Image Basics',
#   'Published_date': '2021-03-14T04:22:11Z',
#   'Views': '45365',
#   'Like_count': '45365',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'What is Machine Learning? | 100 Days of Machine Learning',
#   'Published_date': '2021-03-13T16:15:53Z',
#   'Views': '595213',
#   'Like_count': '595213',
#   'Comment_Count': '248'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Bagging | Introduction | Part 1',
#   'Published_date': '2021-03-12T15:25:14Z',
#   'Views': '36252',
#   'Like_count': '36252',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Voting Ensemble | Regression | Part 3',
#   'Published_date': '2021-03-11T14:06:31Z',
#   'Views': '13482',
#   'Like_count': '13482',
#   'Comment_Count': '18'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Voting Ensemble | Classification | Voting Classifier | Hard Voting Vs Soft Voting | Part 2',
#   'Published_date': '2021-03-10T14:13:57Z',
#   'Views': '19999',
#   'Like_count': '19999',
#   'Comment_Count': '25'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Voting Ensemble |  Introduction and Core Idea | Part 1',
#   'Published_date': '2021-03-09T13:17:07Z',
#   'Views': '21305',
#   'Like_count': '21305',
#   'Comment_Count': '32'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Session on Generative Adversarial Networks | GANs',
#   'Published_date': '2021-01-31T18:16:54Z',
#   'Views': '24242',
#   'Like_count': '24242',
#   'Comment_Count': '49'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Thread Pool Executors | Threading And Multi Processing in Python Part 2',
#   'Published_date': '2021-01-28T14:38:49Z',
#   'Views': '1490',
#   'Like_count': '1490',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Threading | Threading and Multi Processing in Python Part 1',
#   'Published_date': '2021-01-12T15:44:56Z',
#   'Views': '7283',
#   'Like_count': '7283',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Bangalore House Price Prediction | Regression Project | End to End Machine Learning Projects',
#   'Published_date': '2021-01-03T18:56:03Z',
#   'Views': '117213',
#   'Like_count': '117213',
#   'Comment_Count': '222'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Cross-validation in Machine Learning',
#   'Published_date': '2021-01-02T04:31:28Z',
#   'Views': '9713',
#   'Like_count': '9713',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Car Price Predictor Project | Machine Learning | Linear Regression',
#   'Published_date': '2021-01-02T04:25:30Z',
#   'Views': '222972',
#   'Like_count': '222972',
#   'Comment_Count': '311'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Largest Rectangle in Histogram',
#   'Published_date': '2020-11-18T19:16:48Z',
#   'Views': '119',
#   'Like_count': '119',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Face Mask Detection using CNN | VGG16 | Keras Project',
#   'Published_date': '2020-11-16T06:17:14Z',
#   'Views': '44110',
#   'Like_count': '44110',
#   'Comment_Count': '39'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Next Larger Element in an Array',
#   'Published_date': '2020-11-15T19:41:01Z',
#   'Views': '60',
#   'Like_count': '60',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Face Mask Detector Project  Demo| Deep Learning',
#   'Published_date': '2020-11-15T05:47:33Z',
#   'Views': '1331',
#   'Like_count': '1331',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Get minimum item from a stack in O(1) time',
#   'Published_date': '2020-11-14T05:15:35Z',
#   'Views': '38',
#   'Like_count': '38',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Reverse a LinkedList using Stack',
#   'Published_date': '2020-11-13T07:05:20Z',
#   'Views': '2431',
#   'Like_count': '2431',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Online Stock Span Problem in Java | Stacks Problem #1',
#   'Published_date': '2020-11-11T03:37:41Z',
#   'Views': '83',
#   'Like_count': '83',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'News App from Scratch | Part 1 - Course Introduction | Advance Android Tutorials',
#   'Published_date': '2020-10-14T08:02:56Z',
#   'Views': '242',
#   'Like_count': '242',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'DOM Selectors | Multiple Item Selector | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:59:37Z',
#   'Views': '231',
#   'Like_count': '231',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'DOM Selectors Part 1 | Single Element Selector | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:59:00Z',
#   'Views': '213',
#   'Like_count': '213',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Document Object Model | DOM | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:58:35Z',
#   'Views': '275',
#   'Like_count': '275',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'The Window Object | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:57:48Z',
#   'Views': '301',
#   'Like_count': '301',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Type Conversion | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:57:19Z',
#   'Views': '151',
#   'Like_count': '151',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Operators | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:56:47Z',
#   'Views': '127',
#   'Like_count': '127',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Generals Loops | Javascript Fundamentals',
#   'Published_date': '2020-10-08T16:56:13Z',
#   'Views': '184',
#   'Like_count': '184',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Functions | Javascript',
#   'Published_date': '2020-10-08T15:07:58Z',
#   'Views': '209',
#   'Like_count': '209',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'If-else statements | Javascript Fundamentals',
#   'Published_date': '2020-10-08T15:06:08Z',
#   'Views': '149',
#   'Like_count': '149',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Switch Statements | Javascript Fundamentals',
#   'Published_date': '2020-10-08T15:02:45Z',
#   'Views': '150',
#   'Like_count': '150',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'General Loops | Javascript',
#   'Published_date': '2020-10-08T15:02:03Z',
#   'Views': '188',
#   'Like_count': '188',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Block and Function Level Scope | Javascript Fundamentals',
#   'Published_date': '2020-10-08T15:00:41Z',
#   'Views': '239',
#   'Like_count': '239',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Date Objects | Javascript Fundamentals',
#   'Published_date': '2020-10-08T14:59:18Z',
#   'Views': '149',
#   'Like_count': '149',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Object Literals | Javascript Fundamentals',
#   'Published_date': '2020-10-08T14:58:30Z',
#   'Views': '224',
#   'Like_count': '224',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Arrays | Javascript Fundamentals',
#   'Published_date': '2020-10-08T14:57:51Z',
#   'Views': '221',
#   'Like_count': '221',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Template Literals | Javascript',
#   'Published_date': '2020-10-08T14:57:04Z',
#   'Views': '217',
#   'Like_count': '217',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Strings | Javascript',
#   'Published_date': '2020-10-08T14:56:22Z',
#   'Views': '272',
#   'Like_count': '272',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'The Math Object | Javascript Fundamentals',
#   'Published_date': '2020-10-08T14:55:21Z',
#   'Views': '259',
#   'Like_count': '259',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Variables in Javascript',
#   'Published_date': '2020-10-08T14:54:49Z',
#   'Views': '353',
#   'Like_count': '353',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Data Types in Javascript',
#   'Published_date': '2020-10-08T14:54:00Z',
#   'Views': '418',
#   'Like_count': '418',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Console in Javascript',
#   'Published_date': '2020-10-08T14:52:46Z',
#   'Views': '516',
#   'Like_count': '516',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Comments in Javascript',
#   'Published_date': '2020-10-08T14:52:23Z',
#   'Views': '461',
#   'Like_count': '461',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Introduction to Javascript | Using external javascript',
#   'Published_date': '2020-10-08T14:51:38Z',
#   'Views': '2062',
#   'Like_count': '2062',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Math Based Brain Game using Vanilla Javascript in 1 hour',
#   'Published_date': '2020-09-10T20:35:26Z',
#   'Views': '628',
#   'Like_count': '628',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Javascript based Math Brain Game Demo',
#   'Published_date': '2020-09-10T07:21:50Z',
#   'Views': '265',
#   'Like_count': '265',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Neural Network Notation',
#   'Published_date': '2020-09-06T17:18:37Z',
#   'Views': '1592',
#   'Like_count': '1592',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Prediction in Artificial Neural Network',
#   'Published_date': '2020-09-06T17:17:57Z',
#   'Views': '1355',
#   'Like_count': '1355',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Guest Lecture on "Front-end Development in MNCs"',
#   'Published_date': '2020-09-06T16:08:14Z',
#   'Views': '155',
#   'Like_count': '155',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Keras Classification Project - MNIST Digit Recognition Dataset',
#   'Published_date': '2020-09-06T16:04:36Z',
#   'Views': '9195',
#   'Like_count': '9195',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Bank Churn Classification - Keras Deep Learning',
#   'Published_date': '2020-09-06T16:04:12Z',
#   'Views': '1800',
#   'Like_count': '1800',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Graduate Admission Prediction - Keras Regression | Deep Learning | ANN',
#   'Published_date': '2020-09-06T16:03:48Z',
#   'Views': '4435',
#   'Like_count': '4435',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Session on Firebase | Building a Todo List Application',
#   'Published_date': '2020-08-31T06:25:06Z',
#   'Views': '391',
#   'Like_count': '391',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Life as a DevOps Engineer By Shomik Bose (British Telecom)',
#   'Published_date': '2020-08-27T18:24:07Z',
#   'Views': '1166',
#   'Like_count': '1166',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Build an IRCTC clone using Bootstrap and jQuery',
#   'Published_date': '2020-08-19T09:09:02Z',
#   'Views': '3681',
#   'Like_count': '3681',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Internet Protocol | Fundamentals of Web Development | Part 7',
#   'Published_date': '2020-08-07T06:19:58Z',
#   'Views': '1319',
#   'Like_count': '1319',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'The problem of Outliers | Logistic Regression',
#   'Published_date': '2020-08-07T06:19:16Z',
#   'Views': '2331',
#   'Like_count': '2331',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Sigmoid Function and Squashing | Logistic Regression',
#   'Published_date': '2020-08-07T06:18:27Z',
#   'Views': '4352',
#   'Like_count': '4352',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Lists and Tables',
#   'Published_date': '2020-08-07T06:17:48Z',
#   'Views': '1162',
#   'Like_count': '1162',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Style and Colors',
#   'Published_date': '2020-08-07T06:17:21Z',
#   'Views': '973',
#   'Like_count': '973',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Div and Span | Block level and Inline elements',
#   'Published_date': '2020-08-07T06:17:02Z',
#   'Views': '998',
#   'Like_count': '998',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Iframe tag in HTML',
#   'Published_date': '2020-08-07T06:16:37Z',
#   'Views': '951',
#   'Like_count': '951',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Meta Tags in HTML',
#   'Published_date': '2020-08-07T06:16:14Z',
#   'Views': '873',
#   'Like_count': '873',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'HTML Forms and Attributes',
#   'Published_date': '2020-08-07T06:15:43Z',
#   'Views': '965',
#   'Like_count': '965',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'HTML Form Elements',
#   'Published_date': '2020-08-07T06:15:23Z',
#   'Views': '862',
#   'Like_count': '862',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Types of Input Tag',
#   'Published_date': '2020-08-07T06:14:58Z',
#   'Views': '812',
#   'Like_count': '812',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Input Tag Attributes',
#   'Published_date': '2020-08-07T06:14:30Z',
#   'Views': '691',
#   'Like_count': '691',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Box Model',
#   'Published_date': '2020-08-07T06:13:40Z',
#   'Views': '240',
#   'Like_count': '240',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Border Property',
#   'Published_date': '2020-08-07T06:13:03Z',
#   'Views': '429',
#   'Like_count': '429',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Float and Alignment',
#   'Published_date': '2020-08-07T06:12:34Z',
#   'Views': '120',
#   'Like_count': '120',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Layouts',
#   'Published_date': '2020-08-07T06:11:44Z',
#   'Views': '282',
#   'Like_count': '282',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Overflow',
#   'Published_date': '2020-08-07T06:11:07Z',
#   'Views': '184',
#   'Like_count': '184',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Texts and Fonts',
#   'Published_date': '2020-08-07T06:10:27Z',
#   'Views': '70',
#   'Like_count': '70',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Link States and Buttons',
#   'Published_date': '2020-08-07T06:10:00Z',
#   'Views': '81',
#   'Like_count': '81',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Display Property',
#   'Published_date': '2020-08-07T06:09:25Z',
#   'Views': '291',
#   'Like_count': '291',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'CSS Positioning',
#   'Published_date': '2020-08-07T06:08:40Z',
#   'Views': '309',
#   'Like_count': '309',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Perceptron from scratch using Python',
#   'Published_date': '2020-08-07T06:05:36Z',
#   'Views': '9800',
#   'Like_count': '9800',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Perceptron Algorithm in Sklearn',
#   'Published_date': '2020-08-07T06:05:14Z',
#   'Views': '1357',
#   'Like_count': '1357',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'CampusX',
#   'Title': 'Perceptron Trick',
#   'Published_date': '2020-08-07T06:03:48Z',
#   'Views': '1399',
#   'Like_count': '1399',
#   'Comment_Count': '7'},
#  ...]

# %%
Video_data=pd.DataFrame(video_details)

# %%
Video_data
# Out:
#                       Channel_Name  \
# 0                   DeepLearningAI
# 1                   DeepLearningAI
# 2                   DeepLearningAI
# 3                   DeepLearningAI
# 4                   DeepLearningAI
# ...                            ...
# 22953  StatQuest with Josh Starmer
# 22954  StatQuest with Josh Starmer
# 22955  StatQuest with Josh Starmer
# 22956  StatQuest with Josh Starmer
# 22957  StatQuest with Josh Starmer
#
#                                                    Title  \
# 0      Learn to build multi-agent systems with divers...
# 1                     New Course: AI Agents in LangGraph
# 2      New course on agents! Enroll in AI Agentic Des...
# 3      Learn to deploy AI models on edge devices like...
# 4      New course with Qualcomm: Introduction to On-D...
# ...                                                  ...
# 22953           The standard error, Clearly Explained!!!
# 22954            Wrapping up dumplings for pot stickers.
# 22955                    R-squared, Clearly Explained!!!
# 22956                                         onion-dice
# 22957                                     Cutting Butter
#
#              Published_date   Views Like_count Comment_Count
# 0      2024-06-06T18:15:23Z    1650       1650             2
# 1      2024-06-05T13:08:30Z    2472       2472             1
# 2      2024-05-29T13:03:06Z    3140       3140             5
# 3      2024-05-28T22:15:51Z    2234       2234             0
# 4      2024-05-21T12:46:13Z    2987       2987             6
# ...                     ...     ...        ...           ...
# 22953  2015-05-12T14:10:24Z  213297     213297           258
# 22954  2015-04-19T21:18:04Z    9593       9593            17
# 22955  2015-02-03T14:48:20Z  572807     572807           709
# 22956  2014-09-28T16:12:29Z   12018      12018            43
# 22957  2014-08-24T21:40:26Z   17927      17927            65
#
# [22958 rows x 6 columns]

# %%
Video_data['Views'] = Video_data['Views'].replace("N/A", np.nan)
Video_data['Like_count'] = Video_data['Like_count'].replace("N/A", np.nan)
Video_data['Comment_Count'] = Video_data['Comment_Count'].replace("N/A", np.nan)

# %%
Video_data['Views'] = pd.to_numeric(Video_data['Views'], errors='coerce')
Video_data['Like_count'] = pd.to_numeric(Video_data['Like_count'], errors='coerce')
Video_data['Comment_Count'] = pd.to_numeric(Video_data['Comment_Count'], errors='coerce')

# %%
Video_data['Published_date'] = pd.to_datetime(Video_data['Published_date']).dt.date

# %%
Video_data.dtypes
# Out:
# Channel_Name       object
# Title              object
# Published_date     object
# Views             float64
# Like_count        float64
# Comment_Count     float64
# dtype: object

# %%
Video_data.to_csv(r'A:\data science material\data set\youtube\Youtube_dataset_all_dataScience_channels.csv', index=False)

# %%
videos_per_month.set_index('month',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 videos_per_month.set_index('month',inplace=True)
#
# NameError: name 'videos_per_month' is not defined
