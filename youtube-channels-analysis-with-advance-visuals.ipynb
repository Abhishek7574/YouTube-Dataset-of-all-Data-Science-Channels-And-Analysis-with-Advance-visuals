# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/youtube-dataset-all-data-scienceanalyst-channels/Youtube_dataset_all_dataScience_channels.csv

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import offline, iplot
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="plotly")



pd.options.display.float_format = "{:,.1f}".format

# %%
def update_layout(title_font_size = 28, hover_font_size = 16, hover_bgcolor = "#45FFCA", showlegend = False):
    fig.update_layout(
        showlegend = showlegend,
        title = {
            "font" : {
                "size" :title_font_size,
                "family" :"tahoma"
            }
        },
        hoverlabel={
            "bgcolor": hover_bgcolor,
            "font_size": hover_font_size,
            "font_family": "tahoma"
        }
    )

# %% [markdown]
# # Load The Dataset

# %%
df=pd.read_csv('/kaggle/input/youtube-dataset-all-data-scienceanalyst-channels/Youtube_dataset_all_dataScience_channels.csv')
df.sample(n=10)
# Out:
#           Channel_Name                                              Title  \
# 13574      WsCube Tech  Pigeon algorithm | Mind-Blowing Facts About Go...
# 4781        ExcelIsFun  Sort By Last Name using Excel Formula: Amazing...
# 16026           Kaggle  How to Enter a Kaggle Competition (using Kerne...
# 4475   Kevin Stratvert                             PIRATES Invade Seattle
# 3525        Tina Huang  How to Find Your Perfect Career (in the Age of...
# 2698        Krish Naik    Why Automation Will Not Kill Data Science Jobs?
# 1566       Keith Galli                 Quickest Ways to Win at Connect 4!
# 13430      WsCube Tech  What is & How to Use Tag, Triggers and Variabl...
# 3645   Kevin Stratvert     Create How to Videos 11x Faster with Guidde AI
# 22628        Rob Mulla                Kaggle Survey vs. Twitter Sentiment
#
#       Published_date     Views  Like_count  Comment_Count
# 13574     2019-06-22  16,150.0    16,150.0           15.0
# 4781      2023-05-24  26,831.0    26,831.0           23.0
# 16026     2019-08-12 177,618.0   177,618.0           73.0
# 4475      2016-07-03   1,508.0     1,508.0            8.0
# 3525      2023-05-12  92,374.0    92,374.0          209.0
# 2698      2020-10-14  10,704.0    10,704.0           51.0
# 1566      2017-10-16 485,687.0   485,687.0          233.0
# 13430     2019-09-03  19,181.0    19,181.0           34.0
# 3645      2024-05-21  12,948.0    12,948.0           40.0
# 22628     2022-10-26   4,686.0     4,686.0            9.0

# %% [markdown]
# # Now, Let's Get a Quick Overview 🧐

# %%
df.shape
# Out:
# (22958, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22958 entries, 0 to 22957
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    22958 non-null  object
#  1   Title           22958 non-null  object
#  2   Published_date  22958 non-null  object
#  3   Views           22956 non-null  float64
#  4   Like_count      22956 non-null  float64
#  5   Comment_Count   22931 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # Now, It's Time For Data Cleaning & Preprocessing🧐🔨

# %%
#as the null value are in the Views Like_count Comment_Count  we can replace it will 0     
df=df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22958 entries, 0 to 22957
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    22958 non-null  object
#  1   Title           22958 non-null  object
#  2   Published_date  22958 non-null  object
#  3   Views           22958 non-null  float64
#  4   Like_count      22958 non-null  float64
#  5   Comment_Count   22958 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# Channel_Name       object
# Title              object
# Published_date     object
# Views             float64
# Like_count        float64
# Comment_Count     float64
# dtype: object

# %%
df['Published_date'] = pd.to_datetime(df['Published_date'], format='%Y-%m-%d')

# %%
df['Views'] = df['Views'].astype('int64')
df['Like_count'] = df['Like_count'].astype('int64')
df['Comment_Count'] = df['Comment_Count'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22958 entries, 0 to 22957
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    22958 non-null  object
#  1   Title           22958 non-null  object
#  2   Published_date  22958 non-null  datetime64[ns]
#  3   Views           22958 non-null  int64
#  4   Like_count      22958 non-null  int64
#  5   Comment_Count   22958 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# # Now, Let's Dive Deeper Into Each Important Column 🌊🧐

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 22px arial;
#              color: lightgreen;
#              border: 2px solid lime;
#              border-radius: 8px">
# ♠ Rating Column 👦 🧔</h3>

# %%
Channel = df["Channel_Name"].value_counts()
(Channel / df.shape[0] * 100).apply(lambda x: f"{x: 0.2f} %")
# Out:
# Channel_Name
# WsCube Tech                     22.47 %
# ExcelIsFun                      16.11 %
# Krish Naik                       7.99 %
# freeCodeCamp.org                 7.27 %
# sentdex                          5.46 %
# CampusX                          4.57 %
# Guy in a Cube                    4.51 %
# codebasics                       3.82 %
# Kevin Stratvert                  3.72 %
# Socratica                        2.88 %
# Leila Gharani                    2.54 %
# Tableau Tim                      2.21 %
# Chandoo                          2.09 %
# DeepLearningAI                   1.88 %
# Kaggle                           1.66 %
# Nicholas Renotte                 1.34 %
# Alex The Analyst                 1.34 %
# Ken Jee                          1.25 %
# StatQuest with Josh Starmer      1.21 %
# Tina Huang                       0.96 %
# Luke Barousse                    0.69 %
# Rob Mulla                        0.68 %
# Ryan Nolan Data                  0.67 %
# Darshil Parmar                   0.66 %
# techTFQ                          0.59 %
# Keith Galli                      0.39 %
# Rishabh Mishra                   0.38 %
# Thu Vu data analytics            0.37 %
# Dataquest                        0.22 %
# Andrej Karpathy                  0.07 %
# Name: count, dtype: object

# %% [markdown]
# # Channel Name and Number of videos(%)

# %%
# Create the bar plot
fig = px.bar(
    data_frame=Channel.head(10), 
    x=Channel.head(10).index, 
    y=(Channel / sum(Channel) * 100).head(10),
    color=Channel.head(10).index,
    color_discrete_sequence=["#FF0060", "#45FFCA", "#45FFCA", "#293462", "#FF55BB", "#293462"],
    labels={"index": "Channel Name", "y": "(%)"},
    title="Channel Name and Number of videos(%)",
    text=Channel.head(10).apply(lambda x: f"{x / sum(Channel) * 100:0.2f}%"),
    template="plotly_dark"
)

# Update the layout
fig.update_layout(
    hoverlabel=dict(bgcolor="#111"),
    title_font=dict(size=24, color='lightgreen'),
    xaxis=dict(title='Channel Name'),
    yaxis=dict(title='Videos(%)'),
)

# Update traces
fig.update_traces(
    textfont={
        "family": "tahoma",
        "size": 13,
    },
    hovertemplate="Channel Name: %{x}<br>Videos: %{y:0.2f}%"
)

# Display the plot
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a77bc5b9-8ab8-49db-b7bc-4b4450d2f7b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a77bc5b9-8ab8-49db-b7bc-4b4450d2f7b2")) {                    Plotly.newPlot(                        "a77bc5b9-8ab8-49db-b7bc-4b4450d2f7b2",                        [{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"WsCube Tech","marker":{"color":"#FF0060","pattern":{"shape":""}},"name":"WsCube Tech","offsetgroup":"WsCube Tech","orientation":"v","showlegend":true,"text":["22.47%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["WsCube Tech"],"xaxis":"x","y":[22.46711386009234],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"ExcelIsFun","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"ExcelIsFun","offsetgroup":"ExcelIsFun","orientation":"v","showlegend":true,"text":["16.11%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["ExcelIsFun"],"xaxis":"x","y":[16.107674884571825],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Krish Naik","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"Krish Naik","offsetgroup":"Krish Naik","orientation":"v","showlegend":true,"text":["7.99%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Krish Naik"],"xaxis":"x","y":[7.988500740482621],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"freeCodeCamp.org","marker":{"color":"#293462","pattern":{"shape":""}},"name":"freeCodeCamp.org","offsetgroup":"freeCodeCamp.org","orientation":"v","showlegend":true,"text":["7.27%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["freeCodeCamp.org"],"xaxis":"x","y":[7.269797020646397],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"sentdex","marker":{"color":"#FF55BB","pattern":{"shape":""}},"name":"sentdex","offsetgroup":"sentdex","orientation":"v","showlegend":true,"text":["5.46%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["sentdex"],"xaxis":"x","y":[5.462148270755293],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"CampusX","marker":{"color":"#293462","pattern":{"shape":""}},"name":"CampusX","offsetgroup":"CampusX","orientation":"v","showlegend":true,"text":["4.57%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["CampusX"],"xaxis":"x","y":[4.573569126230508],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Guy in a Cube","marker":{"color":"#FF0060","pattern":{"shape":""}},"name":"Guy in a Cube","offsetgroup":"Guy in a Cube","orientation":"v","showlegend":true,"text":["4.51%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Guy in a Cube"],"xaxis":"x","y":[4.512588204547434],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"codebasics","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"codebasics","offsetgroup":"codebasics","orientation":"v","showlegend":true,"text":["3.82%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["codebasics"],"xaxis":"x","y":[3.8156633853123094],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Kevi ...

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 22px arial;
#              color: gold;
#              border: 3px solid tomato;
#              border-radius: 8px">
# ► From This Graph We Can Say that Ws cube tech uploads most videos !!!</h3>

# %% [markdown]
# # Number of Videos of data Science educators Through Years

# %%
view_by_year=df.groupby(df['Published_date'].dt.year)['Views'].agg('sum')
view_by_year
# Out:
# Published_date
# 2008     22022134
# 2009     27035684
# 2010     22467572
# 2011     16278454
# 2012     18713059
# 2013     26628638
# 2014     41098125
# 2015     39824091
# 2016     52527550
# 2017    110918957
# 2018    252950947
# 2019    357491113
# 2020    421882608
# 2021    500637257
# 2022    405691985
# 2023    230701146
# 2024     50743709
# Name: Views, dtype: int64

# %%
fig = px.area(view_by_year, 
            x = view_by_year.index, 
            y =view_by_year, 
            labels = {"index" :"Year", "y" :"View Counts"},
            line_shape="spline", 
            color_discrete_sequence=["#FF0060"],
            title = "Views in Data Science Content Through Years ⌛",
            template="plotly_dark",
              markers="O",
              
       )


update_layout()

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Year: %{x}<br>View Counts: %{y:0.2s}"
)
iplot(fig)
# Out:
# <div>                            <div id="b9e9273f-5cf9-4d25-abef-33d76fe6238e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9e9273f-5cf9-4d25-abef-33d76fe6238e")) {                    Plotly.newPlot(                        "b9e9273f-5cf9-4d25-abef-33d76fe6238e",                        [{"fillpattern":{"shape":""},"hovertemplate":"Year: %{x}\u003cbr\u003eView Counts: %{y:0.2s}","legendgroup":"","line":{"color":"#FF0060","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"stackgroup":"1","textfont":{"family":"tahoma","size":13},"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[22022134,27035684,22467572,16278454,18713059,26628638,41098125,39824091,52527550,110918957,252950947,357491113,421882608,500637257,405691985,230701146,50743709],"yaxis":"y","type":"scatter"}],                        {"hoverlabel":{"bgcolor":"#45FFCA","font":{"family":"tahoma","size":16}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker": ...

# %%
year=df['Published_date'].dt.year.value_counts().sort_index()
year
# Out:
# Published_date
# 2008     366
# 2009     614
# 2010     489
# 2011     359
# 2012     442
# 2013     686
# 2014     502
# 2015     621
# 2016     649
# 2017    1129
# 2018    1146
# 2019    2042
# 2020    3177
# 2021    3738
# 2022    3429
# 2023    2419
# 2024    1150
# Name: count, dtype: int64

# %%
fig = px.area(year, 
        x = year.index, 
        y =year, 
        labels = {"index" :"Year", "y" :"Videos Counts"},
        line_shape="spline", 
        color_discrete_sequence=["#45FFCA"],
        title = "Number of Videos of data Science educators Through Years 🗓️",
        template="plotly_dark",
       )


update_layout()
iplot(fig)
# Out:
# <div>                            <div id="8b8f38c3-e76e-4014-821d-422b6f059ee2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b8f38c3-e76e-4014-821d-422b6f059ee2")) {                    Plotly.newPlot(                        "8b8f38c3-e76e-4014-821d-422b6f059ee2",                        [{"fillpattern":{"shape":""},"hovertemplate":"Published_date=%{x}\u003cbr\u003eVideos Counts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#45FFCA","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[366,614,489,359,442,686,502,621,649,1129,1146,2042,3177,3738,3429,2419,1150],"yaxis":"y","type":"scatter"}],                        {"hoverlabel":{"bgcolor":"#45FFCA","font":{"family":"tahoma","size":16}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d ...

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 22px arial;
#              color: red;
#              border: 3px solid tomato;
#              border-radius: 8px">
#   Videos of data Science educators were highest in the year 2020-2022 probably beacuse of covid !!!</h3>

# %% [markdown]
# # Top 10 Data Science YouTube channels

# %%
df1= df.groupby('Channel_Name', as_index=False)['Views'].agg(['count', 'mean', 'sum'])
df1.columns = ['Channel_Name','video_count', 'view_mean', 'view_count']
df1
# Out:
#                    Channel_Name  video_count  view_mean  view_count
# 0              Alex The Analyst          307  114,871.2    35265444
# 1               Andrej Karpathy           15  690,405.2    10356078
# 2                       CampusX         1050   20,907.1    21952453
# 3                       Chandoo          479  100,542.6    48159907
# 4                Darshil Parmar          152   41,373.9     6288834
# 5                     Dataquest           50   41,937.0     2096849
# 6                DeepLearningAI          432   42,809.3    18493611
# 7                    ExcelIsFun         3698   41,834.8   154704922
# 8                 Guy in a Cube         1036   34,405.9    35644514
# 9                        Kaggle          380   11,207.7     4258920
# 10                  Keith Galli           89  170,584.2    15181994
# 11                      Ken Jee          287   31,390.1     9008964
# 12              Kevin Stratvert          854  491,454.7   419702350
# 13                   Krish Naik         1834   53,714.4    98512242
# 14                Leila Gharani          583  434,039.8   253045182
# 15                Luke Barousse          159  139,121.3    22120289
# 16             Nicholas Renotte          308   57,330.2    17657705
# 17               Rishabh Mishra           88  184,760.7    16258940
# 18                    Rob Mulla          157   74,002.4    11618374
# 19              Ryan Nolan Data          154    2,039.4      314062
# 20                    Socratica          661   89,974.0    59472846
# 21  StatQuest with Josh Starmer          278  236,140.1    65646950
# 22                  Tableau Tim          508    7,863.1     3994445
# 23        Thu Vu data analytics           86   91,346.9     7855837
# 24                   Tina Huang          220  142,059.9    31253178
# 25                  WsCube Tech         5158   56,255.7   290166978
# 26                   codebasics          876   97,570.3    85471551
# 27             freeCodeCamp.org         1669  432,369.5   721624649
# 28                      sentdex         1254   91,576.7   114837190
# 29                      techTFQ          136  122,410.1    16647771

# %%
df2 = df.groupby('Channel_Name', as_index=False)['Like_count'].agg(['mean', 'count', 'sum'])
df2.columns = ['Channel_Name','Like_mean', 'video_count', 'Like_count']
df2
# Out:
#                    Channel_Name  Like_mean  video_count  Like_count
# 0              Alex The Analyst  114,871.2          307    35265444
# 1               Andrej Karpathy  690,405.2           15    10356078
# 2                       CampusX   20,907.1         1050    21952453
# 3                       Chandoo  100,542.6          479    48159907
# 4                Darshil Parmar   41,373.9          152     6288834
# 5                     Dataquest   41,937.0           50     2096849
# 6                DeepLearningAI   42,809.3          432    18493611
# 7                    ExcelIsFun   41,834.8         3698   154704922
# 8                 Guy in a Cube   34,405.9         1036    35644514
# 9                        Kaggle   11,207.7          380     4258920
# 10                  Keith Galli  170,584.2           89    15181994
# 11                      Ken Jee   31,390.1          287     9008964
# 12              Kevin Stratvert  491,454.7          854   419702350
# 13                   Krish Naik   53,714.4         1834    98512242
# 14                Leila Gharani  434,039.8          583   253045182
# 15                Luke Barousse  139,121.3          159    22120289
# 16             Nicholas Renotte   57,330.2          308    17657705
# 17               Rishabh Mishra  184,760.7           88    16258940
# 18                    Rob Mulla   74,002.4          157    11618374
# 19              Ryan Nolan Data    2,039.4          154      314062
# 20                    Socratica   89,974.0          661    59472846
# 21  StatQuest with Josh Starmer  236,140.1          278    65646950
# 22                  Tableau Tim    7,863.1          508     3994445
# 23        Thu Vu data analytics   91,346.9           86     7855837
# 24                   Tina Huang  142,059.9          220    31253178
# 25                  WsCube Tech   56,255.7         5158   290166978
# 26                   codebasics   97,570.3          876    85471551
# 27             freeCodeCamp.org  432,369.5         1669   721624649
# 28                      sentdex   91,576.7         1254   114837190
# 29                      techTFQ  122,410.1          136    16647771

# %%
df3 = df.groupby('Channel_Name', as_index=False)['Comment_Count'].agg(['mean', 'count', 'sum'])
df3.columns = ['Channel_Name','Comment_mean', 'video_count', 'Comment_count']
df3
# Out:
#                    Channel_Name  Comment_mean  video_count  Comment_count
# 0              Alex The Analyst         178.0          307          54633
# 1               Andrej Karpathy         619.0           15           9285
# 2                       CampusX          38.3         1050          40234
# 3                       Chandoo          89.0          479          42617
# 4                Darshil Parmar          88.9          152          13510
# 5                     Dataquest          47.5           50           2375
# 6                DeepLearningAI          15.3          432           6600
# 7                    ExcelIsFun          40.6         3698         149979
# 8                 Guy in a Cube          41.9         1036          43357
# 9                        Kaggle           7.4          380           2805
# 10                  Keith Galli         176.4           89          15703
# 11                      Ken Jee          98.1          287          28143
# 12              Kevin Stratvert         382.6          854         326716
# 13                   Krish Naik          70.7         1834         129752
# 14                Leila Gharani         362.0          583         211057
# 15                Luke Barousse         190.2          159          30246
# 16             Nicholas Renotte         130.1          308          40060
# 17               Rishabh Mishra         349.4           88          30746
# 18                    Rob Mulla          83.8          157          13157
# 19              Ryan Nolan Data           7.5          154           1151
# 20                    Socratica          79.9          661          52827
# 21  StatQuest with Josh Starmer         337.6          278          93856
# 22                  Tableau Tim          11.2          508           5697
# 23        Thu Vu data analytics         111.6           86           9597
# 24                   Tina Huang         215.0          220          47291
# 25                  WsCube Tech          40.4         5158         208442
# 26                   codebasics          93.7          876          82091
# 27             freeCodeCamp.org         297.3         1669         496224
# 28                      sentdex         108.3         1254         135843
# 29                      techTFQ         174.6          136          23740

# %%
Channel_comparison = pd.concat([df1, df2[['Like_mean','Like_count']],df3[['Comment_mean','Comment_count']]],axis=1).query('video_count>20')
Channel_comparison
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
#
10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 0              Alex The Analyst          307  114,871.2    35265444
# 29                      techTFQ          136  122,410.1    16647771
# 15                Luke Barousse          159  139,121.3    22120289
# 24                   Tina Huang          220  142,059.9    31253178
# 10                  Keith Galli           89  170,584.2    15181994
# 17               Rishabh Mishra           88  184,760.7    16258940
# 21  StatQuest with Josh Starmer          278  236,140.1    65646950
# 27             freeCodeCamp.org         1669  432,369.5   721624649
# 14                Leila Gharani          583  434,039.8   253045182
# 12              Kevin Stratvert          854  491,454.7   419702350
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 0   114,871.2    35265444         178.0          54633
# 29  122,410.1    16647771         174.6          23740
# 15  139,121.3    22120289         190.2          30246
# 24  142,059.9    31253178         215.0          47291
# 10  170,584.2    15181994         176.4          15703
# 17  184,760.7    16258940         349.4          30746
# 21  236,140.1    65646950         337.6          93856
# 27  432,369.5   721624649         297.3         496224
# 14  434,039.8   253045182         362.0         211057
# 12  491,454.7   419702350         382.6         326716

# %%
fig = px.bar(
    data_frame= channel_views.tail(10), 
    orientation = "h", 
    y = channel_views.tail(10).Channel_Name, 
    x = channel_views.tail(10).view_mean,
    color = channel_views.tail(10).view_mean,

    labels = {"x": "average views", "y" : "Data Science YouTube channels"},
    title = "Top 10 Data Science YouTube channels with highest average views",
    text_auto= ".2s",
    template = "plotly_dark",
     color_continuous_scale=['#A084E8', '#00FFAB', '#00FFAB']
      )

update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textposition = "outside",
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Data Science YouTube channels: %{y}<br>average views: %{x:0.3s}"
)
iplot(fig)
# Out:
# <div>                            <div id="ae7760e1-a772-4d7f-9fa6-c6905a8b4389" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae7760e1-a772-4d7f-9fa6-c6905a8b4389")) {                    Plotly.newPlot(                        "ae7760e1-a772-4d7f-9fa6-c6905a8b4389",                        [{"alignmentgroup":"True","hovertemplate":"Data Science YouTube channels: %{y}\u003cbr\u003eaverage views: %{x:0.3s}","legendgroup":"","marker":{"color":[114871.15309446254,122410.08088235294,139121.3144654088,142059.9,170584.20224719102,184760.68181818182,236140.10791366905,432369.4721390054,434039.7632933105,491454.7423887588],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"textposition":"outside","texttemplate":"%{x:.2s}","x":[114871.15309446254,122410.08088235294,139121.3144654088,142059.9,170584.20224719102,184760.68181818182,236140.10791366905,432369.4721390054,434039.7632933105,491454.7423887588],"xaxis":"x","y":["Alex The Analyst","techTFQ","Luke Barousse","Tina Huang","Keith Galli","Rishabh Mishra","StatQuest with Josh Starmer","freeCodeCamp.org","Leila Gharani","Kevin Stratvert"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#A084E8"],[0.5,"#00FFAB"],[1.0,"#00FFAB"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %%
channel_Like_mean=Channel_comparison.sort_values(by='Like_mean',ascending=False)
channel_Like_mean.head(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 12              Kevin Stratvert          854  491,454.7   419702350
# 14                Leila Gharani          583  434,039.8   253045182
# 27             freeCodeCamp.org         1669  432,369.5   721624649
# 21  StatQuest with Josh Starmer          278  236,140.1    65646950
# 17               Rishabh Mishra           88  184,760.7    16258940
# 10                  Keith Galli           89  170,584.2    15181994
# 24                   Tina Huang          220  142,059.9    31253178
# 15                Luke Barousse          159  139,121.3    22120289
# 29                      techTFQ          136  122,410.1    16647771
# 0              Alex The Analyst          307  114,871.2    35265444
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 12  491,454.7   419702350         382.6         326716
# 14  434,039.8   253045182         362.0         211057
# 27  432,369.5   721624649         297.3         496224
# 21  236,140.1    65646950         337.6          93856
# 17  184,760.7    16258940         349.4          30746
# 10  170,584.2    15181994         176.4          15703
# 24  142,059.9    31253178         215.0          47291
# 15  139,121.3    22120289         190.2          30246
# 29  122,410.1    16647771         174.6          23740
# 0   114,871.2    35265444         178.0          54633

# %%
fig = px.bar(channel_Like_mean.head(10),  
                 x = "Channel_Name", 
                 y = "Like_mean",
                 color = "Channel_Name",
                 template = "plotly_dark",
                 color_discrete_sequence=["#45FFCA","#FF0060","#FF55BB", "#FFFDAF"],
                 opacity = 0.89,
                title = "Top 10 Data Science YouTube channels with highest average Likes")


update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Channel_Name: %{x}<br>average Likes: %{y}"
)
iplot(fig)
# Out:
# <div>                            <div id="f2716929-3a61-47c5-b4de-e39ec0a00807" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2716929-3a61-47c5-b4de-e39ec0a00807")) {                    Plotly.newPlot(                        "f2716929-3a61-47c5-b4de-e39ec0a00807",                        [{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Kevin Stratvert","marker":{"color":"#45FFCA","opacity":0.89,"pattern":{"shape":""}},"name":"Kevin Stratvert","offsetgroup":"Kevin Stratvert","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Kevin Stratvert"],"xaxis":"x","y":[491454.7423887588],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Leila Gharani","marker":{"color":"#FF0060","opacity":0.89,"pattern":{"shape":""}},"name":"Leila Gharani","offsetgroup":"Leila Gharani","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Leila Gharani"],"xaxis":"x","y":[434039.7632933105],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"freeCodeCamp.org","marker":{"color":"#FF55BB","opacity":0.89,"pattern":{"shape":""}},"name":"freeCodeCamp.org","offsetgroup":"freeCodeCamp.org","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["freeCodeCamp.org"],"xaxis":"x","y":[432369.4721390054],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"StatQuest with Josh Starmer","marker":{"color":"#FFFDAF","opacity":0.89,"pattern":{"shape":""}},"name":"StatQuest with Josh Starmer","offsetgroup":"StatQuest with Josh Starmer","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["StatQuest with Josh Starmer"],"xaxis":"x","y":[236140.10791366905],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Rishabh Mishra","marker":{"color":"#45FFCA","opacity":0.89,"pattern":{"shape":""}},"name":"Rishabh Mishra","offsetgroup":"Rishabh Mishra","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Rishabh Mishra"],"xaxis":"x","y":[184760.68181818182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Keith Galli","marker":{"color":"#FF0060","opacity":0.89,"pattern":{"shape":""}},"name":"Keith Galli","offsetgroup":"Keith Galli","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Keith Galli"],"xaxis":"x","y":[170584.20224719102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Tina Huang","marker":{"color":"#FF55BB","opacity":0.89,"pattern":{"shape":""}},"name":"Tina Huang","offsetgroup":"Tina Huang","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Tina Huang"],"xaxis":"x","y":[142059.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Luke Barousse","marker":{"color":"#FFFDAF","opacity":0.89,"pattern":{"shape":""}},"name":"Luke Barousse","offsetgroup":"Luke Barousse","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Luke Barousse"],"xaxis":"x","y":[139121.3144654088],"yaxis":"y","type ...

# %%
channel_Comment_mean=Channel_comparison.sort_values(by='Comment_mean',ascending=True)
channel_Comment_mean.tail(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 29                      techTFQ          136  122,410.1    16647771
# 10                  Keith Galli           89  170,584.2    15181994
# 0              Alex The Analyst          307  114,871.2    35265444
# 15                Luke Barousse          159  139,121.3    22120289
# 24                   Tina Huang          220  142,059.9    31253178
# 27             freeCodeCamp.org         1669  432,369.5   721624649
# 21  StatQuest with Josh Starmer          278  236,140.1    65646950
# 17               Rishabh Mishra           88  184,760.7    16258940
# 14                Leila Gharani          583  434,039.8   253045182
# 12              Kevin Stratvert          854  491,454.7   419702350
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 29  122,410.1    16647771         174.6          23740
# 10  170,584.2    15181994         176.4          15703
# 0   114,871.2    35265444         178.0          54633
# 15  139,121.3    22120289         190.2          30246
# 24  142,059.9    31253178         215.0          47291
# 27  432,369.5   721624649         297.3         496224
# 21  236,140.1    65646950         337.6          93856
# 17  184,760.7    16258940         349.4          30746
# 14  434,039.8   253045182         362.0         211057
# 12  491,454.7   419702350         382.6         326716

# %%
fig = px.scatter(channel_Comment_mean.tail(10),  
                 y = "Channel_Name", 
                 x = "Comment_mean", 
                 size = "Comment_mean",
                 color = "Comment_mean",
                 template = "plotly_dark",
                 labels={"name" :"Data Science YouTube channels", "score" :"average comments"},
                 opacity = 0.89,
                title = "Top 10 Data Science YouTube channels with highest average comments",
                color_continuous_scale=['#A084E8', '#8BE8E5', '#00FFAB'])


update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "YouTube channels: %{y}<br>average comments: %{x}"
)
iplot(fig)
# Out:
# <div>                            <div id="b525fea1-b98c-4e06-a472-82fa4180f08b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b525fea1-b98c-4e06-a472-82fa4180f08b")) {                    Plotly.newPlot(                        "b525fea1-b98c-4e06-a472-82fa4180f08b",                        [{"hovertemplate":"YouTube channels: %{y}\u003cbr\u003eaverage comments: %{x}","legendgroup":"","marker":{"color":[174.55882352941177,176.43820224719101,177.95765472312704,190.22641509433961,214.95909090909092,297.318154583583,337.6115107913669,349.3863636363636,362.0188679245283,382.57142857142856],"coloraxis":"coloraxis","opacity":0.89,"size":[174.55882352941177,176.43820224719101,177.95765472312704,190.22641509433961,214.95909090909092,297.318154583583,337.6115107913669,349.3863636363636,362.0188679245283,382.57142857142856],"sizemode":"area","sizeref":0.9564285714285714,"symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"x":[174.55882352941177,176.43820224719101,177.95765472312704,190.22641509433961,214.95909090909092,297.318154583583,337.6115107913669,349.3863636363636,362.0188679245283,382.57142857142856],"xaxis":"x","y":["techTFQ","Keith Galli","Alex The Analyst","Luke Barousse","Tina Huang","freeCodeCamp.org","StatQuest with Josh Starmer","Rishabh Mishra","Leila Gharani","Kevin Stratvert"],"yaxis":"y","type":"scatter"}],                        {"coloraxis":{"colorbar":{"title":{"text":"Comment_mean"}},"colorscale":[[0.0,"#A084E8"],[0.5,"#8BE8E5"],[1.0,"#00FFAB"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"itemsizing":"constant","tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %% [markdown]
# <h3 style = "background-color: #010101;
#              padding: 15px;
#              font: bold 20px arial;
#              color: gold;
#              border: 2px solid tomato;
#              border-radius: 8px">
# ♣ Now, will these 3 visuals we can notice some common youtube channels name we can say that probably they are the  <span style = "color: tomato">Best Data Science Educators</span> in The YouTube !! 👑🎬</h3>

# %% [markdown]
# #  Correlation

# %% [markdown]
# <h3 style = "background-color: #010101;
#              padding: 18px;
#              font: bold 24px arial;
#              color: #45FFCA;
#              border: 2px solid green;
#              border-radius: 8px">
# ♣ Is There Any Correlation in the data set?!🎬</h3>

# %%
df_corr = Channel_comparison[["video_count", "view_mean",  "Like_mean", "Comment_mean"]]

# %%
df_corr.corr(numeric_only=True)
# Out:
#               video_count  view_mean  Like_mean  Comment_mean
# video_count           1.0       -0.0       -0.0          -0.2
# view_mean            -0.0        1.0        1.0           0.9
# Like_mean            -0.0        1.0        1.0           0.9
# Comment_mean         -0.2        0.9        0.9           1.0

# %%
# Create The Plotly Heat Map
fig = px.imshow(
    df_corr.corr(numeric_only = True), 
    text_auto="0.2f", aspect="auto", template="plotly_dark",
    title="Correlation",
    color_continuous_scale = "earth"
) 

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Feature[1]: %{x}<br>Feature[2]: %{y}"
)
iplot(fig)
# Out:
# <div>                            <div id="94d77f80-0279-4c27-ad21-9701d608dfc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94d77f80-0279-4c27-ad21-9701d608dfc8")) {                    Plotly.newPlot(                        "94d77f80-0279-4c27-ad21-9701d608dfc8",                        [{"coloraxis":"coloraxis","hovertemplate":"Feature[1]: %{x}\u003cbr\u003eFeature[2]: %{y}","name":"0","textfont":{"family":"tahoma","size":16},"texttemplate":"%{z:0.2f}","x":["video_count","view_mean","Like_mean","Comment_mean"],"xaxis":"x","y":["video_count","view_mean","Like_mean","Comment_mean"],"yaxis":"y","z":[[1.0,-0.036221309523351314,-0.036221309523351314,-0.19989875683467673],[-0.036221309523351314,1.0,1.0,0.8894271545083864],[-0.036221309523351314,1.0,1.0,0.8894271545083864],[-0.19989875683467673,0.8894271545083864,0.8894271545083864,1.0]],"type":"heatmap"}],                        {"coloraxis":{"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":15}},"showlegend":true,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444 ...

# %% [markdown]
# <h3 style = "background-color: #000;
#              padding: 18px;
#              font: bold 20px tahoma;
#              color: gold;
#              border: 3px solid tomato;
#              border-radius: 8px">
#     ► From The HeatMap, We Can Say 😉🧐
#     <BR><HR style = "border: 1px solid #555">
#         1) There Is a Very Strong Positive Correlation Between <U>view_mean</U> and <U>Like_mean</U> (1.0)🔗..
#     <BR>
#         2) There Is a Strong Positive Correlation Between <U>view_mean</U> and <U>Comment_mean</U> (0.89)🔗
#
#
# </h3>

# %%
fig = px.scatter(
    Channel_comparison, 
    x = Channel_comparison["view_mean"], 
    y = Channel_comparison["Like_mean"], 
    trendline="ols",
    template="plotly_dark",
    color = Channel_comparison["Like_mean"],
    color_discrete_sequence=["#45FFCA"],
    title = "Relation Between Views & Likes",
                 
          )

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)
fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Views: %{x:0.3s}<br>Likes: %{y:0.3s}"
)
iplot(fig)
# Out:
# <div>                            <div id="27cdc2d8-e620-41a8-8889-673d117be19c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27cdc2d8-e620-41a8-8889-673d117be19c")) {                    Plotly.newPlot(                        "27cdc2d8-e620-41a8-8889-673d117be19c",                        [{"hovertemplate":"Views: %{x:0.3s}\u003cbr\u003eLikes: %{y:0.3s}","legendgroup":"","marker":{"color":[114871.15309446254,20907.098095238096,100542.60334029228,41373.90789473684,41936.98,42809.28472222222,41834.75446187128,34405.901544401546,11207.684210526315,170584.20224719102,31390.118466898955,491454.7423887588,53714.41766630316,434039.7632933105,139121.3144654088,57330.21103896104,184760.68181818182,74002.3821656051,2039.3636363636363,89974.04841149773,236140.10791366905,7863.080708661418,91346.94186046511,142059.9,56255.71500581621,97570.26369863014,432369.4721390054,91576.70653907496,122410.08088235294],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":
# %%
best_videos=df.sort_values(by=['Views', 'Like_count', 'Comment_Count'], ascending=True)
best_videos.tail(10)
# Out:
#            Channel_Name                                              Title  \
# 20547  freeCodeCamp.org  Introduction to Programming and Computer Scien...
# 20442  freeCodeCamp.org  Microsoft Excel Tutorial for Beginners - Full ...
# 17594        codebasics     Don't put toy dataset projects on your resume!
# 20124  freeCodeCamp.org  Harvard CS50 – Full Computer Science Universit...
# 20872  freeCodeCamp.org               C Programming Tutorial for Beginners
# 20860  freeCodeCamp.org           C++ Tutorial for Beginners - Full Course
# 20720  freeCodeCamp.org       Learn JavaScript - Full Course for Beginners
# 20930  freeCodeCamp.org  SQL Tutorial - Full Database Course for Beginners
# 11210       WsCube Tech  Ethical HACKING Full Course in 10 HOURS (Begin...
# 20913  freeCodeCamp.org  Learn Python - Full Course for Beginners [Tuto...
#
#       Published_date     Views  Like_count  Comment_Count
# 20547     2020-04-21   8255812     8255812           4095
# 20442     2020-10-28   8998280     8998280           2446
# 17594     2024-03-22   9311413     9311413            541
# 20124     2022-10-19  11083884    11083884           7324
# 20872     2018-08-15  11353737    11353737           6674
# 20860     2018-08-24  12260170    12260170          11965
# 20720     2018-12-10  17075237    17075237           8540
# 20930     2018-07-02  18048065    18048065          11098
# 11210     2021-08-29  22003831    22003831           7772
# 20913     2018-07-11  44191019    44191019          44314

# %%
fig = px.bar(
    data_frame=best_videos.tail(10), 
    orientation="h", 
    y=best_videos.tail(10).Title, 
    x=best_videos.tail(10).Views,
    color=best_videos.tail(10).Views,
    labels={"x": "View,Likes and Comment", "y": "Videos"},
    title="Top 10 Videos on the basis of View,Likes and Comment",
    text_auto=".2s",
    template="plotly_dark",
    color_continuous_scale=['#FF5733', '#C70039', '#900C3F']
)
update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textposition = "outside",
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Videos: %{y}<br>AVG View: %{x:0.3s}"
)
iplot(fig)
# Out:
# <div>                            <div id="5c9f0807-9011-44f6-a670-b47af069067b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c9f0807-9011-44f6-a670-b47af069067b")) {                    Plotly.newPlot(                        "5c9f0807-9011-44f6-a670-b47af069067b",                        [{"alignmentgroup":"True","hovertemplate":"Videos: %{y}\u003cbr\u003eAVG View: %{x:0.3s}","legendgroup":"","marker":{"color":[8255812,8998280,9311413,11083884,11353737,12260170,17075237,18048065,22003831,44191019],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"textposition":"outside","texttemplate":"%{x:.2s}","x":[8255812,8998280,9311413,11083884,11353737,12260170,17075237,18048065,22003831,44191019],"xaxis":"x","y":["Introduction to Programming and Computer Science - Full Course","Microsoft Excel Tutorial for Beginners - Full Course","Don't put toy dataset projects on your resume!","Harvard CS50 – Full Computer Science University Course","C Programming Tutorial for Beginners","C++ Tutorial for Beginners - Full Course","Learn JavaScript - Full Course for Beginners","SQL Tutorial - Full Database Course for Beginners","Ethical HACKING Full Course in 10 HOURS (Beginners to Pro) | Learn Ethical Hacking 2024","Learn Python - Full Course for Beginners [Tutorial]"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#FF5733"],[0.5,"#C70039"],[1.0,"#900C3F"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0. ...

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 18px arial;
#              color: lightgreen;
#              border: 2px solid lime;
#              border-radius: 8px">
# ► These are the best video according to the audience .
# <BR>
